# %% [markdown]
# #[Mistral](https://mistral.ai/news/announcing-mistral-7b/)
#
# Mistral is an open-source large language model developed by Mistral AI.
#
# In this notebook, we are using Mistral 7B with 7 billion parameters. We will define prompts for tuning our model and create functions to map our data to these prompts. By doing so, we can tailor the model’s responses to the specific question answering problem.

# %% [markdown]
# ##Configurations and imports
#
# Let's import everything we need for the execution!
#
# **Remember to set the flags in the right way to execute everything you need**

# %%
USE_PRETRAINED = True       # Set to False if you want to fine-tune the model and save it, otherwise it will be loaded the previous fine-tuned LoRA model
EXPORT_MODEL = False        # Set to True if you want to export the GGUF model
DOWNLOAD_BIOSENT = False    # Set to True if you want to download the biosentvec dataset to test the model
TEST_MODEL = True           # Set to True if you want to test the model
DOWNLOAD_DATASET = False    # Set to True if you want to download the huggingface dataset and re-split it (note that by doing it you will have a different split of the train-test)

# %%
MODEL_PATH = '/content/drive/MyDrive/Colab Notebooks/NLP/project/Models/Mistral'
DATAS_PATH = '/content/drive/MyDrive/Colab Notebooks/NLP/project/Models/Datasets'
model_name = "unsloth/mistral-7b-v0.3-bnb-4bit"

# %%
# %%capture
# Installs Unsloth, Xformers (Flash Attention) and all other packages!
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps xformers trl peft accelerate bitsandbytes

# %%
from google.colab import drive
from unsloth import FastLanguageModel
from unsloth import is_bfloat16_supported
import torch
from datasets import load_dataset
from datasets import Dataset
import os
from trl import SFTTrainer
import sys
from transformers import TrainingArguments
from transformers.utils import logging
from nltk import word_tokenize
from nltk.corpus import stopwords
from string import punctuation
from scipy.spatial import distance
import nltk
from tqdm import tqdm
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import time
# Out:
# 🦥 Unsloth: Will patch your computer to enable 2x faster free finetuning.

# %%
if TEST_MODEL:
  # !pip install bert-score
  from bert_score import BERTScorer

  # !git clone https://github.com/epfml/sent2vec.git
  # %cd sent2vec
  # !make
  # !pip install .
  import sent2vec

  sys.setrecursionlimit(4000)
# Out:
# Collecting bert-score
#   Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 1.8 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.3.0+cu121)
# Requirement already satisfied: pandas>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.0.3)
# Requirement already satisfied: transformers>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.41.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from bert-score) (1.25.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from bert-score) (2.31.0)
# Requirement already satisfied: tqdm>=4.31.1 in /usr/local/lib/python3.10/dist-packages (from bert-score) (4.66.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from bert-score) (3.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from bert-score) (24.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.0.1->bert-score) (2024.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.14.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (4.11.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (2023.6.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.0.0->bert-score)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.0->bert-score) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.0.0->bert-score)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 70.1 MB/s eta 0:00:00
# Requirement already satisfied: huggingface-hub<1.0,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.23.1)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=3.0.0->bert-score) (0.4.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->bert-score) (3.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->bert-score) (2024.2.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.0.1->bert-score) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.0.0->bert-score) (2.1.5)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.0->bert-score) (1.3.0)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, bert-score
# Successfully installed bert-score-0.3.13 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105
# Cloning into 'sent2vec'...
# remote: Enumerating objects: 425, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 425 (delta 9), reused 4 (delta 1), pack-reused 403
# Receiving objects: 100% (425/425), 447.46 KiB | 7.33 MiB/s, done.
# Resolving deltas: 100% (261/261), done.
# /content/sent2vec
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/args.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/dictionary.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/productquantizer.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/matrix.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/shmem_matrix.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/qmatrix.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/vector.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/model.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/utils.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/fasttext.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops args.o dictionary.o productquantizer.o matrix.o shmem_matrix.o qmatrix.o vector.o model.o utils.o fasttext.o src/main.cc -o fasttext -lrt
# Processing /content/sent2vec
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: Cython>=0.29.13 in /usr/local/lib/python3.10/dist-packages (from sent2vec==0.0.0) (3.0.10)
# Requirement already satisfied: numpy>=1.17.1 in /usr/local/lib/python3.10/dist-packages (from sent2vec==0.0.0) (1.25.2)
# Building wheels for collected packages: sent2vec
#   Building wheel for sent2vec (pyproject.toml) ... done
#   Created wheel for sent2vec: filename=sent2vec-0.0.0-cp310-cp310-linux_x86_64.whl size=1630746 sha256=e38cea064f6809119e861bb0b6501592975ac1bd043e79050301cfca11180100
#   Stored in directory: /tmp/pip-ephem-wheel-cache-s87x9yku/wheels/c1/9d/a2/1965b1b523b356923efa34b6d037d0436acfc3cd6f81758e1c
# Successfully built sent2vec
# Installing collected packages: sent2vec
# Successfully installed sent2vec-0.0.0

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
if DOWNLOAD_BIOSENT:
  os.chdir(f'{DATAS_PATH}')
  os.getcwd()
  # !wget https://ftp.ncbi.nlm.nih.gov/pub/lu/Suppl/BioSentVec/BioSentVec_PubMed_MIMICIII-bigram_d700.bin

# %%
os.chdir(f'{MODEL_PATH}')
os.getcwd()
# Out:
# '/content/drive/MyDrive/Colab Notebooks/NLP/project/Models/Mistral'

# %%
nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %% [markdown]
# ## Model definition
#
# To accelerate the fine-tuning process of our model, we opted for a lightweight tool developed by the community: [Unsloth](https://github.com/unslothai/unsloth).
#
# Unsloth works by overwriting some parts of the modeling code with optimized operations. By manually deriving backpropagation steps and rewriting all Pytorch modules into Triton kernels, Unsloth can both reduce memory usage and make fine-tuning faster.
#
# Crucially, **accuracy degradation is 0%** with respect to normal QLoRA, because no approximations are made in the optimized code.

# %%
max_seq_length = 4096   # We use RoPE Scaling to extend it to 4096 with Unsloth!
dtype = None            # None for auto detection. Float16 for Tesla T4, V100, Bfloat16 for Ampere+
load_in_4bit = True     # Use 4bit quantization to reduce memory usage. Can be False.

# %%
if USE_PRETRAINED:
    #@title Loading finetuned models
    model, tokenizer = FastLanguageModel.from_pretrained(
        model_name = "lora_model", # YOUR MODEL YOU USED FOR TRAINING
        max_seq_length = max_seq_length,
        dtype = dtype,
        load_in_4bit = load_in_4bit,
    )
    FastLanguageModel.for_inference(model) # Enable native 2x faster inference
# Out:
# config.json:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# ==((====))==  Unsloth: Fast Mistral patching release 2024.5
#    \\   /|    GPU: Tesla T4. Max memory: 14.748 GB. Platform = Linux.
# O^O/ \_/ \    Pytorch: 2.3.0+cu121. CUDA = 7.5. CUDA Toolkit = 12.1.
# \        /    Bfloat16 = FALSE. Xformers = 0.0.26.post1. FA = False.
#  "-____-"     Free Apache license: http://github.com/unslothai/unsloth
# model.safetensors:   0%|          | 0.00/4.14G [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/111 [00:00<?, ?B/s]
# You set `add_prefix_space`. The tokenizer needs to be converted from the slow tokenizers
# You are using the default legacy behaviour of the <class 'transformers.models.llama.tokenization_llama.LlamaTokenizer'>. This is expected, and simply means that the `legacy` (previous) behavior will be used so nothing changes for you. If you want to use the new behaviour, set `legacy=False`. This should only be set if you understand what it means, and thoroughly read the reason why this was added as explained in https://github.com/huggingface/transformers/pull/24565
# Unsloth 2024.5 patched 32 layers with 32 QKV layers, 32 O layers and 32 MLP layers.

# %%
if not USE_PRETRAINED:
  model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = model_name,
    max_seq_length = max_seq_length,
    dtype = dtype,
    load_in_4bit = load_in_4bit,
  )

# %% [markdown]
# To speedup the tuning even more and decrease the needed computational power we used [LoRA](https://arxiv.org/abs/2106.09685). LoRA is a novel technique introduced by Microsoft researchers to deal with the problem of fine-tuning large-language models.
#
# LoRA proposes freezing pre-trained model weights, which reduces the number of trainable parameters and GPU memory requirements.

# %%
if not USE_PRETRAINED:
  model = FastLanguageModel.get_peft_model(
      model,
      r = 32,    #16 in previous implementation                    # Choose any number > 0 ! Suggested 8, 16, 32, 64, 128
      target_modules = ["q_proj", "k_proj", "v_proj", "o_proj",
                        "gate_proj", "up_proj", "down_proj",],
      lora_alpha = 32, #16 in previous implementation
      lora_dropout = 0,                                            # Currently only supports dropout = 0
      bias = "none",                                               # Currently only supports bias = "none"
      use_gradient_checkpointing = "unsloth",                          # We set `gradient_checkpointing=False` ONLY for TinyLlama since Unsloth saves tonnes of memory usage. @@@ IF YOU GET OUT OF MEMORY - set to True @@@
      random_state = 3407,
      use_rslora = False,                                          # We support rank stabilized LoRA
      loftq_config = None,                                         # And LoftQ
  )

# %%
alpaca_prompt = """Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS_TOKEN = tokenizer.eos_token
def formatting_prompts_func(examples):
    instructions = examples["instruction"]
    inputs       = examples["input"]
    outputs      = examples["output"]
    texts = []
    for instruction, input, output in zip(instructions, inputs, outputs):
        # Must add EOS_TOKEN, otherwise your generation will go on forever!
        text = alpaca_prompt.format(instruction, input, output) + EOS_TOKEN
        texts.append(text)
    return { "text" : texts, }
pass

# %% [markdown]
# ## Dataset import
# To maintain the integrity of model testing, we pre-saved the dataset split in a dataframe. This ensures that during testing, no training samples are utilized, thereby preserving the model evaluation process.

# %%
if DOWNLOAD_DATASET:
  dataset_path = "medalpaca/medical_meadow_medical_flashcards"
  raw_dataset = load_dataset(dataset_path)
  dataset = raw_dataset["train"].train_test_split(test_size=0.2)
  train_dataset = dataset["train"]
  test_dataset = dataset["test"]
  if False:
    df_train = dataset["train"].to_pandas()
    df_test = dataset["test"].to_pandas()
    os.chdir(f'{DATAS_PATH}')
    os.getcwd()
    df_train.to_csv("train_split.csv", index=False)
    df_test.to_csv("test_split.csv", index=False)
    os.chdir(f'{MODEL_PATH}')
    os.getcwd()
else:
  os.chdir(f'{DATAS_PATH}')
  os.getcwd()
  test_dataset = Dataset.from_pandas(pd.read_csv('test_split.csv'))
  train_dataset = Dataset.from_pandas(pd.read_csv('train_split.csv'))
  os.chdir(f'{MODEL_PATH}')
  os.getcwd()

train_dataset = train_dataset.map(formatting_prompts_func, batched = True)
test_dataset = test_dataset.map(formatting_prompts_func, batched = True)
# Out:
# Map:   0%|          | 0/27164 [00:00<?, ? examples/s]
# Map:   0%|          | 0/6791 [00:00<?, ? examples/s]

# %% [markdown]
# ## Train the model
# Now let's use Huggingface TRL's `SFTTrainer`!

# %%
if not USE_PRETRAINED:
  logging.set_verbosity_info()

  training_args = TrainingArguments(
      per_device_train_batch_size = 8,
      gradient_accumulation_steps = 4,
      warmup_ratio = 0.1,
      num_train_epochs = 3,
      save_steps = 100,
      learning_rate = 2e-4,
      fp16 = not is_bfloat16_supported(),
      bf16 = is_bfloat16_supported(),
      #fp16 = not torch.cuda.is_bf16_supported(),
      #bf16 = torch.cuda.is_bf16_supported(),
      logging_steps = 1,
      optim = "adamw_8bit",
      weight_decay = 0.01,
      lr_scheduler_type = "linear",
      seed = 3407,
      output_dir = "outputs",
      overwrite_output_dir = True
  )

  trainer = SFTTrainer(
      model = model,
      tokenizer = tokenizer,
      train_dataset = train_dataset,
      dataset_text_field = "text",
      max_seq_length = max_seq_length,
      dataset_num_proc = 2,
      packing = False, # Packs short sequences together to save time!
      args = training_args,
  )

# %%
if not USE_PRETRAINED:
  #@title Show current memory stats
  gpu_stats = torch.cuda.get_device_properties(0)
  start_gpu_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
  max_memory = round(gpu_stats.total_memory / 1024 / 1024 / 1024, 3)
  print(f"GPU = {gpu_stats.name}. Max memory = {max_memory} GB.")
  print(f"{start_gpu_memory} GB of memory reserved.")

# %%
if not USE_PRETRAINED:
  if len(os.listdir("outputs")) <= 1:
    trainer_stats = trainer.train()
  else:
    trainer_stats = trainer.train(resume_from_checkpoint=True)

# %%
if not USE_PRETRAINED:
  #@title Show final memory and time stats
  used_memory = round(torch.cuda.max_memory_reserved() / 1024 / 1024 / 1024, 3)
  used_memory_for_lora = round(used_memory - start_gpu_memory, 3)
  used_percentage = round(used_memory         /max_memory*100, 3)
  lora_percentage = round(used_memory_for_lora/max_memory*100, 3)
  print(f"{trainer_stats.metrics['train_runtime']} seconds used for training.")
  print(f"{round(trainer_stats.metrics['train_runtime']/60, 2)} minutes used for training.")
  print(f"Peak reserved memory = {used_memory} GB.")
  print(f"Peak reserved memory for training = {used_memory_for_lora} GB.")
  print(f"Peak reserved memory % of max memory = {used_percentage} %.")
  print(f"Peak reserved memory for training % of max memory = {lora_percentage} %.")

# %% [markdown]
# ##Functions
# Some useful functions!

# %%
stop_words = set(stopwords.words('english'))
def preprocess_sentence(text):
    text = text.replace('/', ' / ')
    text = text.replace('.-', ' .- ')
    text = text.replace('.', ' . ')
    text = text.replace('\'', ' \' ')
    text = text.lower()

    tokens = [token for token in word_tokenize(text) if token not in punctuation and token not in stop_words]

    return ' '.join(tokens)

# %%
def generate_answer(question):
  # alpaca_prompt = Copied from above
  FastLanguageModel.for_inference(model) # Enable native 2x faster inference
  inputs = tokenizer(
  [
      alpaca_prompt.format(
          "Answer this question truthfully", # instruction
          question, # input
          "", # output - leave this blank for generation!
      )
  ], return_tensors = "pt").to("cuda")

  outputs = model.generate(**inputs, max_new_tokens = 128, use_cache = True, pad_token_id=tokenizer.eos_token_id)
  tokenizer.batch_decode(outputs)
  predicted_answer = tokenizer.batch_decode(outputs[:, inputs['input_ids'].shape[1]:])[0]
  predicted_answer = predicted_answer[:(len(predicted_answer)-5)]
  return predicted_answer

# %% [markdown]
# ## Inference
# Let's run the model! You can change the instruction and input - leave the output blank!

# %% [markdown]
#  We can also use a `TextStreamer` for continuous inference - so you can see the generation token by token, instead of waiting the whole time!

# %%
# alpaca_prompt = Copied from above
FastLanguageModel.for_inference(model) # Enable native 2x faster inference
inputs = tokenizer(
[
    alpaca_prompt.format(
        "Answer this question truthfully", # instruction
        "What is the PAP test?", # input
        "", # output - leave this blank for generation!
    )
], return_tensors = "pt").to("cuda")

from transformers import TextStreamer
text_streamer = TextStreamer(tokenizer)
_ = model.generate(**inputs, streamer = text_streamer, max_new_tokens = 128, use_cache = False)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> Below is an instruction that describes a task, paired with an input that provides further context. Write a response that appropriately completes the request.
#
# ### Instruction:
# Answer this question truthfully
#
# ### Input:
# What is the PAP test?
#
# ### Response:
# The PAP test is a screening test used to detect abnormal cells in the cervix that may be indicative of cervical cancer or pre-cancerous conditions. The test involves collecting cells from the cervix and examining them under a microscope for any abnormalities. The PAP test is recommended for women between the ages of 21 and 65 and should be repeated every 3-5 years. It is an important tool for detecting cervical cancer early, when it is most treatable.</s>

# %% [markdown]
# ##Testing
#
# To evaluate the model is essential to establish metrics that evaluate the accuracy of a generated answer relative to the correct one. In our context, we have identified two key metrics: **BERTScore** and **Evaluation with Embedding**
#
# We chose these metrics over more statistical ones because both BERTScores and embeddings take into account the contextual meaning of sentences when assessing their similarity, making them excellent choices for evaluating our models.
#
# To expedite the evaluation process, a stopping criterion has been used. If, in the last 20 iterations of the for loop calculating the mean score, the mean does not change significantly, the execution stops, and the score is printed.
#
# Additionally, the model has been evaluated for execution time in answering questions.

# %%
index = 300
#@title Manual testing
real_answer = test_dataset[index]["output"]
generated_answer = generate_answer(test_dataset[index]["input"])
question = test_dataset[index]["input"]

print("Question: ", question)
print("Generated answer: ", generated_answer)
print("Real answer: ", real_answer)
# Out:
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# Question:  What does it mean if the relative risk is less than 1 in relation to exposure and disease occurrence?
# Generated answer:  If the relative risk is less than 1, it means that there is a decreased likelihood of disease occurrence associated with exposure
# Real answer:  If the relative risk is less than 1, it means that exposure to a particular factor or variable is associated with a decreased occurrence of the disease in question. In other words, individuals who are exposed to the factor or variable are less likely to develop the disease than those who are not exposed. The relative risk is a measure of the strength of the association between exposure and disease occurrence, and a value less than 1 indicates a negative association.

# %% [markdown]
# ###BioSentVec loading...

# %%
if TEST_MODEL:
  model_path = f'{DATAS_PATH}/BioSentVec_PubMed_MIMICIII-bigram_d700.bin'
  testing_model = sent2vec.Sent2vecModel()

# %%
if TEST_MODEL:
  def evaluate_answer(real, predicted):
    sentence_vector1 = testing_model.embed_sentence(preprocess_sentence(real))
    sentence_vector2 = testing_model.embed_sentence(preprocess_sentence(predicted))
    cosine_sim = 1 - distance.cosine(sentence_vector1[0], sentence_vector2[0])
    return cosine_sim

# %%
if TEST_MODEL:
  try:
      testing_model.load_model(model_path)
  except Exception as e:
      print(e)
  print('model successfully loaded')
# Out:
# model successfully loaded

# %% [markdown]
# ###BioSentVec score

# %%
if TEST_MODEL:
  sum = 0
  n_try = 0
  mean_list = []
  patience = 20
  k = 0
  for i in range(len(test_dataset)):
    real_answer = test_dataset[i]["output"]
    question = test_dataset[i]["input"]
    generated_answer = generate_answer(question)
    if (generated_answer) is not None and (real_answer) is not None:
      score = evaluate_answer(real_answer, generated_answer)
      if i == 0:
        mean = score
      sum += score
      n_try += 1
      old_mean = mean
      mean = sum/n_try
      mean_list.append(mean)

      if abs(mean - old_mean) < 0.001:
        k += 1
        if k == patience:
          print(f'Early stopping at iteration: {i}')
          break
      else:
        k=0
      print(f'Iteration: {i}, Mean: {mean} \nLast relevant mean change is {k} iteration ago\n\n')
# Out:
# Iteration: 0, Mean: 0.7927179932594299
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 1, Mean: 0.8654806911945343
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 2, Mean: 0.8859667380650839
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 3, Mean: 0.8677131235599518
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 4, Mean: 0.8876337885856629
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 5, Mean: 0.8856092095375061
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 6, Mean: 0.8649208460535321
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 7, Mean: 0.8806175142526627
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 8, Mean: 0.8938822348912557
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 9, Mean: 0.8949684739112854
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 10, Mean: 0.8937800093130632
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 11, Mean: 0.869612788160642
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 12, Mean: 0.854552264396961
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 13, Mean: 0.8523419882569995
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 14, Mean: 0.8552656610806783
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 15, Mean: 0.8460257165133953
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 16, Mean: 0.8356186361873851
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 17, Mean: 0.8281274172994826
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 18, Mean: 0.8324384626589323
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 19, Mean: 0.828235787153244
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 20, Mean: 0.8344064496812367
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 21, Mean: 0.8390252535993402
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 22, Mean: 0.8396979026172472
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 23, Mean: 0.8463771566748619
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 24, Mean: 0.8465062975883484
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 25, Mean: 0.8478278953295487
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 26, Mean: 0.8338030554630138
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 27, Mean: 0.8266715705394745
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 28, Mean: 0.827861580355414
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 29, Mean: 0.8316682974497477
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 30, Mean: 0.8227162072735448
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 31, Mean: 0.816696036607027
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 32, Mean: 0.8194326975128867
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 33, Mean: 0.8214921986355501
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 34, Mean: 0.8248854194368634
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 35, Mean: 0.8251072648498747
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 36, Mean: 0.8282146083342062
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 37, Mean: 0.8235599335871244
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 38, Mean: 0.8161219251461518
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 39, Mean: 0.8132017180323601
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 40, Mean: 0.8083726283980579
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 41, Mean: 0.8075531834647769
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 42, Mean: 0.8104540816573209
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 43, Mean: 0.8130938451398503
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 44, Mean: 0.8151356246736314
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 45, Mean: 0.8177084689554961
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 46, Mean: 0.8166892820216239
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 47, Mean: 0.8188487713535627
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 48, Mean: 0.8175573312506383
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 49, Mean: 0.8152286565303802
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 50, Mean: 0.8179880906553829
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 51, Mean: 0.8174103670395337
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 52, Mean: 0.8121078992789647
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 53, Mean: 0.8109792702727847
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 54, Mean: 0.8134810675274242
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 55, Mean: 0.8147017434239388
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 56, Mean: 0.8102967111687911
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 57, Mean: 0.8095226041201887
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 58, Mean: 0.8088359135692402
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 59, Mean: 0.8094517737627029
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 60, Mean: 0.812370059920139
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 61, Mean: 0.8124915592132076
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 62, Mean: 0.8127828779674712
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 63, Mean: 0.8131664572283626
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 64, Mean: 0.8123714584570665
# Last relevant mean change is 4 iteration ago
#
#
# Iteration: 65, Mean: 0.8125580124782793
# Last relevant mean change is 5 iteration ago
#
#
# Iteration: 66, Mean: 0.8124301593695114
# Last relevant mean change is 6 iteration ago
#
#
# Iteration: 67, Mean: 0.8118214668596492
# Last relevant mean change is 7 iteration ago
#
#
# Iteration: 68, Mean: 0.8127139297084532
# Last relevant mean change is 8 iteration ago
#
#
# Iteration: 69, Mean: 0.8117433071136475
# Last relevant mean change is 9 iteration ago
#
#
# Iteration: 70, Mean: 0.8141319869269787
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 72, Mean: 0.8146878066990111
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 73, Mean: 0.8135877896661627
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 74, Mean: 0.8104115805110416
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 75, Mean: 0.8089149085680644
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 76, Mean: 0.8056676081920925
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 77, Mean: 0.8050200513431004
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 78, Mean: 0.8064267451946552
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 79, Mean: 0.806470197212847
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 80, Mean: 0.8062575332820415
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 81, Mean: 0.8067371514108446
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 82, Mean: 0.8058067567464782
# Last relevant mean change is 4 iteration ago
#
#
# Iteration: 83, Mean: 0.8028195306479212
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 84, Mean: 0.8036823485578809
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 85, Mean: 0.8032649916761062
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 86, Mean: 0.8040589773377707
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 87, Mean: 0.8025010933821228
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 88, Mean: 0.8031599176200953
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 89, Mean: 0.8048857082141919
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 90, Mean: 0.8059706416394975
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 91, Mean: 0.8070395700224153
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 92, Mean: 0.8074021015478217
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 93, Mean: 0.8073160706027862
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 94, Mean: 0.8076448174233132
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 95, Mean: 0.8081182950421384
# Last relevant mean change is 4 iteration ago
#
#
# Iteration: 96, Mean: 0.8088978851834933
# Last relevant mean change is 5 iteration ago
#
#
# Iteration: 97, Mean: 0.8095008343765416
# Last relevant mean change is 6 iteration ago
#
#
# Iteration: 98, Mean: 0.8063288160732814
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 99, Mean: 0.8061807468684032
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 100, Mean: 0.807351393699646
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 101, Mean: 0.8081347895140695
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 102, Mean: 0.8099783512891507
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 103, Mean: 0.8102110433347017
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 104, Mean: 0.8104579248107396
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 105, Mean: 0.8106806425821214
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 106, Mean: 0.8116966772754237
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 107, Mean: 0.811817405936874
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 108, Mean: 0.8126545907170685
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 109, Mean: 0.8132292606415005
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 110, Mean: 0.8133011422374031
# Last relevant mean change is 4 iteration ago
#
#
# Iteration: 111, Mean: 0.8118012998555157
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 112, Mean: 0.8120226428977081
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 113, Mean: 0.812441642832967
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 114, Mean: 0.8121693108165473
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 115, Mean: 0.8125041935754859
# Last relevant mean change is 4 iteration ago
#
#
# Iteration: 116, Mean: 0.8127419871502909
# Last relevant mean change is 5 iteration ago
#
#
# Iteration: 117, Mean: 0.8136197012713832
# Last relevant mean change is 6 iteration ago
#
#
# Iteration: 118, Mean: 0.8131034707618972
# Last relevant mean change is 7 iteration ago
#
#
# Iteration: 119, Mean: 0.8127966267721993
# Last relevant mean change is 8 iteration ago
#
#
# Iteration: 120, Mean: 0.8140687137842179
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 121, Mean: 0.8144932753783612
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 122, Mean: 0.8133562471045822
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 123, Mean: 0.8137421210606893
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 124, Mean: 0.8146180034645142
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 125, Mean: 0.8128167572021484
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 126, Mean: 0.8138405193412115
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 127, Mean: 0.8153063420235641
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 128, Mean: 0.8156693931668997
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 129, Mean: 0.815868756567785
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 130, Mean: 0.8155600488185882
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 131, Mean: 0.8157671453388593
# Last relevant mean change is 4 iteration ago
#
#
# Iteration: 132, Mean: 0.8163361003001531
# Last relevant mean change is 5 iteration ago
#
#
# Iteration: 133, Mean: 0.8160025289184168
# Last relevant mean change is 6 iteration ago
#
#
# Iteration: 134, Mean: 0.815736303133751
# Last relevant mean change is 7 iteration ago
#
#
# Iteration: 135, Mean: 0.8163599107000563
# Last relevant mean change is 8 iteration ago
#
#
# Iteration: 136, Mean: 0.816816764719346
# Last relevant mean change is 9 iteration ago
#
#
# Iteration: 137, Mean: 0.8165555757327672
# Last relevant mean change is 10 iteration ago
#
#
# Iteration: 138, Mean: 0.8167808319347493
# Last relevant mean change is 11 iteration ago
#
#
# Iteration: 139, Mean: 0.8159231530676643
# Last relevant mean change is 12 iteration ago
#
#
# Iteration: 140, Mean: 0.8149244938577924
# Last relevant mean change is 13 iteration ago
#
#
# Iteration: 141, Mean: 0.8153678225287309
# Last relevant mean change is 14 iteration ago
#
#
# Iteration: 142, Mean: 0.8149421454315454
# Last relevant mean change is 15 iteration ago
#
#
# Iteration: 143, Mean: 0.8156636740777876
# Last relevant mean change is 16 iteration ago
#
#
# Iteration: 144, Mean: 0.8145984651313888
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 145, Mean: 0.8146332568135755
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 146, Mean: 0.8159028920408797
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 147, Mean: 0.8171552533195132
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 148, Mean: 0.8167786038405186
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 149, Mean: 0.8170103506753909
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 150, Mean: 0.8166334847609202
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 151, Mean: 0.8165764291554887
# Last relevant mean change is 4 iteration ago
#
#
# Iteration: 152, Mean: 0.8171589743149908
# Last relevant mean change is 5 iteration ago
#
#
# Iteration: 153, Mean: 0.8171802042356504
# Last relevant mean change is 6 iteration ago
#
#
# Iteration: 154, Mean: 0.8175885956008713
# Last relevant mean change is 7 iteration ago
#
#
# Iteration: 155, Mean: 0.8176852791540085
# Last relevant mean change is 8 iteration ago
#
#
# Iteration: 156, Mean: 0.8188539632619956
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 157, Mean: 0.8181984933318606
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 158, Mean: 0.8188484016853043
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 159, Mean: 0.8179567831117402
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 160, Mean: 0.8189775764942169
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 161, Mean: 0.8184914207606582
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 162, Mean: 0.8190953731536865
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 163, Mean: 0.8192314955354468
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 164, Mean: 0.819302441870294
# Last relevant mean change is 4 iteration ago
#
#
# Iteration: 165, Mean: 0.8187508543332418
# Last relevant mean change is 5 iteration ago
#
#
# Iteration: 166, Mean: 0.8182028941361301
# Last relevant mean change is 6 iteration ago
#
#
# Iteration: 167, Mean: 0.8180962833101878
# Last relevant mean change is 7 iteration ago
#
#
# Iteration: 168, Mean: 0.8184483466403825
# Last relevant mean change is 8 iteration ago
#
#
# Iteration: 169, Mean: 0.8178623015358604
# Last relevant mean change is 9 iteration ago
#
#
# Iteration: 170, Mean: 0.8181384451249066
# Last relevant mean change is 10 iteration ago
#
#
# Iteration: 171, Mean: 0.8180730004756771
# Last relevant mean change is 11 iteration ago
#
#
# Iteration: 172, Mean: 0.8184607122526613
# Last relevant mean change is 12 iteration ago
#
#
# Iteration: 173, Mean: 0.818812416123517
# Last relevant mean change is 13 iteration ago
#
#
# Iteration: 174, Mean: 0.8183133739164505
# Last relevant mean change is 14 iteration ago
#
#
# Iteration: 175, Mean: 0.8188371787752424
# Last relevant mean change is 15 iteration ago
#
#
# Iteration: 176, Mean: 0.818956387991255
# Last relevant mean change is 16 iteration ago
#
#
# Iteration: 177, Mean: 0.8189344251223203
# Last relevant mean change is 17 iteration ago
#
#
# Iteration: 178, Mean: 0.8197855872384617
# Last relevant mean change is 18 iteration ago
#
#
# Iteration: 179, Mean: 0.8204553460275661
# Last relevant mean change is 19 iteration ago
#
#
# Early stopping at iteration: 180

# %%
if TEST_MODEL:
  plt.plot(mean_list, label='cosine similiarity')
  plt.ylabel('Mean cosine similiarity')
  plt.xlabel('Iteration')
  plt.title("Mean cosine similarity per iteartion")
  plt.legend()
  plt.show()

# %%
if TEST_MODEL:
  print(f'The average cosine similarity is: {mean}')
# Out:
# The average cosine similarity is: 0.8204276525312

# %% [markdown]
# ###BERTScore

# %%
# Initialize the BERTScorer object
if TEST_MODEL:
  scorer = BERTScorer(lang='en')

# %%
if TEST_MODEL:
  sum = [0, 0, 0]
  n_try = 0
  mean_score_list = []
  patience = 20
  k = 0
  for i in range(len(test_dataset)):
    real_answer = test_dataset[i]["output"]
    question = test_dataset[i]["input"]

    generated_answer = generate_answer(question)
    if (generated_answer) is not None and (real_answer) is not None:
      P, R, F1 = scorer.score([generated_answer], [real_answer])
      score = [float(P), float(R), float(F1)]
      if i == 0:
        mean_score = score
      sum = [x + y for x, y in zip(sum, score)]
      n_try += 1
      old_mean = mean_score
      mean_score = [(x / n_try) for x in sum]
      mean_score_list.append(mean_score)

      if abs(mean_score[0] - old_mean[0]) < 0.001 and abs(mean_score[1] - old_mean[1]) < 0.001 and abs(mean_score[2] - old_mean[2]) < 0.001:
        k += 1
        if k == patience:
          print(f'Early stopping at iteration: {i}')
          break
      else:
        k=0
      print(f'Iteration: {i}, Mean: {mean_score} \nLast relevant mean change is {k} iteration ago\n\n')
# Out:
# Iteration: 0, Mean: [0.8940554857254028, 0.8719024062156677, 0.8828400373458862]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 1, Mean: [0.9268993139266968, 0.9110515415668488, 0.9188940525054932]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 2, Mean: [0.919126053651174, 0.9066096742947897, 0.9128104249636332]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 3, Mean: [0.9056114703416824, 0.9179505109786987, 0.9112183600664139]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 4, Mean: [0.9147365093231201, 0.9298979043960571, 0.9218308329582214]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 5, Mean: [0.9158051609992981, 0.9368893702824911, 0.9258288045724233]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 6, Mean: [0.9202536855425153, 0.9235743454524449, 0.9210442815508161]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 7, Mean: [0.929399847984314, 0.9317616894841194, 0.9298191592097282]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 8, Mean: [0.9363544715775384, 0.9370031754175822, 0.9359970291455587]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 9, Mean: [0.9392560184001922, 0.9398458421230316, 0.9389373183250427]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 10, Mean: [0.9417803666808389, 0.9424359419129111, 0.9415502873334017]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 11, Mean: [0.9406281510988871, 0.9428942749897639, 0.9412409663200378]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 12, Mean: [0.9321214694243211, 0.9404213749445401, 0.9356472859015832]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 13, Mean: [0.9313033393451146, 0.9391292801925114, 0.9346366993018559]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 14, Mean: [0.9303218046824138, 0.936992633342743, 0.9331146001815795]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 15, Mean: [0.92993950471282, 0.9309263527393341, 0.9297984205186367]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 16, Mean: [0.9309736174695632, 0.926910442464492, 0.9282278278294731]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 17, Mean: [0.9265787568357255, 0.9252366026242574, 0.9252011113696628]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 18, Mean: [0.9287806341522619, 0.9270247283734774, 0.9272321462631226]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 19, Mean: [0.9292819857597351, 0.92331503033638, 0.925558352470398]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 20, Mean: [0.9316690450622922, 0.926030749366397, 0.9281449772062755]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 21, Mean: [0.9334836981513284, 0.928513147614219, 0.9303245896642859]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 22, Mean: [0.9319639076357302, 0.9273340805717136, 0.9290043582086978]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 23, Mean: [0.9345134869217873, 0.929961177210013, 0.9316194752852122]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 24, Mean: [0.9338040804862976, 0.9299326348304748, 0.9312735295295715]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 25, Mean: [0.9330300986766815, 0.9287397471758035, 0.9303106619761541]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 26, Mean: [0.9305809802479215, 0.9268561712017765, 0.9281643055103443]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 27, Mean: [0.930032593863351, 0.9228448761360986, 0.9257996018443789]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 28, Mean: [0.9319087513561907, 0.9241687244382398, 0.9274168733892769]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 29, Mean: [0.9336818099021912, 0.9246209104855855, 0.9285307784875234]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 30, Mean: [0.9326155358745206, 0.9249561505932962, 0.9281748917794996]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 31, Mean: [0.9330647066235542, 0.9220871087163687, 0.9268702901899815]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 32, Mean: [0.9338094971396707, 0.9217382308208582, 0.9270716598539641]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 33, Mean: [0.9342857844689313, 0.9230930454590741, 0.9280054341344273]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 34, Mean: [0.9339347055980137, 0.9220932773181371, 0.9273404853684561]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 35, Mean: [0.9338852084345288, 0.9220414641830657, 0.927307473288642]
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 36, Mean: [0.9354839276623081, 0.9237589046761796, 0.9289829006066194]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 37, Mean: [0.9330713435223228, 0.9217469802028254, 0.9267873528756594]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 38, Mean: [0.9317390872881963, 0.9200216562320025, 0.9252692583279732]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 39, Mean: [0.9317630544304848, 0.917719304561615, 0.9240674123167991]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 40, Mean: [0.9303258323087925, 0.9158511030964736, 0.9224239791311869]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 41, Mean: [0.9310091208843958, 0.9140196343262991, 0.9217702136153266]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 42, Mean: [0.9314043757527374, 0.9150773661081181, 0.9225132077239281]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 43, Mean: [0.93117225847461, 0.915045590563254, 0.9223974496126175]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 44, Mean: [0.9305284142494201, 0.9147564331690471, 0.9219467586941189]
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 45, Mean: [0.9316795014816782, 0.9162743065668189, 0.9232963556828706]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 46, Mean: [0.9298711254241618, 0.9159974899697811, 0.9222487794592026]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 47, Mean: [0.9309264992674192, 0.9171605482697487, 0.9233718725542227]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 48, Mean: [0.930633510862078, 0.9160957847322736, 0.922691463207712]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 49, Mean: [0.9302657091617584, 0.9155178475379944, 0.9222285723686219]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 50, Mean: [0.9306536947979647, 0.9153935769025017, 0.9223646252763038]
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 51, Mean: [0.930536727492626, 0.9138083778894864, 0.92148030262727]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 52, Mean: [0.9282651611094205, 0.913753295844456, 0.9202744038599842]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 53, Mean: [0.9272673372869138, 0.9131978463243555, 0.9195109120121708]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 54, Mean: [0.9279955928975886, 0.9142322215166959, 0.9204053131016818]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 55, Mean: [0.928172342479229, 0.9140133282967976, 0.9203906325357301]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 56, Mean: [0.9287260979936834, 0.9144591469513742, 0.9209008342341373]
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 57, Mean: [0.9276541985314468, 0.9147617210601938, 0.920507564626891]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 58, Mean: [0.9270479860952345, 0.9135851344819796, 0.9196174680176428]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 59, Mean: [0.9274781326452891, 0.913032145301501, 0.9195438375075659]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 60, Mean: [0.9284480966505457, 0.9143422285064322, 0.920695357635373]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 61, Mean: [0.9278671779940205, 0.9137943858100522, 0.9201416027161383]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 62, Mean: [0.9277259660145593, 0.9141397608651055, 0.9202534461778308]
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 63, Mean: [0.9285422554239631, 0.9150696657598019, 0.921136999502778]
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 64, Mean: [0.9280371711804316, 0.9147254540370061, 0.9207226037979126]
# Last relevant mean change is 4 iteration ago
#
#
# Iteration: 65, Mean: [0.927993812344291, 0.913554310798645, 0.9200922422336809]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 66, Mean: [0.9283137588358638, 0.914450417703657, 0.920708179473877]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 67, Mean: [0.9285354456480812, 0.9133958763935986, 0.9202599621870938]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 68, Mean: [0.927741527557373, 0.9138918000718822, 0.9200994890669117]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 69, Mean: [0.9282155564853123, 0.9128984280994961, 0.9197962999343872]
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 70, Mean: [0.9290228721121667, 0.9137555251658802, 0.9206387215936688]
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 72, Mean: [0.9284089033802351, 0.9144624405437045, 0.9206716848744286]
# Last relevant mean change is 4 iteration ago
#
#
# Iteration: 73, Mean: [0.9273203211287929, 0.9147143437437815, 0.9202367459257988]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 74, Mean: [0.9259425288922077, 0.9143940927209081, 0.9193813051726367]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 75, Mean: [0.9260021845499674, 0.9148618817329407, 0.9196542326609294]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 76, Mean: [0.9256140064252051, 0.9134145347695601, 0.9187142331349222]
# Last relevant mean change is 0 iteration ago
#
#
# Iteration: 77, Mean: [0.925051288171248, 0.9130939214260547, 0.9182828045510626]
# Last relevant mean change is 1 iteration ago
#
#
# Iteration: 78, Mean: [0.9250090213922354, 0.9129282113833305, 0.9181873026566628]
# Last relevant mean change is 2 iteration ago
#
#
# Iteration: 79, Mean: [0.9246827130076252, 0.9125412793099126, 0.917839561836629]
# Last relevant mean change is 3 iteration ago
#
#
# Iteration: 80, Mean: [0.9242539830505848, 0.912410880625248, 0.9175691731274128]
# Last relevant mean change is 4 iteration ago
#
#
# Iteration: 81, Mean: [0.9236784886430811, 0.9120707990210734, 0.9171206259433135]
# Last relevant mean change is 5 iteration ago
#
#
# Iteration: 82, Mean: [0.9228000764439745, 0.9119868692828388, 0.9166387014272737]
# Last relevant mean change is 6 iteration ago
#
#
# Iteration: 83, Mean: [0.9219288869076464, 0.9117087405848215, 0.9160680268184248]
# Last relevant mean change is 7 iteration ago
#
#
# Iteration: 84, Mean: [0.9225713866097587, 0.9121357663756325, 0.9166092453967958]
# Last relevant mean change is 8 iteration ago
#
#
# Iteration: 85, Mean: [0.9224661897210514, 0.9119590647080366, 0.9164761669495527]
# Last relevant mean change is 9 iteration ago
#
#
# Iteration: 86, Mean: [0.9231421365294346, 0.9127749627412751, 0.9172306455845056]
# Last relevant mean change is 10 iteration ago
#
#
# Iteration: 87, Mean: [0.9231317646202, 0.9125148523813007, 0.9171005048971067]
# Last relevant mean change is 11 iteration ago
#
#
# Iteration: 88, Mean: [0.9228090549057181, 0.9120947115800597, 0.9167361110448837]
# Last relevant mean change is 12 iteration ago
#
#
# Iteration: 89, Mean: [0.9234022357490625, 0.9129368769988585, 0.9174614515197411]
# Last relevant mean change is 13 iteration ago
#
#
# Iteration: 90, Mean: [0.9235757814513312, 0.9127302732732561, 0.917446741130617]
# Last relevant mean change is 14 iteration ago
#
#
# Iteration: 91, Mean: [0.9236521170689509, 0.9127465231078011, 0.9175000026985839]
# Last relevant mean change is 15 iteration ago
#
#
# Iteration: 92, Mean: [0.9240260765604351, 0.9131752660740977, 0.9179088570501494]
# Last relevant mean change is 16 iteration ago
#
#
# Iteration: 93, Mean: [0.9236825345664896, 0.9127333202669697, 0.9175223323606676]
# Last relevant mean change is 17 iteration ago
#
#
# Iteration: 94, Mean: [0.9241638437230536, 0.9132421327398178, 0.9180244942928882]
# Last relevant mean change is 18 iteration ago
#
#
# Iteration: 95, Mean: [0.9247621718205904, 0.9136562472895572, 0.9185356585603012]
# Last relevant mean change is 19 iteration ago
#
#
# Early stopping at iteration: 96

# %%
if TEST_MODEL:
  plt.plot([score[0] for score in mean_score_list], color='#2ca02c',label='Precision')
  plt.plot([score[1] for score in mean_score_list], color='#d62728',label='Recall')
  plt.plot([score[2] for score in mean_score_list],label='F1 score')

  plt.ylabel('Mean scores')
  plt.xlabel('Iteration')
  plt.title("Mean scores  per iteartion")
  plt.legend()
  plt.show()

# %%
if TEST_MODEL:
  print("Precision: ", mean_score[0])
  print("Recall: ", mean_score[1])
  print("F1 score: ", mean_score[2])
# Out:
# Precision:  0.9244503360241652
# Recall:  0.9133013846973578
# F1 score:  0.9182086444149414

# %% [markdown]
# ###Execution time

# %%
if TEST_MODEL:
  sum = 0
  n_try = 0
  mean_time_list = []
  patience = 20
  k = 0
  for i in tqdm(range(200)):
    question = test_dataset[i]["input"]

    start = time.time()
    generated_answer = generate_answer(question)
    end = time.time()

    score_time = end-start
    if i == 0:
      mean_time = score_time
    sum += score_time
    n_try += 1
    old_mean_time = mean_time
    mean_time = sum/n_try
    mean_time_list.append(mean_time)
# Out:
# 100%|██████████| 200/200 [15:23<00:00,  4.62s/it]

# %%
plt.plot(mean_time_list)
plt.plot([mean_time for i in mean_time_list], '--', color='blue', label='Mean execution time', linewidth=1)
plt.ylabel('Mean execution time')
plt.xlabel('Iteration')
plt.title("Mean execution time per iteartion")
plt.legend()
plt.show()

# %%
if TEST_MODEL:
  print(f'The average execution time is: {mean_time}')
# Out:
# The average execution time is: 4.613840124607086

# %% [markdown]
# ## Saving
# To save the final model as LoRA adapters, either use Huggingface's `push_to_hub` for an online save or `save_pretrained` for a local save.

# %%
if not USE_PRETRAINED:
  model.save_pretrained("lora_model") # Local saving
  tokenizer.save_pretrained("lora_model")
# Out:
# loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--unsloth--mistral-7b-v0.3-bnb-4bit/snapshots/b462f9510e81ce70c5c45010e4cd89c464829363/config.json
# Model config MistralConfig {
#   "_name_or_path": "mistralai/Mistral-7B-v0.3",
#   "architectures": [
#     "MistralForCausalLM"
#   ],
#   "attention_dropout": 0.0,
#   "bos_token_id": 1,
#   "eos_token_id": 2,
#   "hidden_act": "silu",
#   "hidden_size": 4096,
#   "initializer_range": 0.02,
#   "intermediate_size": 14336,
#   "max_position_embeddings": 32768,
#   "model_type": "mistral",
#   "num_attention_heads": 32,
#   "num_hidden_layers": 32,
#   "num_key_value_heads": 8,
#   "pad_token_id": 770,
#   "quantization_config": {
#     "_load_in_4bit": true,
#     "_load_in_8bit": false,
#     "bnb_4bit_compute_dtype": "bfloat16",
#     "bnb_4bit_quant_storage": "uint8",
#     "bnb_4bit_quant_type": "nf4",
#     "bnb_4bit_use_double_quant": true,
#     "llm_int8_enable_fp32_cpu_offload": false,
#     "llm_int8_has_fp16_weight": false,
#     "llm_int8_skip_modules": null,
#     "llm_int8_threshold": 6.0,
#     "load_in_4bit": true,
#     "load_in_8bit": false,
#     "quant_method": "bitsandbytes"
#   },
#   "rms_norm_eps": 1e-05,
#   "rope_theta": 1000000.0,
#   "sliding_window": null,
#   "tie_word_embeddings": false,
#   "torch_dtype": "bfloat16",
#   "transformers_version": "4.41.0",
#   "use_cache": true,
#   "vocab_size": 32768
# }
#
# tokenizer config file saved in lora_model/tokenizer_config.json
# Special tokens file saved in lora_model/special_tokens_map.json

# %% [markdown]
# ##GGUF / llama.cpp Conversion
# Use `save_pretrained_gguf` for local saving and `push_to_hub_gguf` for uploading to HF.
#
# Some supported quant methods:
# * `q8_0` - Fast conversion. High resource use, but generally acceptable.
# * `q4_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q4_K.
# * `q5_k_m` - Recommended. Uses Q6_K for half of the attention.wv and feed_forward.w2 tensors, else Q5_K.

# %%
if EXPORT_MODEL:
  # Save to 8bit Q8_0
  if False: model.save_pretrained_gguf("model", tokenizer,)
  if False: model.push_to_hub_gguf("hf/model", tokenizer, token = "")

  # Save to 16bit GGUF
  if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "f16")
  if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "f16", token = "")

  # Save to q4_k_m GGUF
  if False: model.save_pretrained_gguf("model", tokenizer, quantization_method = "q4_k_m")
  if False: model.push_to_hub_gguf("hf/model", tokenizer, quantization_method = "q4_k_m", token = "")
