# %% [markdown]
# # Context Retrival Introduction

# %% [markdown]
# **Introduction to Contextual Question Answering**
#
# In the development of question-answering systems, having a context for each question is often crucial. Typically, models are trained to understand and retrieve answers within a given context. However, our dataset contains only question and answers without any additional context. This presents a unique challenge: how can we train an effective question-answering model without inherent contextual information ?
#
# **Importance of Context**
#
# Context is often vital because it provides the backgrounf information needed for understanding and accurately answering. Without context, the model may struggle to comprehend the nuances and specifics of the questions, leasinf to lower accuracy and reliablity
#
# **Challenges without context**
#
#
#
# 1.   **Ambiguity**: question cab be ambiguous without context
# 2.   **Relevance**: without context, it is challenging to determine which information is relevant to the question
# 3.   **Depth of understanding**: context allows the model to provide more comprehensive and detailed answers
#
# **Proposed Solutions**
#
#
# **Using External Sources for Context Retrieval**:
#
#  To address the absence of context in our dataset, we propose a method that involves retrieving relevant context from external sources, specifically leveraging the PubMed API to access medical and biomedical papers and their abstracts. Here's an overview of our approach:
#
#
#  -  **Keyword Extraction**: for each question, we employ keyBERT, a pre-trained mdoel, to extract a set of keywords that capture the essence of the question. These keywords serve as the query terms for retrieving relevant papers and their contexts
#
#  - **Context Retrival**: using the extracted keywords as queries, we utilize the PubMedAPI to search through a vast repository of medical literature. This step aims to retrieve potential contexts from papers and their abstracts, ensuring that the context is domain-specific and directly relevant to the question at hand
#
#  - **Preprocessing and Cleaning**: the retrieved contexts undergo preprocessing and cleaning to ensure they are in the appropriate format for futher analysis. This preprocessing involves removing irrelevant information, normalizing text, and ensuring consistency across retrieved contexts.
#
#  - **Context Ranking**: to prioritize the retrieved contexts, we employ various ranking techniques:
#
#     - **TF-IDF and BM25 Index Search**: These methods assess the importance of terms based on their frequencies within the retrieved contexts and the question itself. This allows us to build a document search engine that matches contexts to a given query (question).
#
#     - **Document vectorization**: utilizing a TD-IDF vectorizer, we compute the textual documents into numerical vectors based on the relevancy of the words and how often they appear in the documents, enabling quantitative comparison.
#
#     - **Sentence Embedding and Cosine Similarity**: We compute sentence embeddings for both the question and the retrieved contexts, then evaluate the cosine similarities between them to obtain similarity scores. This process allows us to rank the contexts based on their relevance to the question. Unlike the previous methods that only consider term frequency, this approach captures the semantic meaning and relationships between words within the sentences.
#
# The last method indeed yielded the best results, as it effectively maintains the semantic relationships between words. This capability enchances the matching process, enabling a more accurate alignment of the question with the context. By considering not only the frequency of terms but also their semantic meaning, this methos provides a more  nuanced understanding of the relationship between the question and the retrieved contexts. This ensures that the generated responses are not only relevant in terms of topic but also in terms of undrlying semantic context, resulting in more precise and informative answers
#
#
#
# 2.  **Fine-Tuning Pre-Trained Models**
# Another solution is to leverage pre-trained models and fine-tune them for our question-answering task. This approach takes advantage of the vast knowledge these models have already acquired during their training
#
#
# 3. **Leveraging Open-Domain Pre-Trained Models**
# In addition to domain-specific models, we can also consider open-domain pre-trained models. Literature shows that models trained on vast, open-domain knowledge have performed well on question-answering tasks after fine-tuning.
#
# **Our Work**
#
# In the forthcoming notebook, we will delve into the process of retrieving external context for each question in our dataset. This endeavor will empower us to construct a comprehensive context for every question, a crucial asset in training models that rely on contextual information for optimal performance.

# %% [markdown]
# ## Import and Install

# %% [markdown]
# Let's install some useful libraries

# %%
# !pip install -q python-terrier
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 110.7/110.7 kB 1.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 11.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.6/69.6 kB 7.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 337.9/337.9 kB 10.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.8/48.8 kB 3.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 9.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.4/287.4 kB 8.7 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.1/45.1 kB 2.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.4/45.4 kB 1.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 13.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 111.8/111.8 kB 14.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Preparing metadata (setup.py) ... done
#   Building wheel for python-terrier (setup.py) ... done
#   Building wheel for ir_measures (setup.py) ... done
#   Building wheel for chest (setup.py) ... done
#   Building wheel for wget (setup.py) ... done
#   Building wheel for cwl-eval (setup.py) ... done
#   Building wheel for warc3-wet-clueweb09 (setup.py) ... done
#   Building wheel for zlib-state (pyproject.toml) ... done
#   Building wheel for cbor (setup.py) ... done

# %%
# !pip install datasets
# Out:
# Collecting datasets
#   Downloading datasets-2.19.1-py3-none-any.whl (542 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 542.0/542.0 kB 6.5 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from datasets) (3.14.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from datasets) (1.25.2)
# Requirement already satisfied: pyarrow>=12.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (14.0.2)
# Requirement already satisfied: pyarrow-hotfix in /usr/local/lib/python3.10/dist-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (2.0.3)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (4.66.4)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 8.5 MB/s eta 0:00:00
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.16-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 9.5 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2024.3.1,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.5)
# Requirement already satisfied: huggingface-hub>=0.21.2 in /usr/local/lib/python3.10/dist-packages (from datasets) (0.23.1)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from datasets) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from datasets) (6.0.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.21.2->datasets) (4.11.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.4)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# Installing collected packages: xxhash, multiprocess, datasets
# Successfully installed datasets-2.19.1 multiprocess-0.70.16 xxhash-3.4.1

# %%
# !pip install biopython
# Out:
# Collecting biopython
#   Downloading biopython-1.83-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 13.2 MB/s eta 0:00:00
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from biopython) (1.25.2)
# Installing collected packages: biopython
# Successfully installed biopython-1.83

# %%
# !pip install keybert
# Out:
# Collecting keybert
#   Downloading keybert-0.8.4.tar.gz (29 kB)
#   Preparing metadata (setup.py) ... done
# Collecting sentence-transformers>=0.3.8 (from keybert)
#   Downloading sentence_transformers-2.7.0-py3-none-any.whl (171 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 171.5/171.5 kB 4.7 MB/s eta 0:00:00
# Requirement already satisfied: scikit-learn>=0.22.2 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.2.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from keybert) (1.25.2)
# Requirement already satisfied: rich>=10.4.0 in /usr/local/lib/python3.10/dist-packages (from keybert) (13.7.1)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=10.4.0->keybert) (2.16.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.11.4)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn>=0.22.2->keybert) (3.5.0)
# Requirement already satisfied: transformers<5.0.0,>=4.34.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.41.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (4.66.4)
# Requirement already satisfied: torch>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (2.3.0+cu121)
# Requirement already satisfied: huggingface-hub>=0.15.1 in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (0.23.1)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (from sentence-transformers>=0.3.8->keybert) (9.4.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (3.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (2023.6.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (24.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (2.31.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (4.11.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=10.4.0->keybert) (0.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (3.1.4)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Requirement already satisfied: triton==2.3.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (2.3.0)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.11.0->sentence-transformers>=0.3.8->keybert)
#   Downloading nvidia_nvjitlink_cu12-12.5.40-py3-none-manylinux2014_x86_64.whl (21.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.3/21.3 MB 53.5 MB/s eta 0:00:00
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.3.8->keybert) (2023.12.25)
# Requirement already satisfied: tokenizers<0.20,>=0.19 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.3.8->keybert) (0.19.1)
# Requirement already satisfied: safetensors>=0.4.1 in /usr/local/lib/python3.10/dist-packages (from transformers<5.0.0,>=4.34.0->sentence-transformers>=0.3.8->keybert) (0.4.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (2.1.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub>=0.15.1->sentence-transformers>=0.3.8->keybert) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.3.8->keybert) (1.3.0)
# Building wheels for collected packages: keybert
#   Building wheel for keybert (setup.py) ... done
#   Created wheel for keybert: filename=keybert-0.8.4-py3-none-any.whl size=39200 sha256=1fd4e7e0ed304fd355867acdcb160c24cb9b5c6610a9f45182ae6563675a5f83
#   Stored in directory: /root/.cache/pip/wheels/97/ef/4c/6588bd7072b0cc04225b40e639b991e49ebd4e21fb81f0acee
# Successfully built keybert
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, sentence-transformers, keybert
# Successfully installed keybert-0.8.4 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.5.40 nvidia-nvtx-cu12-12.1.105 sentence-transformers-2.7.0

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.10/dist-packages (4.3.2)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.25.2)
# Requirement already satisfied: scipy>=1.7.0 in /usr/local/lib/python3.10/dist-packages (from gensim) (1.11.4)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.10/dist-packages (from gensim) (6.4.0)

# %%
# !git clone https://github.com/epfml/sent2vec.git
# %cd sent2vec
# !make
# !pip install .
# Out:
# Cloning into 'sent2vec'...
# remote: Enumerating objects: 425, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (20/20), done.
# remote: Total 425 (delta 9), reused 4 (delta 1), pack-reused 403
# Receiving objects: 100% (425/425), 447.46 KiB | 1.75 MiB/s, done.
# Resolving deltas: 100% (261/261), done.
# /content/sent2vec
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/args.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/dictionary.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/productquantizer.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/matrix.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/shmem_matrix.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/qmatrix.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/vector.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/model.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/utils.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops -c src/fasttext.cc
# c++ -pthread -std=c++0x -O3 -funroll-loops args.o dictionary.o productquantizer.o matrix.o shmem_matrix.o qmatrix.o vector.o model.o utils.o fasttext.o src/main.cc -o fasttext -lrt
# Processing /content/sent2vec
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: Cython>=0.29.13 in /usr/local/lib/python3.10/dist-packages (from sent2vec==0.0.0) (3.0.10)
# Requirement already satisfied: numpy>=1.17.1 in /usr/local/lib/python3.10/dist-packages (from sent2vec==0.0.0) (1.25.2)
# Building wheels for collected packages: sent2vec
#   Building wheel for sent2vec (pyproject.toml) ... done
#   Created wheel for sent2vec: filename=sent2vec-0.0.0-cp310-cp310-linux_x86_64.whl size=1630747 sha256=f5694d67436d90f60bd0d7b54fa80fcd8cdc5f111bf7b61a787910db0b798a44
#   Stored in directory: /tmp/pip-ephem-wheel-cache-aahrfvaq/wheels/c1/9d/a2/1965b1b523b356923efa34b6d037d0436acfc3cd6f81758e1c
# Successfully built sent2vec
# Installing collected packages: sent2vec
# Successfully installed sent2vec-0.0.0

# %% [markdown]
# Let's import some useful libraries

# %%
from google.colab import drive
import os

from datasets import load_dataset
import numpy as np
import pandas as pd
import csv

from collections import Counter

import matplotlib.pyplot as plt

import re
import string
from string import punctuation

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

import pyterrier as pt

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.metrics.pairwise import euclidean_distances

from keybert import KeyBERT

from gensim.models import Word2Vec
from gensim.models.doc2vec import Doc2Vec, TaggedDocument


from Bio import Entrez

from sentence_transformers import SentenceTransformer

import sent2vec

# %% [markdown]
# ## Setup

# %%
drive.mount('/content/drive')
os.chdir(f'/content/drive/MyDrive/Colab Notebooks/NLP/Assignment/datasets') #Teka's path
#os.chdir(f'/content/drive/MyDrive/Colab Notebooks/NLP/NLP Project/Datasets')# Alessandro's path
os.getcwd()
# Out:
# Mounted at /content/drive
# '/content/drive/MyDrive/Colab Notebooks/NLP/Assignment/datasets'

# %% [markdown]
# Variables designated as constants and flags are employed to selectively execute specific segments of the code.

# %%
HUGGINGFACE = False
SAVE_DATASET = True
SET_RANDOM_INDEX = False

# %% [markdown]
# Load models and packages

# %%
nltk.download('stopwords')
nltk.download('wordnet')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
kw_model = KeyBERT()
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_token.py:89: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.7k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
import pyterrier as pt
if not pt.started():
  pt.init()
# Out:
# terrier-assemblies 5.9 jar-with-dependencies not found, downloading to /root/.pyterrier...
# Done
# terrier-python-helper 0.0.8 jar not found, downloading to /root/.pyterrier...
# Done
# PyTerrier 0.10.1 has loaded Terrier 5.9 (built by craigm on 2024-05-02 17:40) and terrier-helper 0.0.8

# %% [markdown]
# ## Utils

# %% [markdown]
# The function **preprocess_document** is designed to process a given document, performing various optional text preprocessing steps based on the specified parameters. These parameters include:
#
# * isSorted: If set to True, the function sorts the processed document alphabetically.
# * isSet: If set to True, the function converts the processed document into a set, removing any duplicate elements.
# * noStopWords: If set to True, the function removes common English stopwords from the processed document.
# * lemmatization: If set to True, the function lemmatizes the words in the processed document using WordNet.
#
# The function begins by removing punctuation from the document using a regular expression. Then, depending on the parameters provided, it applies additional processing steps accordingly. Finally, it returns the processed document.

# %%
def preprocess_document(document,noPunctuation=False ,isSorted=False, isSet=False, noStopWords=False, lemmatization=False):
  newDocument = document
  if noPunctuation==True:
    regex = '[' + string.punctuation + ']'
    newDocument = [re.sub(regex,'',item) for item in newDocument]
  if isSet==True:
    newDocument = set(newDocument)
  if noStopWords==True:
    newDocument =  [w for w in newDocument if w not in stopwords.words('english')]
  if isSorted==True:
    newDocument = sorted(newDocument)
  if lemmatization==True:
    lemmatizer = WordNetLemmatizer()
    newDocument = [lemmatizer.lemmatize(w) for w in newDocument]
  return newDocument

# %% [markdown]
# The upcoming snippet of code defines three functions for interacting with the PubMed databaes:
#
#
# 1.   **search_pubmed(query, max_results=10)**: Searches PubMed using a specified query and returns a list of PubMed IDs (PMIDs) for the retrieved results, with a default maximum of 10 results.
#
# 2.   **fetch_abstracts(pubmed_ids)**: Fetches the abstracts corresponding to a list of PubMed IDs and returns them as text.
#
# 3.   **fetch_abstracts_and_summaries(pubmed_ids)**: Retrieves summaries for the PubMed records identified by a list of PubMed IDs and returns them as structured data.

# %%
def search_pubmed(query, max_results=10):
    Entrez.email = "SemanticSurgeons@gmail.com"
    handle = Entrez.esearch(db="pubmed", term=query, retmax=max_results)
    results = Entrez.read(handle)
    handle.close()
    return results["IdList"]

def fetch_abstracts(pubmed_ids):
    Entrez.email = "SemanticSurgeons@gmail.com"
    handle = Entrez.efetch(db="pubmed", id=pubmed_ids, rettype="abstract", retmode="text")
    abstracts = handle.read()
    handle.close()
    return abstracts

def fetch_abstracts_and_summaries(pubmed_ids):
    Entrez.email = "SemanticSurgeons@gmail.com"
    summaries = Entrez.esummary(db="pubmed", id=','.join(pubmed_ids))
    summary_records = Entrez.read(summaries)
    summaries.close()
    return summary_records

# %% [markdown]
# The following function, **create_query**, generates a query based on the input question. If the question length exceeds a specified threshold (queryLength), the function extracts keywords using a keyword extraction model and constructs a query using these keywords. Otherwise, it returns the original question

# %%
def create_query(question,queryLength):
  if len(question) > queryLength:
    query = []
    keywords = kw_model.extract_keywords(question, keyphrase_ngram_range=(1, 1), stop_words='english',top_n=queryLength)
    for j in range(len(keywords)):
      key = keywords[j][0]
      query.append(key)
    query = ' '.join(query)
    return query
  else:
    return question

# %%
def most_similar(doc_id,similarity_matrix,matrix):
    print (f'Document: {question_documents_train_set[doc_id]}')
    print ('\n')
    print (f'Similar Documents using {matrix}:')
    if matrix=='Cosine Similarity':
        similar_ix=np.argsort(similarity_matrix[doc_id])[::-1]
        print(similar_ix)
    elif matrix=='Euclidean Distance':
        similar_ix=np.argsort(similarity_matrix[doc_id])
    for ix in similar_ix:
        if ix==doc_id:
            continue
        print('\n')
        print (f'Document: {question_documents_train_set[ix]}')
        print (f'{matrix} : {similarity_matrix[doc_id][ix]}')

# %% [markdown]
# # Dataset Loading and preprocessing

# %% [markdown]
# We'll begin by loading and preprocessing the dataset to ensure it's in the appropriate format for the context retrieval phase.

# %%
medFlashCards_df = pd.read_csv('MedFlashCards.csv')
medFlashCards_df.dropna(inplace=True)
medFlashCards_df
# Out:
#                                                    input  \
# 0      What is the relationship between very low Mg2+...
# 1      What leads to genitourinary syndrome of menopa...
# 2      What does low REM sleep latency and experienci...
# 3      What are some possible causes of low PTH and h...
# 4      How does the level of anti-müllerian hormone r...
# ...                                                  ...
# 33946  What is Opsoclonus-Myoclonus Ataxia Syndrome, ...
# 33947  What is Opsoclonus-Myoclonus Ataxia Syndrome, ...
# 33948             Is A part of B in a proportion of A/B?
# 33949  What is the mnemonic "Microtubules Get Constru...
# 33950  At what age does bed wetting (enuresis) become...
#
#                                                   output  \
# 0      Very low Mg2+ levels correspond to low PTH lev...
# 1      Low estradiol production leads to genitourinar...
# 2      Low REM sleep latency and experiencing halluci...
# 3      PTH-independent hypercalcemia, which can be ca...
# 4      The level of anti-müllerian hormone is directl...
# ...                                                  ...
# 33946  Opsoclonus-Myoclonus Ataxia Syndrome is a para...
# 33947  Opsoclonus-Myoclonus Ataxia Syndrome is a para...
# 33948        Yes, A is part of B in a proportion of A/B.
# 33949  The mnemonic "Microtubules Get Constructed Ver...
# 33950  At the age of 5 or older, bed wetting (enuresi...
#
#                            instruction
# 0      Answer this question truthfully
# 1      Answer this question truthfully
# 2      Answer this question truthfully
# 3      Answer this question truthfully
# 4      Answer this question truthfully
# ...                                ...
# 33946  Answer this question truthfully
# 33947  Answer this question truthfully
# 33948  Answer this question truthfully
# 33949  Answer this question truthfully
# 33950  Answer this question truthfully
#
# [33547 rows x 3 columns]

# %%
questions_df = pd.DataFrame(medFlashCards_df['input'])
answers_df = pd.DataFrame(medFlashCards_df['output'])

# %%
questions_df['Cleaned Questions'] = questions_df["input"].apply(lambda question: ' '.join(preprocess_document(question.split(), noPunctuation=True,lemmatization=True )) )

# %% [markdown]
# # Context Retrival

# %%
if SET_RANDOM_INDEX == True:
  random_question_index = np.random.randint(0, len(medFlashCards_df)-1)
else:
  random_question_index = 1460

# %%
question = questions_df['Cleaned Questions'][random_question_index]
answer = answers_df['output'][random_question_index]

# %%
print(f'Question: {question}')
print(f'Answers: {answer}')
# Out:
# Question: What cause amoebic brain disease and is associated with freshwater source
# Answers: Naegleria fowleri causes amoebic brain disease and is associated with freshwater sources.

# %% [markdown]
# We'll now generate the query for retrieving documents from the PubMed API. Considering a query length of 6, we'll use the create_query function to construct the query based on the provided question.

# %%
query_length = 6
query = create_query(question, query_length)

# %% [markdown]
# The upcoming code segment starts by setting the maximum number of results to retrieve from a PubMed search and performs the search using the provided query. If the initial search yields no results, it retries the search using the last keyword from the query which is the least important

# %%
max_results = 30  # Maximum number of results to retrieve
pubmed_ids = search_pubmed(query, max_results)
if not pubmed_ids:
    pubmed_ids = search_pubmed(query[:-1], max_results)

# %% [markdown]
# This code fetches abstracts for PubMed IDs and creates a DataFrame called "documents" with two columns: "docno" and "text," where each row represents an abstract with an incremented ID.

# %%
abstracts = fetch_abstracts(pubmed_ids)
documents = pd.DataFrame(columns=["docno", "text"])
for idx, abstract in enumerate(abstracts.split("\n\n")):
  newEntry = {'docno': idx + 1, 'text': abstract}
  documents = documents._append(newEntry, ignore_index = True)

# %% [markdown]
# Let's preprocess the retrieved contexts to ensure they are in the optimal format for subsequent operations.

# %%
documents['Cleaned Context'] = documents['text'].apply(lambda question: " ".join(preprocess_document(question.split(),noPunctuation=True, lemmatization=True)))

# %%
documents
# Out:
#    docno                                               text  \
# 0      1  1. ACS ES T Water. 2023 Mar 15;3(4):1126-1133....
# 1      2  A Case of Primary Amebic Meningoencephalitis A...
# 2      3  Miko S(1), Cope JR(1), Hlavsa MC(1), Ali IKM(1...
# 3      4  Author information:\n(1)U.S. Centers for Disea...
# 4      5  Naegleria fowleri is a thermophilic ameba foun...
# ..   ...                                                ...
# 88    89  The possibility of congenital infection with A...
# 89    90                         Awadalla HN(1), Sadaka HA.
# 90    91  Author information:\n(1)Department of Parasito...
# 91    92  Acanthamoeba culbertsoni is one of the free-li...
# 92    93                PMID: 8918032 [Indexed for MEDLINE]
#
#                                       Cleaned Context
# 0   1 ACS ES T Water 2023 Mar 153411261133 doi 101...
# 1   A Case of Primary Amebic Meningoencephalitis A...
# 2   Miko S1 Cope JR1 Hlavsa MC1 Ali IKM1 Brown TW1...
# 3   Author information 1US Centers for Disease Con...
# 4   Naegleria fowleri is a thermophilic ameba foun...
# ..                                                ...
# 88  The possibility of congenital infection with A...
# 89                             Awadalla HN1 Sadaka HA
# 90  Author information 1Department of Parasitology...
# 91  Acanthamoeba culbertsoni is one of the freeliv...
# 92                   PMID 8918032 Indexed for MEDLINE
#
# [93 rows x 3 columns]

# %% [markdown]
# ## Document Search Engine using Indexing

# %% [markdown]
# These methods assess the importance of terms based on their frequencies within the retrieved contexts and the question itself

# %% [markdown]
# The first step in order to apply any kind of search is to index the whole dataset of contexts

# %%
indexer = pt.DFIndexer("./index_contexts", overwrite=True)
documents['docno'] = documents['docno'].astype(str)
index_ref = indexer.index(documents["Cleaned Context"],documents['docno'])
index_ref.toString()
# Out:
# './index_contexts/data.properties'

# %%
# !ls -lh index_contexts/
# Out:
# total 134K
# -rw------- 1 root root 1.6K May 25 08:43 data.direct.bf
# -rw------- 1 root root 1.6K May 25 08:43 data.document.fsarrayfile
# -rw------- 1 root root 2.9K May 25 08:43 data.inverted.bf
# -rw------- 1 root root 112K May 25 08:43 data.lexicon.fsomapfile
# -rw------- 1 root root  993 May 25 08:43 data.lexicon.fsomaphash
# -rw------- 1 root root 5.2K May 25 08:43 data.lexicon.fsomapid
# -rw------- 1 root root 1023 May 25 08:43 data.meta-0.fsomapfile
# -rw------- 1 root root  744 May 25 08:43 data.meta.idx
# -rw------- 1 root root 1.5K May 25 08:43 data.meta.zdata
# -rw------- 1 root root 4.2K May 25 08:43 data.properties

# %% [markdown]
# Let's now load the index and print  some information about our collection

# %%
index = pt.IndexFactory.of(index_ref)
print(index.getCollectionStatistics().toString())
# Out:
# Number of documents: 93
# Number of terms: 1328
# Number of postings: 2459
# Number of fields: 0
# Number of tokens: 3205
# Field names: []
# Positions:   false

# %% [markdown]
# ### TF-IDF Index Search

# %% [markdown]
# This code segment initializes a TF-IDF-based batch retrieval system with a specified index and then executes a search using the provided query.

# %%
tf_idf = pt.BatchRetrieve(index, wmodel="TF_IDF")
ranking_td_idf = tf_idf.search(query)
ranking_td_idf
# Out:
#    qid  docid docno  rank     score  \
# 0    1     52    53     0  6.013538
# 1    1     91    92     1  5.589591
# 2    1     66    67     2  5.270139
# 3    1     63    64     3  4.640910
# 4    1     31    32     4  4.603874
# 5    1      4     5     5  4.081031
# 6    1     78    79     6  3.699922
# 7    1     58    59     7  3.276339
# 8    1     18    19     8  3.266189
# 9    1     49    50     9  3.216381
# 10   1     44    45    10  3.161704
# 11   1     24    25    11  3.103534
# 12   1     85    86    12  3.022416
# 13   1     37    38    13  3.017406
# 14   1     10    11    14  2.845765
# 15   1     72    73    15  2.510151
# 16   1     17    18    16  2.383433
# 17   1     77    78    17  2.185089
# 18   1     71    72    18  2.095588
# 19   1      1     2    19  2.092789
# 20   1     75    76    20  2.092789
# 21   1     41    42    21  2.058914
# 22   1     70    71    22  2.026117
# 23   1     55    56    23  1.933712
# 24   1     43    44    24  1.792672
# 25   1     45    46    25  1.772090
# 26   1     59    60    26  1.745150
# 27   1     57    58    27  1.577299
# 28   1     36    37    28  1.540133
# 29   1     23    24    29  1.502279
# 30   1      9    10    30  1.370203
# 31   1     26    27    31  1.314310
# 32   1     51    52    32  1.237287
# 33   1      3     4    33  1.150485
#
#                                                 query
# 0   amoebic freshwater disease brain cause associated
# 1   amoebic freshwater disease brain cause associated
# 2   amoebic freshwater disease brain cause associated
# 3   amoebic freshwater disease brain cause associated
# 4   amoebic freshwater disease brain cause associated
# 5   amoebic freshwater disease brain cause associated
# 6   amoebic freshwater disease brain cause associated
# 7   amoebic freshwater disease brain cause associated
# 8   amoebic freshwater disease brain cause associated
# 9   amoebic freshwater disease brain cause associated
# 10  amoebic freshwater disease brain cause associated
# 11  amoebic freshwater disease brain cause associated
# 12  amoebic freshwater disease brain cause associated
# 13  amoebic freshwater disease brain cause associated
# 14  amoebic freshwater disease brain cause associated
# 15  amoebic freshwater disease brain cause associated
# 16  amoebic freshwater disease brain cause associated
# 17  amoebic freshwater disease brain cause associated
# 18  amoebic freshwater disease brain cause associated
# 19  amoebic freshwater disease brain cause associated
# 20  amoebic freshwater disease brain cause associated
# 21  amoebic freshwater disease brain cause associated
# 22  amoebic freshwater disease brain cause associated
# 23  amoebic freshwater disease brain cause associated
# 24  amoebic freshwater disease brain cause associated
# 25  amoebic freshwater disease brain cause associated
# 26  amoebic freshwater disease brain cause associated
# 27  amoebic freshwater disease brain cause associated
# 28  amoebic freshwater disease brain cause associated
# 29  amoebic freshwater disease brain cause associated
# 30  amoebic freshwater disease brain cause associated
# 31  amoebic freshwater disease brain cause associated
# 32  amoebic freshwater disease brain cause associated
# 33  amoebic freshwater disease brain cause associated

# %% [markdown]
# This code snippet checks if the ranking list is not empty. If it's not empty, it retrieves the most relevant result and, if its length is less than 300 characters, also retrieves the second relevant result and concatenates them. If the ranking list is empty, it assigns 'NAN' to the most relevant result.

# %%
ranking_length = len(ranking_td_idf)
if(ranking_length)!=0:
    most_relevant_result_docno = ranking_td_idf.loc[ranking_td_idf['rank'] == 0, 'docno'].values[0]
    most_relevant_result = documents.loc[documents['docno'] ==  most_relevant_result_docno, 'text'].values[0]

    if len(most_relevant_result) < 300:
      second_relevant_result_docno = ranking_td_idf.loc[ranking['rank'] == 1, 'docno'].values[0]
      second_relevant_result = documents.loc[documents['docno'] ==  most_relevant_result_docno, 'text'].values[0]
      most_relevant_result = most_relevant_result + ' ' + second_relevant_result

else:
      most_relevant_result = 'NAN'

# %%
context_tfIdf = most_relevant_result
print(context_tfIdf)
# Out:
# INTRODUCTION: Primary amoebic meningoencephalitis (PAM) is a rare disease caused
# by the free-living amoeba Naegleria fowleri. Infection occurs by insufflation of
# water containing amoebae into the nasal cavity, and is usually associated with
# bathing in freshwater. Nasal irrigation is a more rarely reported route of
# infection.
# CASE PRESENTATION: A fatal case of PAM in a previously healthy Norwegian woman,
# acquired during a holiday trip to Thailand, is described. Clinical findings were
# consistent with rapidly progressing meningoencephalitis. The cause of infection
# was discovered by chance, owing to the unexpected detection of N. fowleri DNA by
# a PCR assay targeting fungi. A conclusive diagnosis was established based on
# sequencing of N. fowleri DNA from brain biopsies, supported by histopathological
# findings. Nasal irrigation using contaminated tap water is suspected as the
# source of infection.
# CONCLUSION: The clinical presentation of PAM is very similar to severe bacterial
# meningitis. This case is a reminder that when standard investigations fail to
# identify a cause of infection in severe meningoencephalitis, it is of crucial
# importance to continue a broad search for a conclusive diagnosis. PAM should be
# considered as a diagnosis in patients with symptoms of severe
# meningoencephalitis returning from endemic areas.

# %% [markdown]
# ### BM25 Index Search

# %% [markdown]
# This code segment initializes a BM25-based batch retrieval system with a specified index and then executes a search using the provided query.

# %%
bm25 = pt.BatchRetrieve(index, wmodel="BM25")
ranking_bm25 = bm25.search(query)
ranking_bm25
# Out:
#    qid  docid docno  rank     score  \
# 0    1     52    53     0  9.418227
# 1    1     91    92     1  8.867455
# 2    1     66    67     2  8.481014
# 3    1     63    64     3  7.273235
# 4    1     31    32     4  6.767356
# 5    1      4     5     5  6.395992
# 6    1     78    79     6  5.642075
# 7    1     49    50     7  5.468598
# 8    1     58    59     8  5.131413
# 9    1     44    45     9  5.052329
# 10   1     18    19    10  4.968287
# 11   1     24    25    11  4.715383
# 12   1     10    11    12  4.598068
# 13   1     37    38    13  4.485981
# 14   1     85    86    14  4.459742
# 15   1     72    73    15  4.037446
# 16   1     17    18    16  3.222006
# 17   1      1     2    17  3.093240
# 18   1     75    76    18  3.093240
# 19   1     41    42    19  3.043170
# 20   1     70    71    20  2.994696
# 21   1     77    78    21  2.953878
# 22   1     55    56    22  2.858116
# 23   1     71    72    23  2.832888
# 24   1     43    44    24  2.423395
# 25   1     45    46    25  2.395572
# 26   1     59    60    26  2.359153
# 27   1     57    58    27  2.132246
# 28   1     36    37    28  2.082004
# 29   1     23    24    29  2.030831
# 30   1     26    27    30  1.942612
# 31   1      9    10    31  1.852287
# 32   1     51    52    32  1.672606
# 33   1      3     4    33  1.555264
#
#                                                 query
# 0   amoebic freshwater disease brain cause associated
# 1   amoebic freshwater disease brain cause associated
# 2   amoebic freshwater disease brain cause associated
# 3   amoebic freshwater disease brain cause associated
# 4   amoebic freshwater disease brain cause associated
# 5   amoebic freshwater disease brain cause associated
# 6   amoebic freshwater disease brain cause associated
# 7   amoebic freshwater disease brain cause associated
# 8   amoebic freshwater disease brain cause associated
# 9   amoebic freshwater disease brain cause associated
# 10  amoebic freshwater disease brain cause associated
# 11  amoebic freshwater disease brain cause associated
# 12  amoebic freshwater disease brain cause associated
# 13  amoebic freshwater disease brain cause associated
# 14  amoebic freshwater disease brain cause associated
# 15  amoebic freshwater disease brain cause associated
# 16  amoebic freshwater disease brain cause associated
# 17  amoebic freshwater disease brain cause associated
# 18  amoebic freshwater disease brain cause associated
# 19  amoebic freshwater disease brain cause associated
# 20  amoebic freshwater disease brain cause associated
# 21  amoebic freshwater disease brain cause associated
# 22  amoebic freshwater disease brain cause associated
# 23  amoebic freshwater disease brain cause associated
# 24  amoebic freshwater disease brain cause associated
# 25  amoebic freshwater disease brain cause associated
# 26  amoebic freshwater disease brain cause associated
# 27  amoebic freshwater disease brain cause associated
# 28  amoebic freshwater disease brain cause associated
# 29  amoebic freshwater disease brain cause associated
# 30  amoebic freshwater disease brain cause associated
# 31  amoebic freshwater disease brain cause associated
# 32  amoebic freshwater disease brain cause associated
# 33  amoebic freshwater disease brain cause associated

# %%
ranking_length = len(ranking_bm25)
if(ranking_length)!=0:
    most_relevant_result_docno = ranking_td_idf.loc[ranking_bm25['rank'] == 0, 'docno'].values[0]
    most_relevant_result = documents.loc[documents['docno'] ==  most_relevant_result_docno, 'text'].values[0]

    if len(most_relevant_result) < 300:
      second_relevant_result_docno = ranking_bm25.loc[ranking_bm25['rank'] == 1, 'docno'].values[0]
      second_relevant_result = documents.loc[documents['docno'] ==  most_relevant_result_docno, 'text'].values[0]
      most_relevant_result = most_relevant_result + ' ' + second_relevant_result

else:
      most_relevant_result = 'NAN'

# %%
context_bm25 = most_relevant_result
print(context_bm25)
# Out:
# INTRODUCTION: Primary amoebic meningoencephalitis (PAM) is a rare disease caused
# by the free-living amoeba Naegleria fowleri. Infection occurs by insufflation of
# water containing amoebae into the nasal cavity, and is usually associated with
# bathing in freshwater. Nasal irrigation is a more rarely reported route of
# infection.
# CASE PRESENTATION: A fatal case of PAM in a previously healthy Norwegian woman,
# acquired during a holiday trip to Thailand, is described. Clinical findings were
# consistent with rapidly progressing meningoencephalitis. The cause of infection
# was discovered by chance, owing to the unexpected detection of N. fowleri DNA by
# a PCR assay targeting fungi. A conclusive diagnosis was established based on
# sequencing of N. fowleri DNA from brain biopsies, supported by histopathological
# findings. Nasal irrigation using contaminated tap water is suspected as the
# source of infection.
# CONCLUSION: The clinical presentation of PAM is very similar to severe bacterial
# meningitis. This case is a reminder that when standard investigations fail to
# identify a cause of infection in severe meningoencephalitis, it is of crucial
# importance to continue a broad search for a conclusive diagnosis. PAM should be
# considered as a diagnosis in patients with symptoms of severe
# meningoencephalitis returning from endemic areas.

# %% [markdown]
# ### Composition

# %% [markdown]
# This operator allow to re-rank the output of one retriever using a second retriever

# %%
composition = tf_idf >> bm25
composition_ranking = composition.search(query)
composition_ranking
# Out:
#    qid  docid docno  rank     score  \
# 0    1     52    53     0  9.418227
# 1    1     91    92     1  8.867455
# 2    1     66    67     2  8.481014
# 3    1     63    64     3  7.273235
# 4    1     31    32     4  6.767356
# 5    1      4     5     5  6.395992
# 6    1     78    79     6  5.642075
# 7    1     49    50     7  5.468598
# 8    1     58    59     8  5.131413
# 9    1     44    45     9  5.052329
# 10   1     18    19    10  4.968287
# 11   1     24    25    11  4.715383
# 12   1     10    11    12  4.598068
# 13   1     37    38    13  4.485981
# 14   1     85    86    14  4.459742
# 15   1     72    73    15  4.037446
# 16   1     17    18    16  3.222006
# 17   1      1     2    17  3.093240
# 18   1     75    76    18  3.093240
# 19   1     41    42    19  3.043170
# 20   1     70    71    20  2.994696
# 21   1     77    78    21  2.953878
# 22   1     55    56    22  2.858116
# 23   1     71    72    23  2.832888
# 24   1     43    44    24  2.423395
# 25   1     45    46    25  2.395572
# 26   1     59    60    26  2.359153
# 27   1     57    58    27  2.132246
# 28   1     36    37    28  2.082004
# 29   1     23    24    29  2.030831
# 30   1     26    27    30  1.942612
# 31   1      9    10    31  1.852287
# 32   1     51    52    32  1.672606
# 33   1      3     4    33  1.555264
#
#                                                 query
# 0   amoebic freshwater disease brain cause associated
# 1   amoebic freshwater disease brain cause associated
# 2   amoebic freshwater disease brain cause associated
# 3   amoebic freshwater disease brain cause associated
# 4   amoebic freshwater disease brain cause associated
# 5   amoebic freshwater disease brain cause associated
# 6   amoebic freshwater disease brain cause associated
# 7   amoebic freshwater disease brain cause associated
# 8   amoebic freshwater disease brain cause associated
# 9   amoebic freshwater disease brain cause associated
# 10  amoebic freshwater disease brain cause associated
# 11  amoebic freshwater disease brain cause associated
# 12  amoebic freshwater disease brain cause associated
# 13  amoebic freshwater disease brain cause associated
# 14  amoebic freshwater disease brain cause associated
# 15  amoebic freshwater disease brain cause associated
# 16  amoebic freshwater disease brain cause associated
# 17  amoebic freshwater disease brain cause associated
# 18  amoebic freshwater disease brain cause associated
# 19  amoebic freshwater disease brain cause associated
# 20  amoebic freshwater disease brain cause associated
# 21  amoebic freshwater disease brain cause associated
# 22  amoebic freshwater disease brain cause associated
# 23  amoebic freshwater disease brain cause associated
# 24  amoebic freshwater disease brain cause associated
# 25  amoebic freshwater disease brain cause associated
# 26  amoebic freshwater disease brain cause associated
# 27  amoebic freshwater disease brain cause associated
# 28  amoebic freshwater disease brain cause associated
# 29  amoebic freshwater disease brain cause associated
# 30  amoebic freshwater disease brain cause associated
# 31  amoebic freshwater disease brain cause associated
# 32  amoebic freshwater disease brain cause associated
# 33  amoebic freshwater disease brain cause associated

# %%
if(len(composition_ranking))!=0:
    most_relevant_result_docno = composition_ranking.loc[composition_ranking['rank'] == 0, 'docno'].values[0]
    most_relevant_result = documents.loc[documents['docno'] ==  most_relevant_result_docno, 'text'].values[0]
    if len(most_relevant_result) < 300:
      second_relevant_result_docno = composition_ranking.loc[composition_ranking['rank'] == 1, 'docno'].values[0]
      second_relevant_result = documents.loc[documents['docno'] ==  most_relevant_result_docno, 'text'].values[0]
      most_relevant_result = most_relevant_result + ' ' + second_relevant_result
else:
      most_relevant_result = 'NAN'

# %%
context_composition_tfIdf_bm25 = most_relevant_result
print(context_composition_tfIdf_bm25)
# Out:
# INTRODUCTION: Primary amoebic meningoencephalitis (PAM) is a rare disease caused
# by the free-living amoeba Naegleria fowleri. Infection occurs by insufflation of
# water containing amoebae into the nasal cavity, and is usually associated with
# bathing in freshwater. Nasal irrigation is a more rarely reported route of
# infection.
# CASE PRESENTATION: A fatal case of PAM in a previously healthy Norwegian woman,
# acquired during a holiday trip to Thailand, is described. Clinical findings were
# consistent with rapidly progressing meningoencephalitis. The cause of infection
# was discovered by chance, owing to the unexpected detection of N. fowleri DNA by
# a PCR assay targeting fungi. A conclusive diagnosis was established based on
# sequencing of N. fowleri DNA from brain biopsies, supported by histopathological
# findings. Nasal irrigation using contaminated tap water is suspected as the
# source of infection.
# CONCLUSION: The clinical presentation of PAM is very similar to severe bacterial
# meningitis. This case is a reminder that when standard investigations fail to
# identify a cause of infection in severe meningoencephalitis, it is of crucial
# importance to continue a broad search for a conclusive diagnosis. PAM should be
# considered as a diagnosis in patients with symptoms of severe
# meningoencephalitis returning from endemic areas.

# %% [markdown]
# ## Document Search Engine using Document Vectorization

# %% [markdown]
# Compute the textual documents into numerical vectors based on the relevancy of the words and how often they appear in the documents

# %% [markdown]
# Create lists of contexts and questions from the corresponding dataframes for building the train set

# %%
contexts_list = documents['text'].tolist()
questions_list  = questions_df['input'].tolist()

# %%
train_set = questions_list + contexts_list

# %% [markdown]
# This line fits the vectorizer to the training set, learning the vocabulary and the idf (inverse document frequency) values from the training data

# %%
vectorizer = TfidfVectorizer(max_df=0.8, min_df=5, stop_words='english')

# %%
vectorizer.fit(train_set)
# Out:
# TfidfVectorizer(max_df=0.8, min_df=5, stop_words='english')

# %%
learned_vocabulary = vectorizer.get_feature_names_out()
print(f'Length of Vocabulary: {len(learned_vocabulary)}')
# Out:
# Length of Vocabulary: 6239

# %% [markdown]
# The upcoming lines of code transform the question and contexts list into their vector representations using the fitted vectorizer. This process converts the text data into numerical vectors based on the learned vocabulary and idf values

# %%
vector_question = vectorizer.transform([question])
vector_contexts = vectorizer.transform(contexts_list)

# %% [markdown]
# Let's compute the similarities

# %%
question_contexts_similarities = np.dot(vector_question, vector_contexts.T)

# %%
best_matches = np.argmax(question_contexts_similarities, axis=1)
value = best_matches[0][0, 0]
print(f"The more similar context to question 0 is {best_matches[0]}")
print('CONTEXT:' ,contexts_list[value] )
# Out:
# The more similar context to question 0 is [[49]]
# CONTEXT: Fatal primary amoebic meningoencephalitis in a Norwegian tourist returning from
# Thailand.

# %% [markdown]
# ## Document Search Engine using Document Embedding

# %% [markdown]
# A document search engine using embeddings transforms how search results are generated by focusing on the semantic meaning of text rather than just matching keywords. Choosing embeddings for this purpose offers significant advantages. Embeddings capture the semantic meaning of words, enabling more accurate and contextually relevant search results by understanding synonyms and polysemous words. They enhance contextual understanding, improve disambiguation, support scalable and efficient searches, and enable cross-lingual capabilitie

# %% [markdown]
# **Doc2Vec**
#
# Doc2Vec is an extension of the Word2Vec model that learns continuous representations for pieces of text, such as sentences, paragraphs, or documents, while also capturing their semantic meanings. In Doc2Vec, each document is represented as a fixed-length vector, just like words are represented as vectors in Word2Vec.
#
# The following code  prepares the data for training a Doc2Vec model by creating a list of tagged documents. Each document is tokenized into words, and a unique tag is assigned to it. The resulting tagged_data list contains TaggedDocument objects, where each object represents a document (question or context) with its corresponding tag.

# %%
question_documents_train_set = [question] + documents['Cleaned Context'].tolist()
tagged_data = [TaggedDocument(words=word_tokenize(doc), tags=[i]) for i, doc in enumerate(question_documents_train_set)]

# %% [markdown]
# This code initializes a Doc2Vec model with a vector size of 100 and trains it for 100 epochs using the provided tagged data. During training, the model learns to generate document vectors that represent the semantic meaning of the input documents.

# %%
model_d2v = Doc2Vec(vector_size=100,alpha=0.025, min_count=1)

model_d2v.build_vocab(tagged_data)

for epoch in range(100):
    model_d2v.train(tagged_data,
                total_examples=model_d2v.corpus_count,
                epochs=model_d2v.epochs)
# Out:
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles
# WARNING:gensim.models.word2vec:Effective 'alpha' higher than previous training cycles

# %% [markdown]
# Let's initialize an array to store document embeddings with dimensions corresponding to the number of documents in the dataset and a vector size of 100. Then, we are going  iterate over each document in the dataset, retrieve its corresponding Doc2Vec embedding from the trained model, and assign it to the corresponding position in the document_embeddings array.

# %%
document_embeddings=np.zeros((documents.shape[0],100))

for i in range(len(document_embeddings)):
    document_embeddings[i]= model_d2v.docvecs[i]
# Out:
# <ipython-input-81-7a8159e4f679>:4: DeprecationWarning: Call to deprecated `docvecs` (The `docvecs` property has been renamed `dv`.).
#   document_embeddings[i]= model_d2v.docvecs[i]

# %% [markdown]
# Let's calculates pairwise similarities and differences between document embeddings using cosine similarity

# %%
pairwise_similarities=cosine_similarity(document_embeddings)

# %% [markdown]
# Let's retrieve the most similar documents

# %%
most_similar(0,pairwise_similarities,'Cosine Similarity')
# Out:
# Document: What cause amoebic brain disease and is associated with freshwater source
#
#
# Similar Documents using Cosine Similarity:
# [ 0 78 48 50 76 43  7  8 12 16 18 89 42 17 87 33 58 64 82 60 41  9 46 91
#  74 47 83 68 84 62 29 22 71  1 40 35 39 67 61 26  2 66 57 53  3 13 85 69
#  65 24 20 49 31 14 77 72 28 36 59 79 37 70 30 11 55  6 51 10 21 92 52 75
#  80 19 90 44 23 63  4 56 25 27 54 34  5 32 15 88 81 86 38 45 73]
#
#
# Document: Author information 1National Center for Emerging and Zoonotic Infectious Diseases Centers for Disease Control and Prevention1600 Clifton Road Atlanta GA 30329 USA jey9cdcgov
# Cosine Similarity : 0.7261215865224676
#
#
# Document: Conflict of interest statement Potential conflict of interest All author No reported conflict
# Cosine Similarity : 0.7080370555308303
#
#
# Document: Fatal primary amoebic meningoencephalitis in a Norwegian tourist returning from Thailand
# Cosine Similarity : 0.6972952042767578
#
#
# Document: Primary amebic meningoencephalitis death associated with sinus irrigation using contaminated tap water
# Cosine Similarity : 0.6928848238633137
#
#
# Document: Cope JR1 Murphy J1 Kahler A1 Gorbett DG2 Ali I1 Taylor B3 Corbitt L4 Roy S1 Lee N5 Roellig D1 Brewer S6 Hill VR1
# Cosine Similarity : 0.691211865053597
#
#
# Document: 2 Front Microbiol 2023 Feb 1131056418 doi 103389fmicb20221056418 eCollection 2022
# Cosine Similarity : 0.6882809889087357
#
#
# Document: Naegleria genus pangenome reveals new structural and functional insight into the versatility of these freeliving amoeba
# Cosine Similarity : 0.679754580466191
#
#
# Document: Copyright © 2023 Dereeper Allouch Guerlais Garnier Ma De Jonckheere Joseph Ali Talarmin and Marcelino
# Cosine Similarity : 0.6719485195070808
#
#
# Document: Comparative Genomic and Transcriptomic Analysis of Naegleria fowleri Clinical and Environmental Isolates
# Cosine Similarity : 0.6686539228473909
#
#
# Document: Author information 1Waterborne Disease Prevention Branch Division of Foodborne Waterborne and Environmental Diseases National Center for Emerging and Zoonotic Infectious Diseases Centers for Disease Control and Preventiongrid416738f Atlanta Georgia USA 2Eagle Medical Services Atlanta Georgia USA
# Cosine Similarity : 0.6671730632455167
#
#
# Document: The possibility of congenital infection with Acanthamoeba culbertsoni
# Cosine Similarity : 0.6659148784735224
#
#
# Document: Primary Amebic Meningoencephalitis Associated With Rafting on an Artificial Whitewater River Case Report and Environmental Investigation
# Cosine Similarity : 0.6617918934225643
#
#
# Document: Joseph SJ1 Park S2 Kelley A2 Roy S1 Cope JR1 Ali IKM1
# Cosine Similarity : 0.6554888980389426
#
#
# Document: PMID 15915965 Indexed for MEDLINE
# Cosine Similarity : 0.6548399092930035
#
#
# Document: DOI 103201eid2701202119 PMCID PMC7774533 PMID 33350926 Indexed for MEDLINE
# Cosine Similarity : 0.6542536439962077
#
#
# Document: Author information 1Centers for Disease Control and Prevention Atlanta Georgia 2Louisiana Department of Health and Hospitals New Orleans and Baton Rouge 3Tulane University Health Sciences Center New Orleans Louisiana
# Cosine Similarity : 0.650782606822117
#
#
# Document: An autopsy case of Balamuthia mandrillaris amoebic encephalitis a rare emerging infectious disease with a brief review of the case reported in Japan
# Cosine Similarity : 0.650743047595824
#
#
# Document: Primary amebic meningoencephalitis 1st case observed in Madagascar
# Cosine Similarity : 0.6490841497278422
#
#
# Document: Published by Oxford University Press on behalf of the Infectious Diseases Society of America 2015 This work is written by a US Government employee and is in the public domain in the US
# Cosine Similarity : 0.6469639148244191
#
#
# Document: 7 Clin Infect Dis 2018 Feb 1664548553 doi 101093cidcix810
# Cosine Similarity : 0.6464183591886348
#
#
# Document: Dereeper A1 Allouch N1 Guerlais V1 Garnier M1 Ma L2 De Jonckheere JF3 Joseph SJ4 Ali IKM4 Talarmin A1 Marcelino I1
# Cosine Similarity : 0.6443534339748181
#
#
# Document: Published by Oxford University Press for the Infectious Diseases Society of America 2017 This work is written by a US Government employee and is in the public domain in the US
# Cosine Similarity : 0.6435474997977747
#
#
# Document: Author information 1Department of Parasitology Faculty of Medicine Alexandria University Egypt
# Cosine Similarity : 0.6434571775240445
#
#
# Document: PMCID PMC4585351 PMID 24226628 Indexed for MEDLINE
# Cosine Similarity : 0.6418332017271511
#
#
# Document: DOI 101093cidcix810 PMCID PMC5801760 PMID 29401275 Indexed for MEDLINE
# Cosine Similarity : 0.6357472481530807
#
#
# Document: Article in French
# Cosine Similarity : 0.6303689084457038
#
#
# Document: © 2014 Japanese Society of Neuropathology
# Cosine Similarity : 0.6261283763862744
#
#
# Document: JaffarBandjee MC1 Alessandri JL Molet B Clouzeau J Jacquemot L Sampériz S Saly JC
# Cosine Similarity : 0.6250132126176319
#
#
# Document: Conflict of interest statement Potential conflict of interest All author no reported conflict
# Cosine Similarity : 0.6237635588618127
#
#
# Document: Geographic Range of Recreational WaterAssociated Primary Amebic Meningoencephalitis United States 19782018
# Cosine Similarity : 0.6236240025176485
#
#
# Document: Naegleria fowleri Protein structure to facilitate drug discovery for the deadly pathogenic freeliving amoeba
# Cosine Similarity : 0.6198410138760307
#
#
# Document: Notes from the field primary amebic meningoencephalitis associated with ritual nasal rinsingSt Thomas US Virgin island 2012
# Cosine Similarity : 0.6191468351849349
#
#
# Document: 1 ACS ES T Water 2023 Mar 153411261133 doi 101021acsestwater2c00592
# Cosine Similarity : 0.6185509955598403
#
#
# Document: DOI 101016jexppara201803010 PMCID PMC5918159 PMID 29551628 Indexed for MEDLINE
# Cosine Similarity : 0.6124507122870096
#
#
# Document: Identification of cysteine protease inhibitor a new drug lead against Naegleria fowleri
# Cosine Similarity : 0.6113166493692352
#
#
# Document: Copyright © 2018 Elsevier Inc All right reserved
# Cosine Similarity : 0.6110763599838783
#
#
# Document: Balamuthia mandrillaris is an amoeba found in fresh water and soil that cause granulomatous amoebic encephalitis We report herein an autopsy case of B mandrillaris amoebic encephalitis which wa definitely diagnosed by PCR An 81yearold man who had Sjögrens syndrome manifested drowsiness 2 month before his death with progressive deterioration Neuroimaging demonstrated focus of T2 and fluidattenuated inversion recovery high and T1 lowintensity with irregular postcontrast ring enhancement in the cerebral hemisphere thalamus and midbrain Pathologically multiple hemorrhagic and necrotic lesion were found in the cerebrum thalamus midbrain pons medulla and cerebellum which were characterized by liquefactive necrosis marked edema hemorrhage and necrotizing vasculitis associated with the perivascular accumulation of amoebic trophozoite a few cyst and the infiltration of numerous neutrophil and microgliamacrophages The trophozoite were ovoid or round 1060 μm in diameter and they showed foamy cytoplasm and a round nucleus with small karyosome in the center The PCR and immunohistochemistry from paraffinembedded brain specimen revealed angioinvasive encephalitis due to B mandrillaris Human case of B mandrillaris brain infection are rare in Japan with only a few brief report in the literature
# Cosine Similarity : 0.6040632640867449
#
#
# Document: DOI 101093cidciv017 PMCID PMC4627687 PMID 25595746 Indexed for MEDLINE
# Cosine Similarity : 0.6037707453217174
#
#
# Document: DOI 101371journalpone0241738 PMCID PMC7990177 PMID 33760815 Indexed for MEDLINE
# Cosine Similarity : 0.6018023282810884
#
#
# Document: A Case of Primary Amebic Meningoencephalitis Associated with Surfing at an Artificial Surf Venue Environmental Investigation
# Cosine Similarity : 0.5993128561095379
#
#
# Document: Author information 1Department of Pathology  Applied Neurobiology Graduate School of Medical Science Kyoto Prefectural University of Medicine Kyoto Japan
# Cosine Similarity : 0.5992037019379148
#
#
# Document: Cope JR1 Ratard RC2 Hill VR1 Sokol T2 Causey JJ2 Yoder JS1 Mirani G3 Mull B1 Mukerjee KA3 Narayanan J1 Doucet M3 Qvarnstrom Y1 Poole CN3 Akingbola OA3 Ritter JM1 Xiong Z3 da Silva AJ1 Roellig D1 Van Dyke RB3 Stern H3 Xiao L1 Beach MJ1
# Cosine Similarity : 0.5957425556790704
#
#
# Document: INTRODUCTION Primary amoebic meningoencephalitis PAM is a rare disease caused by the freeliving amoeba Naegleria fowleri Infection occurs by insufflation of water containing amoeba into the nasal cavity and is usually associated with bathing in freshwater Nasal irrigation is a more rarely reported route of infection CASE PRESENTATION A fatal case of PAM in a previously healthy Norwegian woman acquired during a holiday trip to Thailand is described Clinical finding were consistent with rapidly progressing meningoencephalitis The cause of infection wa discovered by chance owing to the unexpected detection of N fowleri DNA by a PCR assay targeting fungi A conclusive diagnosis wa established based on sequencing of N fowleri DNA from brain biopsy supported by histopathological finding Nasal irrigation using contaminated tap water is suspected a the source of infection CONCLUSION The clinical presentation of PAM is very similar to severe bacterial meningitis This case is a reminder that when standard investigation fail to identify a cause of infection in severe meningoencephalitis it is of crucial importance to continue a broad search for a conclusive diagnosis PAM should be considered a a diagnosis in patient with symptom of severe meningoencephalitis returning from endemic area
# Cosine Similarity : 0.5948295218375931
#
#
# Document: Miko S1 Cope JR1 Hlavsa MC1 Ali IKM1 Brown TW1 Collins JP1 Greeley RD2 Kahler AM1 Moore KO3 Roundtree AV14 Roy S1 Sanders LL5 Shah V5 Stuteville HD3 Mattioli MC1
# Cosine Similarity : 0.5860697761494829
#
#
# Document: DOI 103389fmicb20221056418 PMCID PMC9928731 PMID 36817109
# Cosine Similarity : 0.5825932467341873
#
#
# Document: Author information 1Laboratoire de biologie Centre hospitalier départemental FélixGuyon SaintDenis La Réunion France mcjaffarchdfguyonfr
# Cosine Similarity : 0.5818635079775565
#
#
# Document: DOI 101111neup12151 PMID 25186798 Indexed for MEDLINE
# Cosine Similarity : 0.5814755319632351
#
#
# Document: Itoh K1 Yagita K Nozaki T Katano H Hasegawa H Matsuo K Hosokawa Y Tando S Fushiki S
# Cosine Similarity : 0.5762107848780704
#
#
# Document: Author information 1Department of Medicine Division Allergy and Infectious Disease Center for Emerging and Reemerging Infectious Disease CERID University of Washington Seattle Washington United States of America 2Seattle Structural Genomics Center for Infectious Diseases Seattle Washington United States of America 3Department of Biology Washington University St Louis Missouri United States of America 4UCB Pharma Bainbridge Island Washington United States of America 5Seattle Childrens Research Institute Seattle Washington United States of America 6Department of Pediatrics University of Washington Seattle Washington United States of America 7Department of Biomedical Informatics  Medical Education University of Washington Seattle Washington United States of America 8Department of Global Health Pathobiology University of Washington Seattle Washington United States of America 9Center for Tropical and Emerging Global Diseases University of Georgia Athens Georgia United States of America 10Eukaryotic Pathogens Innovation Center Department of Genetics and Biochemistry Clemson University Clemson South Carolina United States of America 11Department of Chemistry University of South Florida Tampa Florida United States of America 12Department of Chemistry and Chemical Biology and Department of Pharmaceutical Sciences Northeastern University Boston Massachusetts United States of America
# Cosine Similarity : 0.5759031039104932
#
#
# Document: DOI 101128mSphere0063721 PMCID PMC8386437 PMID 34378985 Indexed for MEDLINE
# Cosine Similarity : 0.574217537037929
#
#
# Document: 8 JMM Case Rep 2016 Jun 2533e005042 doi 101099jmmcr0005042 eCollection 2016 Jun
# Cosine Similarity : 0.5729511318603882
#
#
# Document: Comment in Pediatr Infect Dis J 2021 Apr 1404358
# Cosine Similarity : 0.5696560245351575
#
#
# Document: Conflict of interest statement The author declare that the research wa conducted in the absence of any commercial or financial relationship that could be construed a a potential conflict of interest
# Cosine Similarity : 0.5692062931153474
#
#
# Document: Yoder JS1 StraifBourgeois S Roy SL Moore TA Visvesvara GS Ratard RC Hill VR Wilson JD Linscott AJ Crager R Kozak NA Sriram R Narayanan J Mull B Kahler AM Schneeberger C da Silva AJ Poudel M Baumgarten KL Xiao L Beach MJ
# Cosine Similarity : 0.5642346897484516
#
#
# Document: Centers for Disease Control and Prevention CDC
# Cosine Similarity : 0.5640980651687043
#
#
# Document: 5 Emerg Infect Dis 2021 Jan271271274 doi 103201eid2701202119
# Cosine Similarity : 0.5597582717418882
#
#
# Document: Zyserman I1 Mondal D2 Sarabia F2 McKerrow JH1 Roush WR2 Debnath A3
# Cosine Similarity : 0.5573675483766893
#
#
# Document: BACKGROUND Naegleria fowleri is a climatesensitive thermophilic ameba found in warm freshwater lake and river Primary amebic meningoencephalitis PAM which is almost universally fatal occurs when N fowlericontaining water enters the nose typically during swimming and migrates to the brain via the olfactory nerve In August 2013 a 4yearold boy died of meningoencephalitis of unknown etiology in a Louisiana hospital METHODS Clinical and environmental testing and a case investigation were initiated to determine the cause of death and to identify potential exposure RESULTS Based on testing of cerebrospinal fluid and brain specimen the child wa diagnosed with PAM His only reported water exposure wa tap water in particular tap water that wa used to supply water to a lawn water slide on which the child had played extensively prior to becoming ill Water sample were collected from both the home and the water distribution system that supplied the home and tested N fowleri wa identified in water sample from both the home and the water distribution system CONCLUSIONS This case is the first reported PAM death associated with culturable N fowleri in tap water from a US treated drinking water system This case occurred in the context of an expanding geographic range for PAM beyond southern state with recent case report from Minnesota Kansas and Indiana This case also highlight the role of adequate disinfection throughout drinking water distribution system and the importance of maintaining vigilance when operating drinking water system using source water with elevated temperature
# Cosine Similarity : 0.5538476235442181
#
#
# Document: BACKGROUND Naegleria fowleri is a climatesensitive thermophilic ameba found in the environment including warm freshwater lake and river Primary amebic meningoencephalitis PAM which is almost universally fatal occurs when N fowlericontaining water enters the nose typically during swimming and N fowleri migrates to the brain via the olfactory nerve In 2011 2 adult died in Louisiana hospital of infectious meningoencephalitis after brief illness METHODS Clinical and environmental testing and case investigation were initiated to determine the cause of death and to identify the exposure RESULTS Both patient had diagnosis of PAM Their only reported water exposure were tap water used for household activity including regular sinus irrigation with neti pot Water sample tap swab sample and neti pot were collected from both household and tested N fowleri were identified in water sample from both home CONCLUSIONS These are the first reported PAM case in the United States associated with the presence of N fowleri in household plumbing served by treated municipal water supply and the first report of PAM potentially associated with the use of a nasal irrigation device These case occurred in the context of an expanding geographic range for PAM beyond southern tier state with recent case report from Minnesota Kansas and Virginia These infection introduce an additional consideration for physician recommending nasal irrigation and demonstrate the importance of using appropriate water distilled boiled filtered for nasal irrigation Furthermore the changing epidemiology of PAM highlight the importance of raising awareness about this disease among physician treating person showing meningitislike symptom
# Cosine Similarity : 0.5529195214897318
#
#
# Document: Author information 1Center for Discovery and Innovation in Parasitic Diseases Skaggs School of Pharmacy and Pharmaceutical Sciences University of California San Diego 9500 Gilman Drive MC0755 La Jolla CA 920930755 USA 2The Scripps Research Institute Scripps Florida 130 Scripps Way 3A2 Jupiter FL 33458 USA 3Center for Discovery and Innovation in Parasitic Diseases Skaggs School of Pharmacy and Pharmaceutical Sciences University of California San Diego 9500 Gilman Drive MC0755 La Jolla CA 920930755 USA Electronic address adebnathucsdedu
# Cosine Similarity : 0.551009123898653
#
#
# Document: 11 MMWR Morb Mortal Wkly Rep 2013 Nov 156245903
# Cosine Similarity : 0.5506489397131134
#
#
# Document: Gharpure R Gleason M Salah Z Blackstock AJ HessHomeier D Yoder JS Ali IKM Collier SA Cope JR
# Cosine Similarity : 0.5505676473107209
#
#
# Document: INTRODUCTION Freeliving amoeba of the Naegleria genus belong to the major protist clade Heterolobosea and are ubiquitously distributed in soil and freshwater habitat Of the 47 Naegleria specie described N fowleri is the only one being pathogenic to human causing a rare but fulminant primary amoebic meningoencephalitis Some Naegleria genome sequence are publicly available but the genetic basis for Naegleria diversity and ability to thrive in diverse environment including human brain remains unclear METHODS Herein we constructed a highquality Naegleria genus pangenome to obtain a comprehensive catalog of gene encoded by these amoeba For this we first sequenced assembled and annotated six new Naegleria genome RESULTS AND DISCUSSION Genome architecture analysis revealed that Naegleria may use genome plasticity feature such a ploidyaneuploidy to modulate their behavior in different environment When comparing 14 neartocomplete genome sequence our result estimated the theoretical Naegleria pangenome a a closed genome with 13943 gene including 3563 core and 10380 accessory gene The functional annotation revealed that a large fraction of Naegleria gene show significant sequence similarity with those already described in other kingdom namely Animalia and Plantae Comparative analysis highlighted a remarkable genomic heterogeneity even for closely related strain and demonstrate that Naegleria harbor extensive genome variability reflected in different metabolic repertoire If Naegleria core genome wa enriched in conserved gene essential for metabolic regulatory and survival process the accessory genome revealed the presence of gene involved in stress response macromolecule modification cell signaling and immune response Commonly reported N fowleri virulenceassociated gene were present in both core and accessory genome suggesting that N fowleris ability to infect human brain could be related to it unique speciesspecific gene mostly of unknown function andor to differential gene expression The construction of Naegleria first pangenome allowed u to move away from a single reference genome that doe not necessarily represent each specie a a whole and to identify essential and dispensable gene in Naegleria evolution diversity and biology paving the way for further genomic and postgenomic study
# Cosine Similarity : 0.5504981652131107
#
#
# Document: 9 Clin Infect Dis 2015 Apr 15608e3642 doi 101093cidciv017 Epub 2015 Jan 16
# Cosine Similarity : 0.5488455673480486
#
#
# Document: DOI 101021acsestwater2c00592 PMCID PMC10193442 PMID 37213412
# Cosine Similarity : 0.5459893518784216
#
#
# Document: Stubhaug TT1 Reiakvam OM2 Stensvold CR3 Hermansen NO1 HolbergPetersen M1 Antal EA4 Gaustad K5 Førde IS5 Heger B2
# Cosine Similarity : 0.5454252435153154
#
#
# Document: Author information 1Institut Pasteur de la Guadeloupe Unité TReDPath Les Abymes Guadeloupe France 2Institut Pasteur de Paris Biomics Paris France 3Scientific Institute of Public Health Brussels Belgium 4Centers for Disease Control and Prevention CDC Atlanta GA United States
# Cosine Similarity : 0.5387036744397998
#
#
# Document: 4 PLoS One 2021 Mar 24163e0241738 doi 101371journalpone0241738 eCollection 2021
# Cosine Similarity : 0.5384940712227414
#
#
# Document: Acanthamoeba culbertsoni is one of the freeliving amoeba which are known to be pathogenic to man causing granulomatous amoebic encephalitis GAE In this study Acanthamoeba culbertsoni wa isolated from a water sample of ElMahmoudia Canal in Alexandria in July1993 This wa used to infect mouse intranasally to study the histopathological picture of the brain and lung The neuropathological feature consisted of chronic granulomatous encephalitis in which cyst and trophozoite were found Associated Acanthamoeba pneumonitis with massive consolidation wa also observed Congenital infection of offspring wa reported for the first time in this study
# Cosine Similarity : 0.5351684789610273
#
#
# Document: Author information 1Department of Microbiology Oslo University Hospital  Ullevaal Oslo Norway 2Department of Infectious Diseases Oslo University Hospital  Ullevaal Oslo Norway 3Department of Microbiology and Infection Control Statens Serum Institut Copenhagen Denmark 4Department of Pathology Oslo University Hospital  Rikshospitalet Oslo Norway 5Department of Anaesthesiology Oslo University Hospital  Ullevaal Oslo Norway
# Cosine Similarity : 0.529248256759832
#
#
# Document: 12 Clin Infect Dis 2012 Nov559e7985 doi 101093cidcis626 Epub 2012 Aug 22
# Cosine Similarity : 0.526548503205324
#
#
# Document: DOI 101093cidcis626 PMID 22919000 Indexed for MEDLINE
# Cosine Similarity : 0.5250940297432236
#
#
# Document: Out of over 40 specie of Naegleria which are freeliving thermophilic ameba found in freshwater and soil worldwide only Naegleria fowleri infects human causing primary amebic meningoencephalitis PAM a typically fatal brain disease To understand the population structure of Naegleria specie and the genetic relationship between N fowleri isolates and to detect pathogenic factor we characterized 52 novel clinical and environmental N fowleri genome and a single Naegleria lovaniensis strain along with transcriptomic data for a subset of 37 N fowleri isolates Wholegenome analysis of 56 isolates from three Naegleria specie N fowleri N lovaniensis and Naegleria gruberi identified several gene unique to N fowleri that have previously been linked to the pathogenicity of N fowleri while other unique gene could be associated with novel pathogenicity factor in this highly fatal pathogen Population structure analysis estimated the presence of 10 population within the three Naegleria specie of which 7 population were within N fowleri The wholenucleargenome WNG phylogenetic analysis showed an overall geographical clustering of N fowleri isolates with few exception and provided higher resolution in identifying potential cluster of isolates beyond that of the traditional locus typing There were only 34 gene that showed significant difference in gene expression between the clinical and environmental isolates Genomic data generated in this study can be used for developing rapid molecular assay and to conduct future populationbased global genomic analysis and will also be a valuable addition to genomic reference database where shotgun metagenomics data from routine water sample could be searched for the presence of N fowleri strain IMPORTANCE N fowleri the only known Naegleria specie to infect human cause fatal brain disease PAM case from 1965 to 2016 showed 20 case per year globally Out of approximately 150 case in North America since 1962 only four PAM survivor are known yielding a 97 case fatality rate which is critically high Although the pathogenesis of N fowleri ha been studied for the last 50 year pathogenetic factor that lead to human infection and breaching the bloodbrain barrier remain unknown In addition little is known regarding the genomic diversity both within N fowleri isolates and among Naegleria specie In this study we generated novel genome sequence and performed comparative genomic and transcriptomic analysis of a set of 52 N fowleri draft genome sequence from clinical and environmental isolates derived from all over the world in the last 53 year which will help shape future genomewide study and develop sensitive assay for routine surveillance
# Cosine Similarity : 0.5228831702415262
#
#
# Document: Awadalla HN1 Sadaka HA
# Cosine Similarity : 0.5213751863650119
#
#
# Document: Author information 1Waterborne Disease Prevention Branch Centers for Disease Control and Prevention Atlanta Georgia 2Mount Carmel Hospital Columbus Ohio 3Ohio Department of Health Columbus 4Mecklenburg County Health Department Charlotte North Carolina 5North Carolina Department of Health and Human Services Raleigh 6Franklin County Public Health Columbus Ohio
# Cosine Similarity : 0.5210208458362687
#
#
# Document: Tillery L12 Barrett K12 Goldstein J3 Lassner JW3 Osterhout B3 Tran NL3 Xu L3 Young RM3 Craig J12 Chun I12 Dranow DM24 Abendroth J24 Delker SL24 Davies DR24 Mayclin SJ24 Calhoun B24 Bolejack MJ24 Staker B25 Subramanian S25 Phan I25 Lorimer DD24 Myler PJ25678 Edwards TE24 Kyle DE9 Rice CA9 Morris JC10 Leahy JW11 Manetsch R12 Barrett LK12 Smith CL3 Van Voorhis WC128
# Cosine Similarity : 0.5195062605331165
#
#
# Document: 10 Neuropathology 2015 Feb351649 doi 101111neup12151 Epub 2014 Sep 3
# Cosine Similarity : 0.5174855870810253
#
#
# Document: Author information 1US Centers for Disease Control and Prevention 1600 Clifton Rd NE Atlanta GA 30333 2New Jersey Department of Health P O Box 360 Trenton NJ 086250360 3Texas Department of State Health Services PO Box 149347 Austin TX 787149347 4Chenega Enterprise System  Solutions 609 Independence Parkway Suite 210 Chesapeake VA 23320 5WacoMcLennan County Public Health District 225 W Waco Dr Waco TX 76707
# Cosine Similarity : 0.5123407321049047
#
#
# Document: The first association of a primary amebic meningoencephalitis death with culturable Naegleria fowleri in tap water from a US treated public drinking water system
# Cosine Similarity : 0.5103485603675634
#
#
# Document: Naegleria fowleri is a pathogenic thermophilic freeliving amoeba which cause primary amebic meningoencephalitis PAM Penetrating the olfactory mucosa the braineating amoeba travel along the olfactory nerve burrowing through the cribriform plate to it destination the brain frontal lobe The amoeba thrives in warm freshwater environment with peak infection rate in the summer month and ha a mortality rate of approximately 97 A major contributor to the pathogen high mortality is the lack of sensitivity of N fowleri to current drug therapy even in the face of combinationdrug therapy To enable rational drug discovery and design effort we have pursued protein production and crystallographybased structure determination effort for likely drug target from N fowleri The gene were selected if they had homology to drug target listed in Drug Bank or were nominated by primary investigator engaged in N fowleri research In 2017 178 N fowleri protein target were queued to the Seattle Structural Genomics Center of Infectious Disease SSGCID pipeline and to date 89 soluble recombinant protein and 19 unique target structure have been produced Many of the new protein structure are potential drug target and contain structural difference compared to their human homologs which could allow for the development of pathogenspecific inhibitor Five of the structure were analyzed in more detail and four of five show promise that selective inhibitor of the active site could be found The 19 solved crystal structure build a foundation for future work in combating this devastating disease by encouraging further investigation to stimulate drug discovery for this neglected pathogen
# Cosine Similarity : 0.507129525254278
#
#
# Document: Conflict of interest statement The author have read the journal’s policy and have the following competing interest DMD JA SLD DRD SJM BC MJB DDL and TEE are employee of UCB Pharma The LSCAT Sector 21 wa supported by a grant from the Michigan Economic Development Corporation This doe not alter our adherence to PLOS ONE policy on sharing data and material There are no patent product in development or marketed product associated with this research to declare
# Cosine Similarity : 0.5004293859228696
#
#
# Document: DOI 101099jmmcr0005042 PMCID PMC5330229 PMID 28348761
# Cosine Similarity : 0.4961500881305781
#
#
# Document: 6 Exp Parasitol 2018 May1883641 doi 101016jexppara201803010 Epub 2018 Mar 15
# Cosine Similarity : 0.4827578505651593
#
#
# Document: Naegleria fowleri is a thermophilic ameba found in freshwater that cause primary amebic meningoencephalitis PAM when it enters the nose and migrates to the brain In September 2018 a 29yearold man died of PAM after traveling to Texas We conducted an epidemiologic and environmental investigation to identify the water exposure associated with this PAM case The patient most probable water exposure occurred while surfing in an artificial surf venue The surf venue water wa not filtered or recirculated water disinfection and water quality testing were not documented N fowleri and thermophilic ameba were detected in recreational water and sediment sample throughout the facility Codes and standard for treated recreational water venue open to the public could be developed to address these novel venue Clinicians and public health official should also consider novel recreational water venue a a potential exposure for this rare amebic infection
# Cosine Similarity : 0.47956126866078286
#
#
# Document: Naegleria fowleri is a freeliving ameba that cause primary amebic meningoencephalitis PAM a rare but usually fatal disease We analyzed trend in recreational water exposure associated with PAM case reported during 19782018 in the United States Although PAM incidence remained stable the geographic range of exposure location expanded northward
# Cosine Similarity : 0.47850038326591854
#
#
# Document: 3 mSphere 2021 Aug 2564e0063721 doi 101128mSphere0063721 Epub 2021 Aug 11
# Cosine Similarity : 0.4381471354113802
#
#
# Document: 14 J Egypt Soc Parasitol 1996 Dec2636018
# Cosine Similarity : 0.43446796037741137
#
#
# Document: 13 Bull Soc Pathol Exot 2005 Apr981113
# Cosine Similarity : 0.40369625805915527
#
#
# Document: The primary amebic meningoencephalitis is an acute suppurative infection that involves both the brain and the meninges It is caused by Naegleria fowleri and is a very rare and fulminating condition so far nearly always fatal We report the first case in the area of Southern part of Indian Ocean that occured in a 7year old French boy living in Madagascar It is assumed that the disease wa contracted by swimming in warm fresh water in a lake of the Madagascar east coast Clinical sign began 1012 day after exposure associating headache vomiting and pyrexia 3940 degree C Upon admission in a Madagascar hospital the patient wa started on antibiotic that did not control the disease and soon presented with a loss of consciousness and a delirium He wa transferred to Reunion island Centre Hospitalier Départemental FélixGuyon where the diagnosis of primary amebic meningoencephalitis wa confirmed Therefore he wa started on highdose of intraspinal amphotericin B IV amphotericin B lipid complex and tetracycline He developed myocarditis diabetes insipidus deep coma and subsequently died a week later The diagnosis of amebic meningoencephalitis wa based on  the cerebrospinal fluid examination that confirmed the diagnosis of purulent meningitis 420 leucocyte 76 polynuclears 14 lymphocyte 90 red blood cell and showed 50 ameboid trophozoite per 100 leucocyte approximately 20 microm in size  the flagellate transformation test in distilled water showed two anterior flagellas that confirmed the genus Naegleria
# Cosine Similarity : 0.3878227066050571
#
#
# Document: Primary amebic meningoencephalitis PAM is a rapidly fatal infection caused by the freeliving ameba Naegleria fowleri PAM occurs principally in healthy child of le than 13 year old with a history of recent exposure to warm fresh water While a yet not a reportable disease the Centers for Disease Control and Prevention CDC document a total of 143 case in the United States Only four patient have survived Infection result from water containing N fowleri entering the nose followed by migration of the ameba to the brain Within the brain N fowleri infection result in extensive necrosis leading to death in 37 day Mortality among patient with PAM is greater than 95 The drug of choice in treating PAM are the antifungal amphotericin B and the antileishmanial miltefosine However neither drug is FDAapproved for this indication and the use of amphotericin B is associated with severe adverse effect Moreover very few patient treated with amphotericin B have survived PAM Therefore development of new safe and effective drug is a critical unmet need to avert future death of child The molecular mechanism underlying the pathogenesis of PAM are poorly understood but it is known that cysteine protease of N fowleri play a role in the progression of PAM We therefore assessed the in vitro activity of the synthetic vinyl sulfone cysteine protease inhibitor K11777 and 33 analog with valine phenylalanine or pyridylalanine at P2 position against cysteine protease activity in the lysate of N fowleri Inhibitors with phenylalanine or pyridylalanine at P2 position were particularly effective in inhibiting the cysteine protease activity of N fowleri cell lysate with IC50 ranging between 3 nM and 66 μM Three of the 34 inhibitor also showed inhibitory activity against N fowleri in a cell viability assay and were 16 to 25fold more potent than the standard of care drug miltefosine Our study provides the first evidence of the activity of synthetic small molecule cysteine protease inhibitor against N fowleri
# Cosine Similarity : 0.3619576527279774
#
#
# Document: BACKGROUND Naegleria fowleri is a thermophilic ameba found in freshwater that cause primary amebic meningoencephalitis PAM when it enters the nose and migrates to the brain Patient exposure to water containing the ameba typically occurs in warm freshwater lake and pond during recreational water activity In June 2016 an 18yearold woman died of PAM after traveling to North Carolina where she participated in rafting on an artificial whitewater river METHODS We conducted an epidemiologic and environmental investigation to determine the water exposure that led to the death of this patient RESULTS The case patient most probable water exposure occurred while rafting on an artificial whitewater river during which she wa thrown out of the raft and submerged underwater The approximately 115 million gallon of water in the whitewater facility were partially filtered subjected to ultraviolet light treatment and occasionally chlorinated Heavy algal growth wa noted Eleven waterrelated sample were collected from the facility all were positive for N fowleri Of 5 sample collected from the nearby natural river 1 sediment sample wa positive for N fowleri CONCLUSIONS This investigation document a novel exposure to an artificial whitewater river a the likely exposure causing PAM in this case Conditions in the whitewater facility warm turbid water with little chlorine and heavy algal growth rendered the water treatment ineffective and provided an ideal environment for N fowleri to thrive The combination of natural and engineered element at the whitewater facility created a challenging environment to control the growth of N fowleri
# Cosine Similarity : 0.351803453306532
#
#
# Document: On November 21 2012 the US Virgin Islands USVI Department of Health documented the first case and death from primary amebic meningoencephalitis PAM in the territory PAM a rare and almost universally fatal condition result when Naegleria fowleri a freeliving thermophilic ameba found in warm freshwater enters the nose and migrates to the brain The patient wa a man aged 47 year whose only reported freshwater exposure were the use of tap water for daily household activity and for ablution a ritual cleansing that he practiced several time a day in preparation for Islamic prayer Ablution can include nasal rinsing On November 16 2012 the patient had visited the emergency department with a headache he wa treated symptomatically and released The following day the patient returned to the emergency department by ambulance with fever confusion agitation and a severe headache for which he wa admitted Cerebrospinal fluid CSF study were consistent with bacterial meningitis and antibiotic were started On November 18 neurologic finding included fixed nonresponsive pupil no response in the upper or lower extremity muted plantar response and no response to verbal command Microscopic examination of the CSF obtained from a second lumbar puncture revealed motile amebic trophozoite CSF specimen sent to CDC for confirmatory testing were positive for N fowleri by realtime polymerase chain reaction testing On the morning of November 21 the patient wa pronounced brain dead based on neurologic criterion
# Cosine Similarity : 0.2863975876104245

# %% [markdown]
# **Sentence Transformer**

# %% [markdown]
# Sentence Transformers is a versatile toolkit designed for creating fixed-length numerical representations, or embeddings, of sentences and short texts. It harnesses the power of pre-trained transformer models like BERT, RoBERTa, or DistilBERT to encode input sentences into dense vector representations. These embeddings effectively capture the semantic meaning of the sentences, enabling a wide range of downstream tasks such as semantic similarity assessment, text classification, or clustering. In our case, we're utilizing the **all-mpnet-base-v2** variant, which is built on the MPNet architecture.

# %% [markdown]
# The upcoming  code initializes a Sentence Transformers model using the **all-mpnet-base-v2** variant, which is based on the MPNet architecture. The model is capable of generating high-quality sentence embeddings for a wide range of natural language processing task

# %%
sbert_model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# 1_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %% [markdown]
# We'll employ the previously loaded model to create embeddings for a collection of documents containing both questions and answers, which together constitute the training set

# %%
document_embeddings = sbert_model.encode(question_documents_train_set)

# %% [markdown]
# Let's calculates pairwise similarities and differences between document embeddings using cosine similarity

# %%
pairwise_similarities=cosine_similarity(document_embeddings)
pairwise_differences=euclidean_distances(document_embeddings)

# %% [markdown]
# Let's retrieve the most similar documents

# %%
most_similar(0,pairwise_similarities,'Cosine Similarity')
# Out:
# Document: What cause amoebic brain disease and is associated with freshwater source
#
#
# Similar Documents using Cosine Similarity:
# [ 0 67 73 53 92 76 64 42  5 86 45  2 50 32 59 79 19 56 82 29 11 71 38 68
#  66 18 63 44  6 25 89 85 22 75 55 41 52 10 28 20 33 69 61  8 78 74 91 47
#  40 80 26 58 37 31  1 60 46  4 24 72  7 87 54 93 16 13 21 34 88 14 49 35
#  15 27 81 39 90 83 62 48 84 57 36 70  3  9 77 23 51 65 43 17 30 12]
#
#
# Document: Balamuthia mandrillaris is an amoeba found in fresh water and soil that cause granulomatous amoebic encephalitis We report herein an autopsy case of B mandrillaris amoebic encephalitis which wa definitely diagnosed by PCR An 81yearold man who had Sjögrens syndrome manifested drowsiness 2 month before his death with progressive deterioration Neuroimaging demonstrated focus of T2 and fluidattenuated inversion recovery high and T1 lowintensity with irregular postcontrast ring enhancement in the cerebral hemisphere thalamus and midbrain Pathologically multiple hemorrhagic and necrotic lesion were found in the cerebrum thalamus midbrain pons medulla and cerebellum which were characterized by liquefactive necrosis marked edema hemorrhage and necrotizing vasculitis associated with the perivascular accumulation of amoebic trophozoite a few cyst and the infiltration of numerous neutrophil and microgliamacrophages The trophozoite were ovoid or round 1060 μm in diameter and they showed foamy cytoplasm and a round nucleus with small karyosome in the center The PCR and immunohistochemistry from paraffinembedded brain specimen revealed angioinvasive encephalitis due to B mandrillaris Human case of B mandrillaris brain infection are rare in Japan with only a few brief report in the literature
# Cosine Similarity : 0.6959260106086731
#
#
# Document: On November 21 2012 the US Virgin Islands USVI Department of Health documented the first case and death from primary amebic meningoencephalitis PAM in the territory PAM a rare and almost universally fatal condition result when Naegleria fowleri a freeliving thermophilic ameba found in warm freshwater enters the nose and migrates to the brain The patient wa a man aged 47 year whose only reported freshwater exposure were the use of tap water for daily household activity and for ablution a ritual cleansing that he practiced several time a day in preparation for Islamic prayer Ablution can include nasal rinsing On November 16 2012 the patient had visited the emergency department with a headache he wa treated symptomatically and released The following day the patient returned to the emergency department by ambulance with fever confusion agitation and a severe headache for which he wa admitted Cerebrospinal fluid CSF study were consistent with bacterial meningitis and antibiotic were started On November 18 neurologic finding included fixed nonresponsive pupil no response in the upper or lower extremity muted plantar response and no response to verbal command Microscopic examination of the CSF obtained from a second lumbar puncture revealed motile amebic trophozoite CSF specimen sent to CDC for confirmatory testing were positive for N fowleri by realtime polymerase chain reaction testing On the morning of November 21 the patient wa pronounced brain dead based on neurologic criterion
# Cosine Similarity : 0.6362990140914917
#
#
# Document: INTRODUCTION Primary amoebic meningoencephalitis PAM is a rare disease caused by the freeliving amoeba Naegleria fowleri Infection occurs by insufflation of water containing amoeba into the nasal cavity and is usually associated with bathing in freshwater Nasal irrigation is a more rarely reported route of infection CASE PRESENTATION A fatal case of PAM in a previously healthy Norwegian woman acquired during a holiday trip to Thailand is described Clinical finding were consistent with rapidly progressing meningoencephalitis The cause of infection wa discovered by chance owing to the unexpected detection of N fowleri DNA by a PCR assay targeting fungi A conclusive diagnosis wa established based on sequencing of N fowleri DNA from brain biopsy supported by histopathological finding Nasal irrigation using contaminated tap water is suspected a the source of infection CONCLUSION The clinical presentation of PAM is very similar to severe bacterial meningitis This case is a reminder that when standard investigation fail to identify a cause of infection in severe meningoencephalitis it is of crucial importance to continue a broad search for a conclusive diagnosis PAM should be considered a a diagnosis in patient with symptom of severe meningoencephalitis returning from endemic area
# Cosine Similarity : 0.629975438117981
#
#
# Document: Acanthamoeba culbertsoni is one of the freeliving amoeba which are known to be pathogenic to man causing granulomatous amoebic encephalitis GAE In this study Acanthamoeba culbertsoni wa isolated from a water sample of ElMahmoudia Canal in Alexandria in July1993 This wa used to infect mouse intranasally to study the histopathological picture of the brain and lung The neuropathological feature consisted of chronic granulomatous encephalitis in which cyst and trophozoite were found Associated Acanthamoeba pneumonitis with massive consolidation wa also observed Congenital infection of offspring wa reported for the first time in this study
# Cosine Similarity : 0.6196944117546082
#
#
# Document: Primary amebic meningoencephalitis death associated with sinus irrigation using contaminated tap water
# Cosine Similarity : 0.6171989440917969
#
#
# Document: An autopsy case of Balamuthia mandrillaris amoebic encephalitis a rare emerging infectious disease with a brief review of the case reported in Japan
# Cosine Similarity : 0.6023877859115601
#
#
# Document: Primary Amebic Meningoencephalitis Associated With Rafting on an Artificial Whitewater River Case Report and Environmental Investigation
# Cosine Similarity : 0.5898062586784363
#
#
# Document: Naegleria fowleri is a thermophilic ameba found in freshwater that cause primary amebic meningoencephalitis PAM when it enters the nose and migrates to the brain In September 2018 a 29yearold man died of PAM after traveling to Texas We conducted an epidemiologic and environmental investigation to identify the water exposure associated with this PAM case The patient most probable water exposure occurred while surfing in an artificial surf venue The surf venue water wa not filtered or recirculated water disinfection and water quality testing were not documented N fowleri and thermophilic ameba were detected in recreational water and sediment sample throughout the facility Codes and standard for treated recreational water venue open to the public could be developed to address these novel venue Clinicians and public health official should also consider novel recreational water venue a a potential exposure for this rare amebic infection
# Cosine Similarity : 0.5870835781097412
#
#
# Document: The primary amebic meningoencephalitis is an acute suppurative infection that involves both the brain and the meninges It is caused by Naegleria fowleri and is a very rare and fulminating condition so far nearly always fatal We report the first case in the area of Southern part of Indian Ocean that occured in a 7year old French boy living in Madagascar It is assumed that the disease wa contracted by swimming in warm fresh water in a lake of the Madagascar east coast Clinical sign began 1012 day after exposure associating headache vomiting and pyrexia 3940 degree C Upon admission in a Madagascar hospital the patient wa started on antibiotic that did not control the disease and soon presented with a loss of consciousness and a delirium He wa transferred to Reunion island Centre Hospitalier Départemental FélixGuyon where the diagnosis of primary amebic meningoencephalitis wa confirmed Therefore he wa started on highdose of intraspinal amphotericin B IV amphotericin B lipid complex and tetracycline He developed myocarditis diabetes insipidus deep coma and subsequently died a week later The diagnosis of amebic meningoencephalitis wa based on  the cerebrospinal fluid examination that confirmed the diagnosis of purulent meningitis 420 leucocyte 76 polynuclears 14 lymphocyte 90 red blood cell and showed 50 ameboid trophozoite per 100 leucocyte approximately 20 microm in size  the flagellate transformation test in distilled water showed two anterior flagellas that confirmed the genus Naegleria
# Cosine Similarity : 0.5823485851287842
#
#
# Document: BACKGROUND Naegleria fowleri is a thermophilic ameba found in freshwater that cause primary amebic meningoencephalitis PAM when it enters the nose and migrates to the brain Patient exposure to water containing the ameba typically occurs in warm freshwater lake and pond during recreational water activity In June 2016 an 18yearold woman died of PAM after traveling to North Carolina where she participated in rafting on an artificial whitewater river METHODS We conducted an epidemiologic and environmental investigation to determine the water exposure that led to the death of this patient RESULTS The case patient most probable water exposure occurred while rafting on an artificial whitewater river during which she wa thrown out of the raft and submerged underwater The approximately 115 million gallon of water in the whitewater facility were partially filtered subjected to ultraviolet light treatment and occasionally chlorinated Heavy algal growth wa noted Eleven waterrelated sample were collected from the facility all were positive for N fowleri Of 5 sample collected from the nearby natural river 1 sediment sample wa positive for N fowleri CONCLUSIONS This investigation document a novel exposure to an artificial whitewater river a the likely exposure causing PAM in this case Conditions in the whitewater facility warm turbid water with little chlorine and heavy algal growth rendered the water treatment ineffective and provided an ideal environment for N fowleri to thrive The combination of natural and engineered element at the whitewater facility created a challenging environment to control the growth of N fowleri
# Cosine Similarity : 0.5715160369873047
#
#
# Document: A Case of Primary Amebic Meningoencephalitis Associated with Surfing at an Artificial Surf Venue Environmental Investigation
# Cosine Similarity : 0.570941686630249
#
#
# Document: Fatal primary amoebic meningoencephalitis in a Norwegian tourist returning from Thailand
# Cosine Similarity : 0.5603888630867004
#
#
# Document: Naegleria fowleri is a freeliving ameba that cause primary amebic meningoencephalitis PAM a rare but usually fatal disease We analyzed trend in recreational water exposure associated with PAM case reported during 19782018 in the United States Although PAM incidence remained stable the geographic range of exposure location expanded northward
# Cosine Similarity : 0.5527989864349365
#
#
# Document: BACKGROUND Naegleria fowleri is a climatesensitive thermophilic ameba found in warm freshwater lake and river Primary amebic meningoencephalitis PAM which is almost universally fatal occurs when N fowlericontaining water enters the nose typically during swimming and migrates to the brain via the olfactory nerve In August 2013 a 4yearold boy died of meningoencephalitis of unknown etiology in a Louisiana hospital METHODS Clinical and environmental testing and a case investigation were initiated to determine the cause of death and to identify potential exposure RESULTS Based on testing of cerebrospinal fluid and brain specimen the child wa diagnosed with PAM His only reported water exposure wa tap water in particular tap water that wa used to supply water to a lawn water slide on which the child had played extensively prior to becoming ill Water sample were collected from both the home and the water distribution system that supplied the home and tested N fowleri wa identified in water sample from both the home and the water distribution system CONCLUSIONS This case is the first reported PAM death associated with culturable N fowleri in tap water from a US treated drinking water system This case occurred in the context of an expanding geographic range for PAM beyond southern state with recent case report from Minnesota Kansas and Indiana This case also highlight the role of adequate disinfection throughout drinking water distribution system and the importance of maintaining vigilance when operating drinking water system using source water with elevated temperature
# Cosine Similarity : 0.5520877838134766
#
#
# Document: BACKGROUND Naegleria fowleri is a climatesensitive thermophilic ameba found in the environment including warm freshwater lake and river Primary amebic meningoencephalitis PAM which is almost universally fatal occurs when N fowlericontaining water enters the nose typically during swimming and N fowleri migrates to the brain via the olfactory nerve In 2011 2 adult died in Louisiana hospital of infectious meningoencephalitis after brief illness METHODS Clinical and environmental testing and case investigation were initiated to determine the cause of death and to identify the exposure RESULTS Both patient had diagnosis of PAM Their only reported water exposure were tap water used for household activity including regular sinus irrigation with neti pot Water sample tap swab sample and neti pot were collected from both household and tested N fowleri were identified in water sample from both home CONCLUSIONS These are the first reported PAM case in the United States associated with the presence of N fowleri in household plumbing served by treated municipal water supply and the first report of PAM potentially associated with the use of a nasal irrigation device These case occurred in the context of an expanding geographic range for PAM beyond southern tier state with recent case report from Minnesota Kansas and Virginia These infection introduce an additional consideration for physician recommending nasal irrigation and demonstrate the importance of using appropriate water distilled boiled filtered for nasal irrigation Furthermore the changing epidemiology of PAM highlight the importance of raising awareness about this disease among physician treating person showing meningitislike symptom
# Cosine Similarity : 0.5312678813934326
#
#
# Document: Out of over 40 specie of Naegleria which are freeliving thermophilic ameba found in freshwater and soil worldwide only Naegleria fowleri infects human causing primary amebic meningoencephalitis PAM a typically fatal brain disease To understand the population structure of Naegleria specie and the genetic relationship between N fowleri isolates and to detect pathogenic factor we characterized 52 novel clinical and environmental N fowleri genome and a single Naegleria lovaniensis strain along with transcriptomic data for a subset of 37 N fowleri isolates Wholegenome analysis of 56 isolates from three Naegleria specie N fowleri N lovaniensis and Naegleria gruberi identified several gene unique to N fowleri that have previously been linked to the pathogenicity of N fowleri while other unique gene could be associated with novel pathogenicity factor in this highly fatal pathogen Population structure analysis estimated the presence of 10 population within the three Naegleria specie of which 7 population were within N fowleri The wholenucleargenome WNG phylogenetic analysis showed an overall geographical clustering of N fowleri isolates with few exception and provided higher resolution in identifying potential cluster of isolates beyond that of the traditional locus typing There were only 34 gene that showed significant difference in gene expression between the clinical and environmental isolates Genomic data generated in this study can be used for developing rapid molecular assay and to conduct future populationbased global genomic analysis and will also be a valuable addition to genomic reference database where shotgun metagenomics data from routine water sample could be searched for the presence of N fowleri strain IMPORTANCE N fowleri the only known Naegleria specie to infect human cause fatal brain disease PAM case from 1965 to 2016 showed 20 case per year globally Out of approximately 150 case in North America since 1962 only four PAM survivor are known yielding a 97 case fatality rate which is critically high Although the pathogenesis of N fowleri ha been studied for the last 50 year pathogenetic factor that lead to human infection and breaching the bloodbrain barrier remain unknown In addition little is known regarding the genomic diversity both within N fowleri isolates and among Naegleria specie In this study we generated novel genome sequence and performed comparative genomic and transcriptomic analysis of a set of 52 N fowleri draft genome sequence from clinical and environmental isolates derived from all over the world in the last 53 year which will help shape future genomewide study and develop sensitive assay for routine surveillance
# Cosine Similarity : 0.5207160711288452
#
#
# Document: The first association of a primary amebic meningoencephalitis death with culturable Naegleria fowleri in tap water from a US treated public drinking water system
# Cosine Similarity : 0.5152726769447327
#
#
# Document: Primary amebic meningoencephalitis 1st case observed in Madagascar
# Cosine Similarity : 0.5015941262245178
#
#
# Document: Geographic Range of Recreational WaterAssociated Primary Amebic Meningoencephalitis United States 19782018
# Cosine Similarity : 0.49093276262283325
#
#
# Document: INTRODUCTION Freeliving amoeba of the Naegleria genus belong to the major protist clade Heterolobosea and are ubiquitously distributed in soil and freshwater habitat Of the 47 Naegleria specie described N fowleri is the only one being pathogenic to human causing a rare but fulminant primary amoebic meningoencephalitis Some Naegleria genome sequence are publicly available but the genetic basis for Naegleria diversity and ability to thrive in diverse environment including human brain remains unclear METHODS Herein we constructed a highquality Naegleria genus pangenome to obtain a comprehensive catalog of gene encoded by these amoeba For this we first sequenced assembled and annotated six new Naegleria genome RESULTS AND DISCUSSION Genome architecture analysis revealed that Naegleria may use genome plasticity feature such a ploidyaneuploidy to modulate their behavior in different environment When comparing 14 neartocomplete genome sequence our result estimated the theoretical Naegleria pangenome a a closed genome with 13943 gene including 3563 core and 10380 accessory gene The functional annotation revealed that a large fraction of Naegleria gene show significant sequence similarity with those already described in other kingdom namely Animalia and Plantae Comparative analysis highlighted a remarkable genomic heterogeneity even for closely related strain and demonstrate that Naegleria harbor extensive genome variability reflected in different metabolic repertoire If Naegleria core genome wa enriched in conserved gene essential for metabolic regulatory and survival process the accessory genome revealed the presence of gene involved in stress response macromolecule modification cell signaling and immune response Commonly reported N fowleri virulenceassociated gene were present in both core and accessory genome suggesting that N fowleris ability to infect human brain could be related to it unique speciesspecific gene mostly of unknown function andor to differential gene expression The construction of Naegleria first pangenome allowed u to move away from a single reference genome that doe not necessarily represent each specie a a whole and to identify essential and dispensable gene in Naegleria evolution diversity and biology paving the way for further genomic and postgenomic study
# Cosine Similarity : 0.4774681329727173
#
#
# Document: Notes from the field primary amebic meningoencephalitis associated with ritual nasal rinsingSt Thomas US Virgin island 2012
# Cosine Similarity : 0.4619860053062439
#
#
# Document: Primary amebic meningoencephalitis PAM is a rapidly fatal infection caused by the freeliving ameba Naegleria fowleri PAM occurs principally in healthy child of le than 13 year old with a history of recent exposure to warm fresh water While a yet not a reportable disease the Centers for Disease Control and Prevention CDC document a total of 143 case in the United States Only four patient have survived Infection result from water containing N fowleri entering the nose followed by migration of the ameba to the brain Within the brain N fowleri infection result in extensive necrosis leading to death in 37 day Mortality among patient with PAM is greater than 95 The drug of choice in treating PAM are the antifungal amphotericin B and the antileishmanial miltefosine However neither drug is FDAapproved for this indication and the use of amphotericin B is associated with severe adverse effect Moreover very few patient treated with amphotericin B have survived PAM Therefore development of new safe and effective drug is a critical unmet need to avert future death of child The molecular mechanism underlying the pathogenesis of PAM are poorly understood but it is known that cysteine protease of N fowleri play a role in the progression of PAM We therefore assessed the in vitro activity of the synthetic vinyl sulfone cysteine protease inhibitor K11777 and 33 analog with valine phenylalanine or pyridylalanine at P2 position against cysteine protease activity in the lysate of N fowleri Inhibitors with phenylalanine or pyridylalanine at P2 position were particularly effective in inhibiting the cysteine protease activity of N fowleri cell lysate with IC50 ranging between 3 nM and 66 μM Three of the 34 inhibitor also showed inhibitory activity against N fowleri in a cell viability assay and were 16 to 25fold more potent than the standard of care drug miltefosine Our study provides the first evidence of the activity of synthetic small molecule cysteine protease inhibitor against N fowleri
# Cosine Similarity : 0.45409148931503296
#
#
# Document: © 2014 Japanese Society of Neuropathology
# Cosine Similarity : 0.4108133614063263
#
#
# Document: Author information 1Department of Pathology  Applied Neurobiology Graduate School of Medical Science Kyoto Prefectural University of Medicine Kyoto Japan
# Cosine Similarity : 0.39487892389297485
#
#
# Document: Author information 1Waterborne Disease Prevention Branch Division of Foodborne Waterborne and Environmental Diseases National Center for Emerging and Zoonotic Infectious Diseases Centers for Disease Control and Preventiongrid416738f Atlanta Georgia USA 2Eagle Medical Services Atlanta Georgia USA
# Cosine Similarity : 0.3876761198043823
#
#
# Document: 10 Neuropathology 2015 Feb351649 doi 101111neup12151 Epub 2014 Sep 3
# Cosine Similarity : 0.38696426153182983
#
#
# Document: Author information 1Waterborne Disease Prevention Branch Centers for Disease Control and Prevention Atlanta Georgia 2Mount Carmel Hospital Columbus Ohio 3Ohio Department of Health Columbus 4Mecklenburg County Health Department Charlotte North Carolina 5North Carolina Department of Health and Human Services Raleigh 6Franklin County Public Health Columbus Ohio
# Cosine Similarity : 0.3715077042579651
#
#
# Document: DOI 101021acsestwater2c00592 PMCID PMC10193442 PMID 37213412
# Cosine Similarity : 0.3694869577884674
#
#
# Document: Naegleria fowleri is a pathogenic thermophilic freeliving amoeba which cause primary amebic meningoencephalitis PAM Penetrating the olfactory mucosa the braineating amoeba travel along the olfactory nerve burrowing through the cribriform plate to it destination the brain frontal lobe The amoeba thrives in warm freshwater environment with peak infection rate in the summer month and ha a mortality rate of approximately 97 A major contributor to the pathogen high mortality is the lack of sensitivity of N fowleri to current drug therapy even in the face of combinationdrug therapy To enable rational drug discovery and design effort we have pursued protein production and crystallographybased structure determination effort for likely drug target from N fowleri The gene were selected if they had homology to drug target listed in Drug Bank or were nominated by primary investigator engaged in N fowleri research In 2017 178 N fowleri protein target were queued to the Seattle Structural Genomics Center of Infectious Disease SSGCID pipeline and to date 89 soluble recombinant protein and 19 unique target structure have been produced Many of the new protein structure are potential drug target and contain structural difference compared to their human homologs which could allow for the development of pathogenspecific inhibitor Five of the structure were analyzed in more detail and four of five show promise that selective inhibitor of the active site could be found The 19 solved crystal structure build a foundation for future work in combating this devastating disease by encouraging further investigation to stimulate drug discovery for this neglected pathogen
# Cosine Similarity : 0.3503948748111725
#
#
# Document: The possibility of congenital infection with Acanthamoeba culbertsoni
# Cosine Similarity : 0.3484306335449219
#
#
# Document: Author information 1Laboratoire de biologie Centre hospitalier départemental FélixGuyon SaintDenis La Réunion France mcjaffarchdfguyonfr
# Cosine Similarity : 0.3425234854221344
#
#
# Document: Naegleria fowleri Protein structure to facilitate drug discovery for the deadly pathogenic freeliving amoeba
# Cosine Similarity : 0.33265596628189087
#
#
# Document: 12 Clin Infect Dis 2012 Nov559e7985 doi 101093cidcis626 Epub 2012 Aug 22
# Cosine Similarity : 0.32274940609931946
#
#
# Document: 9 Clin Infect Dis 2015 Apr 15608e3642 doi 101093cidciv017 Epub 2015 Jan 16
# Cosine Similarity : 0.3127853274345398
#
#
# Document: 7 Clin Infect Dis 2018 Feb 1664548553 doi 101093cidcix810
# Cosine Similarity : 0.3113410472869873
#
#
# Document: Author information 1Department of Microbiology Oslo University Hospital  Ullevaal Oslo Norway 2Department of Infectious Diseases Oslo University Hospital  Ullevaal Oslo Norway 3Department of Microbiology and Infection Control Statens Serum Institut Copenhagen Denmark 4Department of Pathology Oslo University Hospital  Rikshospitalet Oslo Norway 5Department of Anaesthesiology Oslo University Hospital  Ullevaal Oslo Norway
# Cosine Similarity : 0.31061428785324097
#
#
# Document: Author information 1Institut Pasteur de la Guadeloupe Unité TReDPath Les Abymes Guadeloupe France 2Institut Pasteur de Paris Biomics Paris France 3Scientific Institute of Public Health Brussels Belgium 4Centers for Disease Control and Prevention CDC Atlanta GA United States
# Cosine Similarity : 0.3036114275455475
#
#
# Document: 5 Emerg Infect Dis 2021 Jan271271274 doi 103201eid2701202119
# Cosine Similarity : 0.3028983771800995
#
#
# Document: DOI 101128mSphere0063721 PMCID PMC8386437 PMID 34378985 Indexed for MEDLINE
# Cosine Similarity : 0.3002086281776428
#
#
# Document: DOI 103201eid2701202119 PMCID PMC7774533 PMID 33350926 Indexed for MEDLINE
# Cosine Similarity : 0.29617753624916077
#
#
# Document: DOI 101111neup12151 PMID 25186798 Indexed for MEDLINE
# Cosine Similarity : 0.2879619002342224
#
#
# Document: DOI 101093cidciv017 PMCID PMC4627687 PMID 25595746 Indexed for MEDLINE
# Cosine Similarity : 0.28433912992477417
#
#
# Document: Naegleria genus pangenome reveals new structural and functional insight into the versatility of these freeliving amoeba
# Cosine Similarity : 0.2841770052909851
#
#
# Document: Author information 1National Center for Emerging and Zoonotic Infectious Diseases Centers for Disease Control and Prevention1600 Clifton Road Atlanta GA 30329 USA jey9cdcgov
# Cosine Similarity : 0.2835228443145752
#
#
# Document: PMCID PMC4585351 PMID 24226628 Indexed for MEDLINE
# Cosine Similarity : 0.2814106345176697
#
#
# Document: Author information 1Department of Parasitology Faculty of Medicine Alexandria University Egypt
# Cosine Similarity : 0.2802249789237976
#
#
# Document: DOI 101093cidcix810 PMCID PMC5801760 PMID 29401275 Indexed for MEDLINE
# Cosine Similarity : 0.27870821952819824
#
#
# Document: DOI 101016jexppara201803010 PMCID PMC5918159 PMID 29551628 Indexed for MEDLINE
# Cosine Similarity : 0.2772703766822815
#
#
# Document: DOI 101093cidcis626 PMID 22919000 Indexed for MEDLINE
# Cosine Similarity : 0.2759166955947876
#
#
# Document: DOI 101371journalpone0241738 PMCID PMC7990177 PMID 33760815 Indexed for MEDLINE
# Cosine Similarity : 0.27144327759742737
#
#
# Document: Author information 1Centers for Disease Control and Prevention Atlanta Georgia 2Louisiana Department of Health and Hospitals New Orleans and Baton Rouge 3Tulane University Health Sciences Center New Orleans Louisiana
# Cosine Similarity : 0.2625543475151062
#
#
# Document: Author information 1Center for Discovery and Innovation in Parasitic Diseases Skaggs School of Pharmacy and Pharmaceutical Sciences University of California San Diego 9500 Gilman Drive MC0755 La Jolla CA 920930755 USA 2The Scripps Research Institute Scripps Florida 130 Scripps Way 3A2 Jupiter FL 33458 USA 3Center for Discovery and Innovation in Parasitic Diseases Skaggs School of Pharmacy and Pharmaceutical Sciences University of California San Diego 9500 Gilman Drive MC0755 La Jolla CA 920930755 USA Electronic address adebnathucsdedu
# Cosine Similarity : 0.2607201933860779
#
#
# Document: Comment in Pediatr Infect Dis J 2021 Apr 1404358
# Cosine Similarity : 0.2572121024131775
#
#
# Document: 1 ACS ES T Water 2023 Mar 153411261133 doi 101021acsestwater2c00592
# Cosine Similarity : 0.2498180866241455
#
#
# Document: Published by Oxford University Press on behalf of the Infectious Diseases Society of America 2015 This work is written by a US Government employee and is in the public domain in the US
# Cosine Similarity : 0.24458056688308716
#
#
# Document: Published by Oxford University Press for the Infectious Diseases Society of America 2017 This work is written by a US Government employee and is in the public domain in the US
# Cosine Similarity : 0.24332085251808167
#
#
# Document: Author information 1US Centers for Disease Control and Prevention 1600 Clifton Rd NE Atlanta GA 30333 2New Jersey Department of Health P O Box 360 Trenton NJ 086250360 3Texas Department of State Health Services PO Box 149347 Austin TX 787149347 4Chenega Enterprise System  Solutions 609 Independence Parkway Suite 210 Chesapeake VA 23320 5WacoMcLennan County Public Health District 225 W Waco Dr Waco TX 76707
# Cosine Similarity : 0.23663541674613953
#
#
# Document: Author information 1Department of Medicine Division Allergy and Infectious Disease Center for Emerging and Reemerging Infectious Disease CERID University of Washington Seattle Washington United States of America 2Seattle Structural Genomics Center for Infectious Diseases Seattle Washington United States of America 3Department of Biology Washington University St Louis Missouri United States of America 4UCB Pharma Bainbridge Island Washington United States of America 5Seattle Childrens Research Institute Seattle Washington United States of America 6Department of Pediatrics University of Washington Seattle Washington United States of America 7Department of Biomedical Informatics  Medical Education University of Washington Seattle Washington United States of America 8Department of Global Health Pathobiology University of Washington Seattle Washington United States of America 9Center for Tropical and Emerging Global Diseases University of Georgia Athens Georgia United States of America 10Eukaryotic Pathogens Innovation Center Department of Genetics and Biochemistry Clemson University Clemson South Carolina United States of America 11Department of Chemistry University of South Florida Tampa Florida United States of America 12Department of Chemistry and Chemical Biology and Department of Pharmaceutical Sciences Northeastern University Boston Massachusetts United States of America
# Cosine Similarity : 0.23254716396331787
#
#
# Document: Centers for Disease Control and Prevention CDC
# Cosine Similarity : 0.23191127181053162
#
#
# Document: 2 Front Microbiol 2023 Feb 1131056418 doi 103389fmicb20221056418 eCollection 2022
# Cosine Similarity : 0.22371679544448853
#
#
# Document: PMID 15915965 Indexed for MEDLINE
# Cosine Similarity : 0.2208375483751297
#
#
# Document: DOI 101099jmmcr0005042 PMCID PMC5330229 PMID 28348761
# Cosine Similarity : 0.21408450603485107
#
#
# Document: PMID 8918032 Indexed for MEDLINE
# Cosine Similarity : 0.21034599840641022
#
#
# Document: Comparative Genomic and Transcriptomic Analysis of Naegleria fowleri Clinical and Environmental Isolates
# Cosine Similarity : 0.2099049687385559
#
#
# Document: DOI 103389fmicb20221056418 PMCID PMC9928731 PMID 36817109
# Cosine Similarity : 0.20366740226745605
#
#
# Document: 4 PLoS One 2021 Mar 24163e0241738 doi 101371journalpone0241738 eCollection 2021
# Cosine Similarity : 0.2020362913608551
#
#
# Document: 6 Exp Parasitol 2018 May1883641 doi 101016jexppara201803010 Epub 2018 Mar 15
# Cosine Similarity : 0.19216620922088623
#
#
# Document: 14 J Egypt Soc Parasitol 1996 Dec2636018
# Cosine Similarity : 0.1870976686477661
#
#
# Document: Conflict of interest statement The author declare that the research wa conducted in the absence of any commercial or financial relationship that could be construed a a potential conflict of interest
# Cosine Similarity : 0.18469735980033875
#
#
# Document: 8 JMM Case Rep 2016 Jun 2533e005042 doi 101099jmmcr0005042 eCollection 2016 Jun
# Cosine Similarity : 0.16011616587638855
#
#
# Document: Identification of cysteine protease inhibitor a new drug lead against Naegleria fowleri
# Cosine Similarity : 0.15366710722446442
#
#
# Document: 3 mSphere 2021 Aug 2564e0063721 doi 101128mSphere0063721 Epub 2021 Aug 11
# Cosine Similarity : 0.14965416491031647
#
#
# Document: Conflict of interest statement The author have read the journal’s policy and have the following competing interest DMD JA SLD DRD SJM BC MJB DDL and TEE are employee of UCB Pharma The LSCAT Sector 21 wa supported by a grant from the Michigan Economic Development Corporation This doe not alter our adherence to PLOS ONE policy on sharing data and material There are no patent product in development or marketed product associated with this research to declare
# Cosine Similarity : 0.14354772865772247
#
#
# Document: 13 Bull Soc Pathol Exot 2005 Apr981113
# Cosine Similarity : 0.1412259042263031
#
#
# Document: Copyright © 2018 Elsevier Inc All right reserved
# Cosine Similarity : 0.13086454570293427
#
#
# Document: Awadalla HN1 Sadaka HA
# Cosine Similarity : 0.12865665555000305
#
#
# Document: Article in French
# Cosine Similarity : 0.12566934525966644
#
#
# Document: Conflict of interest statement Potential conflict of interest All author no reported conflict
# Cosine Similarity : 0.12293410301208496
#
#
# Document: Conflict of interest statement Potential conflict of interest All author No reported conflict
# Cosine Similarity : 0.12293410301208496
#
#
# Document: JaffarBandjee MC1 Alessandri JL Molet B Clouzeau J Jacquemot L Sampériz S Saly JC
# Cosine Similarity : 0.10218040645122528
#
#
# Document: Cope JR1 Ratard RC2 Hill VR1 Sokol T2 Causey JJ2 Yoder JS1 Mirani G3 Mull B1 Mukerjee KA3 Narayanan J1 Doucet M3 Qvarnstrom Y1 Poole CN3 Akingbola OA3 Ritter JM1 Xiong Z3 da Silva AJ1 Roellig D1 Van Dyke RB3 Stern H3 Xiao L1 Beach MJ1
# Cosine Similarity : 0.09964416176080704
#
#
# Document: Zyserman I1 Mondal D2 Sarabia F2 McKerrow JH1 Roush WR2 Debnath A3
# Cosine Similarity : 0.08688367903232574
#
#
# Document: 11 MMWR Morb Mortal Wkly Rep 2013 Nov 156245903
# Cosine Similarity : 0.07464878261089325
#
#
# Document: Miko S1 Cope JR1 Hlavsa MC1 Ali IKM1 Brown TW1 Collins JP1 Greeley RD2 Kahler AM1 Moore KO3 Roundtree AV14 Roy S1 Sanders LL5 Shah V5 Stuteville HD3 Mattioli MC1
# Cosine Similarity : 0.07367810606956482
#
#
# Document: Dereeper A1 Allouch N1 Guerlais V1 Garnier M1 Ma L2 De Jonckheere JF3 Joseph SJ4 Ali IKM4 Talarmin A1 Marcelino I1
# Cosine Similarity : 0.07176670432090759
#
#
# Document: Yoder JS1 StraifBourgeois S Roy SL Moore TA Visvesvara GS Ratard RC Hill VR Wilson JD Linscott AJ Crager R Kozak NA Sriram R Narayanan J Mull B Kahler AM Schneeberger C da Silva AJ Poudel M Baumgarten KL Xiao L Beach MJ
# Cosine Similarity : 0.06100079417228699
#
#
# Document: Tillery L12 Barrett K12 Goldstein J3 Lassner JW3 Osterhout B3 Tran NL3 Xu L3 Young RM3 Craig J12 Chun I12 Dranow DM24 Abendroth J24 Delker SL24 Davies DR24 Mayclin SJ24 Calhoun B24 Bolejack MJ24 Staker B25 Subramanian S25 Phan I25 Lorimer DD24 Myler PJ25678 Edwards TE24 Kyle DE9 Rice CA9 Morris JC10 Leahy JW11 Manetsch R12 Barrett LK12 Smith CL3 Van Voorhis WC128
# Cosine Similarity : 0.04698370397090912
#
#
# Document: Stubhaug TT1 Reiakvam OM2 Stensvold CR3 Hermansen NO1 HolbergPetersen M1 Antal EA4 Gaustad K5 Førde IS5 Heger B2
# Cosine Similarity : 0.04659032076597214
#
#
# Document: Itoh K1 Yagita K Nozaki T Katano H Hasegawa H Matsuo K Hosokawa Y Tando S Fushiki S
# Cosine Similarity : 0.027028260752558708
#
#
# Document: Cope JR1 Murphy J1 Kahler A1 Gorbett DG2 Ali I1 Taylor B3 Corbitt L4 Roy S1 Lee N5 Roellig D1 Brewer S6 Hill VR1
# Cosine Similarity : 0.026529841125011444
#
#
# Document: Joseph SJ1 Park S2 Kelley A2 Roy S1 Cope JR1 Ali IKM1
# Cosine Similarity : 0.012014307081699371
#
#
# Document: Gharpure R Gleason M Salah Z Blackstock AJ HessHomeier D Yoder JS Ali IKM Collier SA Cope JR
# Cosine Similarity : -0.0036523123271763325
#
#
# Document: Copyright © 2023 Dereeper Allouch Guerlais Garnier Ma De Jonckheere Joseph Ali Talarmin and Marcelino
# Cosine Similarity : -0.015726573765277863

# %% [markdown]
# **BioSentVec**

# %% [markdown]
# BioSentVec, a pre-trained model, transforms sentences into numerical forms, effectively capturing the intricate connections between words within the realm of biology and medicine. Its training dataset includes a vast collection of over 30 million documents sourced from scholarly articles found in PubMed and clinical notes extracted from the MIMIC-III Clinical Database. This extensive training ensures its proficiency in understanding the language and concepts specific to these fields.

# %%
model_BioSentVec_path = '/content/drive/MyDrive/Colab Notebooks/NLP/project/Models/Datasets/BioSentVec_PubMed_MIMICIII-bigram_d700.bin'
testing_model = sent2vec.Sent2vecModel()

# %% [markdown]
# Let's load the model

# %%
try:
    testing_model.load_model(model_BioSentVec_path)
except Exception as e:
    print(e)
print('model successfully loaded')
# Out:
# model successfully loaded

# %% [markdown]
# We'll employ the previously loaded model to create embeddings for a collection of documents containing both questions and answers, which together constitute the training set

# %%
document_embeddings = testing_model.embed_sentences(question_documents_train_set)

# %% [markdown]
# Let's calculates pairwise similarities and differences between document embeddings using cosine similarity

# %%
pairwise_similarities = cosine_similarity(document_embeddings)

# %% [markdown]
# Let's retrieve the most similar documents

# %%
most_similar(0,pairwise_similarities,'Cosine Similarity')
# Out:
# Document: What cause amoebic brain disease and is associated with freshwater source
#
#
# Similar Documents using Cosine Similarity:
# [ 0 53 79 67 59 32 25 45 86 19 38 73  5 92 64 56 11 50 82 76 71 27 22 35
#  14  8 89 46 16 48 60 62 37 75  4 63  1  7 21 55 41 39 81 28 15 49 10 85
#  34 88 44 78 70 18 31 68 91 52 66 77 57  2 58 42 24 83 72 12 80 87 20 93
#  74 26 61 69 33 40 47 90  3 54 51  6 84  9 23 43 13 36 30 17 65 29]
#
#
# Document: INTRODUCTION Primary amoebic meningoencephalitis PAM is a rare disease caused by the freeliving amoeba Naegleria fowleri Infection occurs by insufflation of water containing amoeba into the nasal cavity and is usually associated with bathing in freshwater Nasal irrigation is a more rarely reported route of infection CASE PRESENTATION A fatal case of PAM in a previously healthy Norwegian woman acquired during a holiday trip to Thailand is described Clinical finding were consistent with rapidly progressing meningoencephalitis The cause of infection wa discovered by chance owing to the unexpected detection of N fowleri DNA by a PCR assay targeting fungi A conclusive diagnosis wa established based on sequencing of N fowleri DNA from brain biopsy supported by histopathological finding Nasal irrigation using contaminated tap water is suspected a the source of infection CONCLUSION The clinical presentation of PAM is very similar to severe bacterial meningitis This case is a reminder that when standard investigation fail to identify a cause of infection in severe meningoencephalitis it is of crucial importance to continue a broad search for a conclusive diagnosis PAM should be considered a a diagnosis in patient with symptom of severe meningoencephalitis returning from endemic area
# Cosine Similarity : 0.5416655540466309
#
#
# Document: BACKGROUND Naegleria fowleri is a climatesensitive thermophilic ameba found in the environment including warm freshwater lake and river Primary amebic meningoencephalitis PAM which is almost universally fatal occurs when N fowlericontaining water enters the nose typically during swimming and N fowleri migrates to the brain via the olfactory nerve In 2011 2 adult died in Louisiana hospital of infectious meningoencephalitis after brief illness METHODS Clinical and environmental testing and case investigation were initiated to determine the cause of death and to identify the exposure RESULTS Both patient had diagnosis of PAM Their only reported water exposure were tap water used for household activity including regular sinus irrigation with neti pot Water sample tap swab sample and neti pot were collected from both household and tested N fowleri were identified in water sample from both home CONCLUSIONS These are the first reported PAM case in the United States associated with the presence of N fowleri in household plumbing served by treated municipal water supply and the first report of PAM potentially associated with the use of a nasal irrigation device These case occurred in the context of an expanding geographic range for PAM beyond southern tier state with recent case report from Minnesota Kansas and Virginia These infection introduce an additional consideration for physician recommending nasal irrigation and demonstrate the importance of using appropriate water distilled boiled filtered for nasal irrigation Furthermore the changing epidemiology of PAM highlight the importance of raising awareness about this disease among physician treating person showing meningitislike symptom
# Cosine Similarity : 0.507055938243866
#
#
# Document: Balamuthia mandrillaris is an amoeba found in fresh water and soil that cause granulomatous amoebic encephalitis We report herein an autopsy case of B mandrillaris amoebic encephalitis which wa definitely diagnosed by PCR An 81yearold man who had Sjögrens syndrome manifested drowsiness 2 month before his death with progressive deterioration Neuroimaging demonstrated focus of T2 and fluidattenuated inversion recovery high and T1 lowintensity with irregular postcontrast ring enhancement in the cerebral hemisphere thalamus and midbrain Pathologically multiple hemorrhagic and necrotic lesion were found in the cerebrum thalamus midbrain pons medulla and cerebellum which were characterized by liquefactive necrosis marked edema hemorrhage and necrotizing vasculitis associated with the perivascular accumulation of amoebic trophozoite a few cyst and the infiltration of numerous neutrophil and microgliamacrophages The trophozoite were ovoid or round 1060 μm in diameter and they showed foamy cytoplasm and a round nucleus with small karyosome in the center The PCR and immunohistochemistry from paraffinembedded brain specimen revealed angioinvasive encephalitis due to B mandrillaris Human case of B mandrillaris brain infection are rare in Japan with only a few brief report in the literature
# Cosine Similarity : 0.5001941919326782
#
#
# Document: BACKGROUND Naegleria fowleri is a climatesensitive thermophilic ameba found in warm freshwater lake and river Primary amebic meningoencephalitis PAM which is almost universally fatal occurs when N fowlericontaining water enters the nose typically during swimming and migrates to the brain via the olfactory nerve In August 2013 a 4yearold boy died of meningoencephalitis of unknown etiology in a Louisiana hospital METHODS Clinical and environmental testing and a case investigation were initiated to determine the cause of death and to identify potential exposure RESULTS Based on testing of cerebrospinal fluid and brain specimen the child wa diagnosed with PAM His only reported water exposure wa tap water in particular tap water that wa used to supply water to a lawn water slide on which the child had played extensively prior to becoming ill Water sample were collected from both the home and the water distribution system that supplied the home and tested N fowleri wa identified in water sample from both the home and the water distribution system CONCLUSIONS This case is the first reported PAM death associated with culturable N fowleri in tap water from a US treated drinking water system This case occurred in the context of an expanding geographic range for PAM beyond southern state with recent case report from Minnesota Kansas and Indiana This case also highlight the role of adequate disinfection throughout drinking water distribution system and the importance of maintaining vigilance when operating drinking water system using source water with elevated temperature
# Cosine Similarity : 0.4961909353733063
#
#
# Document: Naegleria fowleri is a freeliving ameba that cause primary amebic meningoencephalitis PAM a rare but usually fatal disease We analyzed trend in recreational water exposure associated with PAM case reported during 19782018 in the United States Although PAM incidence remained stable the geographic range of exposure location expanded northward
# Cosine Similarity : 0.4951639771461487
#
#
# Document: Naegleria fowleri is a pathogenic thermophilic freeliving amoeba which cause primary amebic meningoencephalitis PAM Penetrating the olfactory mucosa the braineating amoeba travel along the olfactory nerve burrowing through the cribriform plate to it destination the brain frontal lobe The amoeba thrives in warm freshwater environment with peak infection rate in the summer month and ha a mortality rate of approximately 97 A major contributor to the pathogen high mortality is the lack of sensitivity of N fowleri to current drug therapy even in the face of combinationdrug therapy To enable rational drug discovery and design effort we have pursued protein production and crystallographybased structure determination effort for likely drug target from N fowleri The gene were selected if they had homology to drug target listed in Drug Bank or were nominated by primary investigator engaged in N fowleri research In 2017 178 N fowleri protein target were queued to the Seattle Structural Genomics Center of Infectious Disease SSGCID pipeline and to date 89 soluble recombinant protein and 19 unique target structure have been produced Many of the new protein structure are potential drug target and contain structural difference compared to their human homologs which could allow for the development of pathogenspecific inhibitor Five of the structure were analyzed in more detail and four of five show promise that selective inhibitor of the active site could be found The 19 solved crystal structure build a foundation for future work in combating this devastating disease by encouraging further investigation to stimulate drug discovery for this neglected pathogen
# Cosine Similarity : 0.49299219250679016
#
#
# Document: BACKGROUND Naegleria fowleri is a thermophilic ameba found in freshwater that cause primary amebic meningoencephalitis PAM when it enters the nose and migrates to the brain Patient exposure to water containing the ameba typically occurs in warm freshwater lake and pond during recreational water activity In June 2016 an 18yearold woman died of PAM after traveling to North Carolina where she participated in rafting on an artificial whitewater river METHODS We conducted an epidemiologic and environmental investigation to determine the water exposure that led to the death of this patient RESULTS The case patient most probable water exposure occurred while rafting on an artificial whitewater river during which she wa thrown out of the raft and submerged underwater The approximately 115 million gallon of water in the whitewater facility were partially filtered subjected to ultraviolet light treatment and occasionally chlorinated Heavy algal growth wa noted Eleven waterrelated sample were collected from the facility all were positive for N fowleri Of 5 sample collected from the nearby natural river 1 sediment sample wa positive for N fowleri CONCLUSIONS This investigation document a novel exposure to an artificial whitewater river a the likely exposure causing PAM in this case Conditions in the whitewater facility warm turbid water with little chlorine and heavy algal growth rendered the water treatment ineffective and provided an ideal environment for N fowleri to thrive The combination of natural and engineered element at the whitewater facility created a challenging environment to control the growth of N fowleri
# Cosine Similarity : 0.4922998249530792
#
#
# Document: The primary amebic meningoencephalitis is an acute suppurative infection that involves both the brain and the meninges It is caused by Naegleria fowleri and is a very rare and fulminating condition so far nearly always fatal We report the first case in the area of Southern part of Indian Ocean that occured in a 7year old French boy living in Madagascar It is assumed that the disease wa contracted by swimming in warm fresh water in a lake of the Madagascar east coast Clinical sign began 1012 day after exposure associating headache vomiting and pyrexia 3940 degree C Upon admission in a Madagascar hospital the patient wa started on antibiotic that did not control the disease and soon presented with a loss of consciousness and a delirium He wa transferred to Reunion island Centre Hospitalier Départemental FélixGuyon where the diagnosis of primary amebic meningoencephalitis wa confirmed Therefore he wa started on highdose of intraspinal amphotericin B IV amphotericin B lipid complex and tetracycline He developed myocarditis diabetes insipidus deep coma and subsequently died a week later The diagnosis of amebic meningoencephalitis wa based on  the cerebrospinal fluid examination that confirmed the diagnosis of purulent meningitis 420 leucocyte 76 polynuclears 14 lymphocyte 90 red blood cell and showed 50 ameboid trophozoite per 100 leucocyte approximately 20 microm in size  the flagellate transformation test in distilled water showed two anterior flagellas that confirmed the genus Naegleria
# Cosine Similarity : 0.49006614089012146
#
#
# Document: Out of over 40 specie of Naegleria which are freeliving thermophilic ameba found in freshwater and soil worldwide only Naegleria fowleri infects human causing primary amebic meningoencephalitis PAM a typically fatal brain disease To understand the population structure of Naegleria specie and the genetic relationship between N fowleri isolates and to detect pathogenic factor we characterized 52 novel clinical and environmental N fowleri genome and a single Naegleria lovaniensis strain along with transcriptomic data for a subset of 37 N fowleri isolates Wholegenome analysis of 56 isolates from three Naegleria specie N fowleri N lovaniensis and Naegleria gruberi identified several gene unique to N fowleri that have previously been linked to the pathogenicity of N fowleri while other unique gene could be associated with novel pathogenicity factor in this highly fatal pathogen Population structure analysis estimated the presence of 10 population within the three Naegleria specie of which 7 population were within N fowleri The wholenucleargenome WNG phylogenetic analysis showed an overall geographical clustering of N fowleri isolates with few exception and provided higher resolution in identifying potential cluster of isolates beyond that of the traditional locus typing There were only 34 gene that showed significant difference in gene expression between the clinical and environmental isolates Genomic data generated in this study can be used for developing rapid molecular assay and to conduct future populationbased global genomic analysis and will also be a valuable addition to genomic reference database where shotgun metagenomics data from routine water sample could be searched for the presence of N fowleri strain IMPORTANCE N fowleri the only known Naegleria specie to infect human cause fatal brain disease PAM case from 1965 to 2016 showed 20 case per year globally Out of approximately 150 case in North America since 1962 only four PAM survivor are known yielding a 97 case fatality rate which is critically high Although the pathogenesis of N fowleri ha been studied for the last 50 year pathogenetic factor that lead to human infection and breaching the bloodbrain barrier remain unknown In addition little is known regarding the genomic diversity both within N fowleri isolates and among Naegleria specie In this study we generated novel genome sequence and performed comparative genomic and transcriptomic analysis of a set of 52 N fowleri draft genome sequence from clinical and environmental isolates derived from all over the world in the last 53 year which will help shape future genomewide study and develop sensitive assay for routine surveillance
# Cosine Similarity : 0.47985008358955383
#
#
# Document: Primary amebic meningoencephalitis PAM is a rapidly fatal infection caused by the freeliving ameba Naegleria fowleri PAM occurs principally in healthy child of le than 13 year old with a history of recent exposure to warm fresh water While a yet not a reportable disease the Centers for Disease Control and Prevention CDC document a total of 143 case in the United States Only four patient have survived Infection result from water containing N fowleri entering the nose followed by migration of the ameba to the brain Within the brain N fowleri infection result in extensive necrosis leading to death in 37 day Mortality among patient with PAM is greater than 95 The drug of choice in treating PAM are the antifungal amphotericin B and the antileishmanial miltefosine However neither drug is FDAapproved for this indication and the use of amphotericin B is associated with severe adverse effect Moreover very few patient treated with amphotericin B have survived PAM Therefore development of new safe and effective drug is a critical unmet need to avert future death of child The molecular mechanism underlying the pathogenesis of PAM are poorly understood but it is known that cysteine protease of N fowleri play a role in the progression of PAM We therefore assessed the in vitro activity of the synthetic vinyl sulfone cysteine protease inhibitor K11777 and 33 analog with valine phenylalanine or pyridylalanine at P2 position against cysteine protease activity in the lysate of N fowleri Inhibitors with phenylalanine or pyridylalanine at P2 position were particularly effective in inhibiting the cysteine protease activity of N fowleri cell lysate with IC50 ranging between 3 nM and 66 μM Three of the 34 inhibitor also showed inhibitory activity against N fowleri in a cell viability assay and were 16 to 25fold more potent than the standard of care drug miltefosine Our study provides the first evidence of the activity of synthetic small molecule cysteine protease inhibitor against N fowleri
# Cosine Similarity : 0.47924676537513733
#
#
# Document: On November 21 2012 the US Virgin Islands USVI Department of Health documented the first case and death from primary amebic meningoencephalitis PAM in the territory PAM a rare and almost universally fatal condition result when Naegleria fowleri a freeliving thermophilic ameba found in warm freshwater enters the nose and migrates to the brain The patient wa a man aged 47 year whose only reported freshwater exposure were the use of tap water for daily household activity and for ablution a ritual cleansing that he practiced several time a day in preparation for Islamic prayer Ablution can include nasal rinsing On November 16 2012 the patient had visited the emergency department with a headache he wa treated symptomatically and released The following day the patient returned to the emergency department by ambulance with fever confusion agitation and a severe headache for which he wa admitted Cerebrospinal fluid CSF study were consistent with bacterial meningitis and antibiotic were started On November 18 neurologic finding included fixed nonresponsive pupil no response in the upper or lower extremity muted plantar response and no response to verbal command Microscopic examination of the CSF obtained from a second lumbar puncture revealed motile amebic trophozoite CSF specimen sent to CDC for confirmatory testing were positive for N fowleri by realtime polymerase chain reaction testing On the morning of November 21 the patient wa pronounced brain dead based on neurologic criterion
# Cosine Similarity : 0.4762219190597534
#
#
# Document: Naegleria fowleri is a thermophilic ameba found in freshwater that cause primary amebic meningoencephalitis PAM when it enters the nose and migrates to the brain In September 2018 a 29yearold man died of PAM after traveling to Texas We conducted an epidemiologic and environmental investigation to identify the water exposure associated with this PAM case The patient most probable water exposure occurred while surfing in an artificial surf venue The surf venue water wa not filtered or recirculated water disinfection and water quality testing were not documented N fowleri and thermophilic ameba were detected in recreational water and sediment sample throughout the facility Codes and standard for treated recreational water venue open to the public could be developed to address these novel venue Clinicians and public health official should also consider novel recreational water venue a a potential exposure for this rare amebic infection
# Cosine Similarity : 0.4647693932056427
#
#
# Document: Acanthamoeba culbertsoni is one of the freeliving amoeba which are known to be pathogenic to man causing granulomatous amoebic encephalitis GAE In this study Acanthamoeba culbertsoni wa isolated from a water sample of ElMahmoudia Canal in Alexandria in July1993 This wa used to infect mouse intranasally to study the histopathological picture of the brain and lung The neuropathological feature consisted of chronic granulomatous encephalitis in which cyst and trophozoite were found Associated Acanthamoeba pneumonitis with massive consolidation wa also observed Congenital infection of offspring wa reported for the first time in this study
# Cosine Similarity : 0.45697087049484253
#
#
# Document: An autopsy case of Balamuthia mandrillaris amoebic encephalitis a rare emerging infectious disease with a brief review of the case reported in Japan
# Cosine Similarity : 0.4293995499610901
#
#
# Document: The first association of a primary amebic meningoencephalitis death with culturable Naegleria fowleri in tap water from a US treated public drinking water system
# Cosine Similarity : 0.3995606601238251
#
#
# Document: INTRODUCTION Freeliving amoeba of the Naegleria genus belong to the major protist clade Heterolobosea and are ubiquitously distributed in soil and freshwater habitat Of the 47 Naegleria specie described N fowleri is the only one being pathogenic to human causing a rare but fulminant primary amoebic meningoencephalitis Some Naegleria genome sequence are publicly available but the genetic basis for Naegleria diversity and ability to thrive in diverse environment including human brain remains unclear METHODS Herein we constructed a highquality Naegleria genus pangenome to obtain a comprehensive catalog of gene encoded by these amoeba For this we first sequenced assembled and annotated six new Naegleria genome RESULTS AND DISCUSSION Genome architecture analysis revealed that Naegleria may use genome plasticity feature such a ploidyaneuploidy to modulate their behavior in different environment When comparing 14 neartocomplete genome sequence our result estimated the theoretical Naegleria pangenome a a closed genome with 13943 gene including 3563 core and 10380 accessory gene The functional annotation revealed that a large fraction of Naegleria gene show significant sequence similarity with those already described in other kingdom namely Animalia and Plantae Comparative analysis highlighted a remarkable genomic heterogeneity even for closely related strain and demonstrate that Naegleria harbor extensive genome variability reflected in different metabolic repertoire If Naegleria core genome wa enriched in conserved gene essential for metabolic regulatory and survival process the accessory genome revealed the presence of gene involved in stress response macromolecule modification cell signaling and immune response Commonly reported N fowleri virulenceassociated gene were present in both core and accessory genome suggesting that N fowleris ability to infect human brain could be related to it unique speciesspecific gene mostly of unknown function andor to differential gene expression The construction of Naegleria first pangenome allowed u to move away from a single reference genome that doe not necessarily represent each specie a a whole and to identify essential and dispensable gene in Naegleria evolution diversity and biology paving the way for further genomic and postgenomic study
# Cosine Similarity : 0.3903197646141052
#
#
# Document: Fatal primary amoebic meningoencephalitis in a Norwegian tourist returning from Thailand
# Cosine Similarity : 0.3795761168003082
#
#
# Document: Primary amebic meningoencephalitis 1st case observed in Madagascar
# Cosine Similarity : 0.3716064989566803
#
#
# Document: Primary amebic meningoencephalitis death associated with sinus irrigation using contaminated tap water
# Cosine Similarity : 0.3715507984161377
#
#
# Document: Notes from the field primary amebic meningoencephalitis associated with ritual nasal rinsingSt Thomas US Virgin island 2012
# Cosine Similarity : 0.36229196190834045
#
#
# Document: Conflict of interest statement The author have read the journal’s policy and have the following competing interest DMD JA SLD DRD SJM BC MJB DDL and TEE are employee of UCB Pharma The LSCAT Sector 21 wa supported by a grant from the Michigan Economic Development Corporation This doe not alter our adherence to PLOS ONE policy on sharing data and material There are no patent product in development or marketed product associated with this research to declare
# Cosine Similarity : 0.31876063346862793
#
#
# Document: Naegleria fowleri Protein structure to facilitate drug discovery for the deadly pathogenic freeliving amoeba
# Cosine Similarity : 0.3101392984390259
#
#
# Document: Identification of cysteine protease inhibitor a new drug lead against Naegleria fowleri
# Cosine Similarity : 0.29367563128471375
#
#
# Document: Conflict of interest statement The author declare that the research wa conducted in the absence of any commercial or financial relationship that could be construed a a potential conflict of interest
# Cosine Similarity : 0.2646487355232239
#
#
# Document: Naegleria genus pangenome reveals new structural and functional insight into the versatility of these freeliving amoeba
# Cosine Similarity : 0.24148857593536377
#
#
# Document: The possibility of congenital infection with Acanthamoeba culbertsoni
# Cosine Similarity : 0.23048809170722961
#
#
# Document: Published by Oxford University Press for the Infectious Diseases Society of America 2017 This work is written by a US Government employee and is in the public domain in the US
# Cosine Similarity : 0.20208050310611725
#
#
# Document: Comparative Genomic and Transcriptomic Analysis of Naegleria fowleri Clinical and Environmental Isolates
# Cosine Similarity : 0.1855010986328125
#
#
# Document: Conflict of interest statement Potential conflict of interest All author No reported conflict
# Cosine Similarity : 0.17865750193595886
#
#
# Document: Published by Oxford University Press on behalf of the Infectious Diseases Society of America 2015 This work is written by a US Government employee and is in the public domain in the US
# Cosine Similarity : 0.1726188063621521
#
#
# Document: Conflict of interest statement Potential conflict of interest All author no reported conflict
# Cosine Similarity : 0.16969963908195496
#
#
# Document: Author information 1Center for Discovery and Innovation in Parasitic Diseases Skaggs School of Pharmacy and Pharmaceutical Sciences University of California San Diego 9500 Gilman Drive MC0755 La Jolla CA 920930755 USA 2The Scripps Research Institute Scripps Florida 130 Scripps Way 3A2 Jupiter FL 33458 USA 3Center for Discovery and Innovation in Parasitic Diseases Skaggs School of Pharmacy and Pharmaceutical Sciences University of California San Diego 9500 Gilman Drive MC0755 La Jolla CA 920930755 USA Electronic address adebnathucsdedu
# Cosine Similarity : 0.1597169190645218
#
#
# Document: 12 Clin Infect Dis 2012 Nov559e7985 doi 101093cidcis626 Epub 2012 Aug 22
# Cosine Similarity : 0.12346188724040985
#
#
# Document: Author information 1US Centers for Disease Control and Prevention 1600 Clifton Rd NE Atlanta GA 30333 2New Jersey Department of Health P O Box 360 Trenton NJ 086250360 3Texas Department of State Health Services PO Box 149347 Austin TX 787149347 4Chenega Enterprise System  Solutions 609 Independence Parkway Suite 210 Chesapeake VA 23320 5WacoMcLennan County Public Health District 225 W Waco Dr Waco TX 76707
# Cosine Similarity : 0.11887406557798386
#
#
# Document: 10 Neuropathology 2015 Feb351649 doi 101111neup12151 Epub 2014 Sep 3
# Cosine Similarity : 0.11056001484394073
#
#
# Document: 1 ACS ES T Water 2023 Mar 153411261133 doi 101021acsestwater2c00592
# Cosine Similarity : 0.10942748188972473
#
#
# Document: 2 Front Microbiol 2023 Feb 1131056418 doi 103389fmicb20221056418 eCollection 2022
# Cosine Similarity : 0.10722462087869644
#
#
# Document: 4 PLoS One 2021 Mar 24163e0241738 doi 101371journalpone0241738 eCollection 2021
# Cosine Similarity : 0.10185734182596207
#
#
# Document: 9 Clin Infect Dis 2015 Apr 15608e3642 doi 101093cidciv017 Epub 2015 Jan 16
# Cosine Similarity : 0.10040023922920227
#
#
# Document: 7 Clin Infect Dis 2018 Feb 1664548553 doi 101093cidcix810
# Cosine Similarity : 0.09887431561946869
#
#
# Document: Copyright © 2018 Elsevier Inc All right reserved
# Cosine Similarity : 0.09804269671440125
#
#
# Document: 13 Bull Soc Pathol Exot 2005 Apr981113
# Cosine Similarity : 0.09758784621953964
#
#
# Document: 5 Emerg Infect Dis 2021 Jan271271274 doi 103201eid2701202119
# Cosine Similarity : 0.0968337208032608
#
#
# Document: 3 mSphere 2021 Aug 2564e0063721 doi 101128mSphere0063721 Epub 2021 Aug 11
# Cosine Similarity : 0.09602618962526321
#
#
# Document: 8 JMM Case Rep 2016 Jun 2533e005042 doi 101099jmmcr0005042 eCollection 2016 Jun
# Cosine Similarity : 0.09227044880390167
#
#
# Document: Author information 1Institut Pasteur de la Guadeloupe Unité TReDPath Les Abymes Guadeloupe France 2Institut Pasteur de Paris Biomics Paris France 3Scientific Institute of Public Health Brussels Belgium 4Centers for Disease Control and Prevention CDC Atlanta GA United States
# Cosine Similarity : 0.0896555706858635
#
#
# Document: Author information 1Laboratoire de biologie Centre hospitalier départemental FélixGuyon SaintDenis La Réunion France mcjaffarchdfguyonfr
# Cosine Similarity : 0.08256261050701141
#
#
# Document: 6 Exp Parasitol 2018 May1883641 doi 101016jexppara201803010 Epub 2018 Mar 15
# Cosine Similarity : 0.07437658309936523
#
#
# Document: 14 J Egypt Soc Parasitol 1996 Dec2636018
# Cosine Similarity : 0.07203754782676697
#
#
# Document: Author information 1Waterborne Disease Prevention Branch Centers for Disease Control and Prevention Atlanta Georgia 2Mount Carmel Hospital Columbus Ohio 3Ohio Department of Health Columbus 4Mecklenburg County Health Department Charlotte North Carolina 5North Carolina Department of Health and Human Services Raleigh 6Franklin County Public Health Columbus Ohio
# Cosine Similarity : 0.07177601754665375
#
#
# Document: Author information 1National Center for Emerging and Zoonotic Infectious Diseases Centers for Disease Control and Prevention1600 Clifton Road Atlanta GA 30329 USA jey9cdcgov
# Cosine Similarity : 0.06912121176719666
#
#
# Document: 11 MMWR Morb Mortal Wkly Rep 2013 Nov 156245903
# Cosine Similarity : 0.06843814253807068
#
#
# Document: Author information 1Waterborne Disease Prevention Branch Division of Foodborne Waterborne and Environmental Diseases National Center for Emerging and Zoonotic Infectious Diseases Centers for Disease Control and Preventiongrid416738f Atlanta Georgia USA 2Eagle Medical Services Atlanta Georgia USA
# Cosine Similarity : 0.06499242782592773
#
#
# Document: Comment in Pediatr Infect Dis J 2021 Apr 1404358
# Cosine Similarity : 0.06427362561225891
#
#
# Document: © 2014 Japanese Society of Neuropathology
# Cosine Similarity : 0.05641557648777962
#
#
# Document: Author information 1Department of Parasitology Faculty of Medicine Alexandria University Egypt
# Cosine Similarity : 0.05299365520477295
#
#
# Document: Author information 1Department of Microbiology Oslo University Hospital  Ullevaal Oslo Norway 2Department of Infectious Diseases Oslo University Hospital  Ullevaal Oslo Norway 3Department of Microbiology and Infection Control Statens Serum Institut Copenhagen Denmark 4Department of Pathology Oslo University Hospital  Rikshospitalet Oslo Norway 5Department of Anaesthesiology Oslo University Hospital  Ullevaal Oslo Norway
# Cosine Similarity : 0.04944378137588501
#
#
# Document: Author information 1Department of Pathology  Applied Neurobiology Graduate School of Medical Science Kyoto Prefectural University of Medicine Kyoto Japan
# Cosine Similarity : 0.04267847537994385
#
#
# Document: Yoder JS1 StraifBourgeois S Roy SL Moore TA Visvesvara GS Ratard RC Hill VR Wilson JD Linscott AJ Crager R Kozak NA Sriram R Narayanan J Mull B Kahler AM Schneeberger C da Silva AJ Poudel M Baumgarten KL Xiao L Beach MJ
# Cosine Similarity : 0.03934835270047188
#
#
# Document: Cope JR1 Ratard RC2 Hill VR1 Sokol T2 Causey JJ2 Yoder JS1 Mirani G3 Mull B1 Mukerjee KA3 Narayanan J1 Doucet M3 Qvarnstrom Y1 Poole CN3 Akingbola OA3 Ritter JM1 Xiong Z3 da Silva AJ1 Roellig D1 Van Dyke RB3 Stern H3 Xiao L1 Beach MJ1
# Cosine Similarity : 0.03934835270047188
#
#
# Document: A Case of Primary Amebic Meningoencephalitis Associated with Surfing at an Artificial Surf Venue Environmental Investigation
# Cosine Similarity : 0.03244861960411072
#
#
# Document: Author information 1Centers for Disease Control and Prevention Atlanta Georgia 2Louisiana Department of Health and Hospitals New Orleans and Baton Rouge 3Tulane University Health Sciences Center New Orleans Louisiana
# Cosine Similarity : 0.029940808191895485
#
#
# Document: Primary Amebic Meningoencephalitis Associated With Rafting on an Artificial Whitewater River Case Report and Environmental Investigation
# Cosine Similarity : 0.025627994909882545
#
#
# Document: Author information 1Department of Medicine Division Allergy and Infectious Disease Center for Emerging and Reemerging Infectious Disease CERID University of Washington Seattle Washington United States of America 2Seattle Structural Genomics Center for Infectious Diseases Seattle Washington United States of America 3Department of Biology Washington University St Louis Missouri United States of America 4UCB Pharma Bainbridge Island Washington United States of America 5Seattle Childrens Research Institute Seattle Washington United States of America 6Department of Pediatrics University of Washington Seattle Washington United States of America 7Department of Biomedical Informatics  Medical Education University of Washington Seattle Washington United States of America 8Department of Global Health Pathobiology University of Washington Seattle Washington United States of America 9Center for Tropical and Emerging Global Diseases University of Georgia Athens Georgia United States of America 10Eukaryotic Pathogens Innovation Center Department of Genetics and Biochemistry Clemson University Clemson South Carolina United States of America 11Department of Chemistry University of South Florida Tampa Florida United States of America 12Department of Chemistry and Chemical Biology and Department of Pharmaceutical Sciences Northeastern University Boston Massachusetts United States of America
# Cosine Similarity : 0.02337782457470894
#
#
# Document: Article in French
# Cosine Similarity : 0.020155450329184532
#
#
# Document: Centers for Disease Control and Prevention CDC
# Cosine Similarity : 0.014331435784697533
#
#
# Document: Copyright © 2023 Dereeper Allouch Guerlais Garnier Ma De Jonckheere Joseph Ali Talarmin and Marcelino
# Cosine Similarity : 0.014219308272004128
#
#
# Document: DOI 101093cidcis626 PMID 22919000 Indexed for MEDLINE
# Cosine Similarity : 0.00700010359287262
#
#
# Document: PMID 15915965 Indexed for MEDLINE
# Cosine Similarity : 0.00700010359287262
#
#
# Document: DOI 101128mSphere0063721 PMCID PMC8386437 PMID 34378985 Indexed for MEDLINE
# Cosine Similarity : 0.00700010359287262
#
#
# Document: PMID 8918032 Indexed for MEDLINE
# Cosine Similarity : 0.00700010359287262
#
#
# Document: PMCID PMC4585351 PMID 24226628 Indexed for MEDLINE
# Cosine Similarity : 0.00700010359287262
#
#
# Document: DOI 101371journalpone0241738 PMCID PMC7990177 PMID 33760815 Indexed for MEDLINE
# Cosine Similarity : 0.00700010359287262
#
#
# Document: DOI 101093cidciv017 PMCID PMC4627687 PMID 25595746 Indexed for MEDLINE
# Cosine Similarity : 0.00700010359287262
#
#
# Document: DOI 101111neup12151 PMID 25186798 Indexed for MEDLINE
# Cosine Similarity : 0.00700010359287262
#
#
# Document: DOI 103201eid2701202119 PMCID PMC7774533 PMID 33350926 Indexed for MEDLINE
# Cosine Similarity : 0.00700010359287262
#
#
# Document: DOI 101016jexppara201803010 PMCID PMC5918159 PMID 29551628 Indexed for MEDLINE
# Cosine Similarity : 0.00700010359287262
#
#
# Document: DOI 101093cidcix810 PMCID PMC5801760 PMID 29401275 Indexed for MEDLINE
# Cosine Similarity : 0.00700010359287262
#
#
# Document: Awadalla HN1 Sadaka HA
# Cosine Similarity : 0.0
#
#
# Document: Miko S1 Cope JR1 Hlavsa MC1 Ali IKM1 Brown TW1 Collins JP1 Greeley RD2 Kahler AM1 Moore KO3 Roundtree AV14 Roy S1 Sanders LL5 Shah V5 Stuteville HD3 Mattioli MC1
# Cosine Similarity : 0.0
#
#
# Document: DOI 101099jmmcr0005042 PMCID PMC5330229 PMID 28348761
# Cosine Similarity : 0.0
#
#
# Document: Stubhaug TT1 Reiakvam OM2 Stensvold CR3 Hermansen NO1 HolbergPetersen M1 Antal EA4 Gaustad K5 Førde IS5 Heger B2
# Cosine Similarity : 0.0
#
#
# Document: DOI 101021acsestwater2c00592 PMCID PMC10193442 PMID 37213412
# Cosine Similarity : 0.0
#
#
# Document: JaffarBandjee MC1 Alessandri JL Molet B Clouzeau J Jacquemot L Sampériz S Saly JC
# Cosine Similarity : 0.0
#
#
# Document: Dereeper A1 Allouch N1 Guerlais V1 Garnier M1 Ma L2 De Jonckheere JF3 Joseph SJ4 Ali IKM4 Talarmin A1 Marcelino I1
# Cosine Similarity : 0.0
#
#
# Document: Tillery L12 Barrett K12 Goldstein J3 Lassner JW3 Osterhout B3 Tran NL3 Xu L3 Young RM3 Craig J12 Chun I12 Dranow DM24 Abendroth J24 Delker SL24 Davies DR24 Mayclin SJ24 Calhoun B24 Bolejack MJ24 Staker B25 Subramanian S25 Phan I25 Lorimer DD24 Myler PJ25678 Edwards TE24 Kyle DE9 Rice CA9 Morris JC10 Leahy JW11 Manetsch R12 Barrett LK12 Smith CL3 Van Voorhis WC128
# Cosine Similarity : 0.0
#
#
# Document: Cope JR1 Murphy J1 Kahler A1 Gorbett DG2 Ali I1 Taylor B3 Corbitt L4 Roy S1 Lee N5 Roellig D1 Brewer S6 Hill VR1
# Cosine Similarity : 0.0
#
#
# Document: DOI 103389fmicb20221056418 PMCID PMC9928731 PMID 36817109
# Cosine Similarity : 0.0
#
#
# Document: Zyserman I1 Mondal D2 Sarabia F2 McKerrow JH1 Roush WR2 Debnath A3
# Cosine Similarity : 0.0
#
#
# Document: Gharpure R Gleason M Salah Z Blackstock AJ HessHomeier D Yoder JS Ali IKM Collier SA Cope JR
# Cosine Similarity : 0.0
#
#
# Document: Joseph SJ1 Park S2 Kelley A2 Roy S1 Cope JR1 Ali IKM1
# Cosine Similarity : 0.0
#
#
# Document: Itoh K1 Yagita K Nozaki T Katano H Hasegawa H Matsuo K Hosokawa Y Tando S Fushiki S
# Cosine Similarity : 0.0
#
#
# Document: Geographic Range of Recreational WaterAssociated Primary Amebic Meningoencephalitis United States 19782018
# Cosine Similarity : -0.03697952628135681

# %% [markdown]
# # Evaluation

# %% [markdown]
# The code cells above showcase three methods for documents retrival based on a given query. Each method successfully organizes the retrieved documents from most relevant to least relevant. It's evident that approaches solely relying on term frequency were surpassed by those utilizing sentence embeddings, which capture semantic relatioships of words within a sentence.
# Additionaly, models pre-trained within our specific domain, such as BioSentVec, demonstrated superior accuracy

# %%
tf_idf_bm_25 = "INTRODUCTION: Primary amoebic meningoencephalitis (PAM) is a rare disease caused\
by the free-living amoeba Naegleria fowleri. Infection occurs by insufflation of\
water containing amoebae into the nasal cavity, and is usually associated with\
bathing in freshwater. Nasal irrigation is a more rarely reported route of\
infection.\
CASE PRESENTATION: A fatal case of PAM in a previously healthy Norwegian woman,\
acquired during a holiday trip to Thailand, is described. Clinical findings were\
consistent with rapidly progressing meningoencephalitis. The cause of infection\
was discovered by chance, owing to the unexpected detection of N. fowleri DNA by\
a PCR assay targeting fungi. A conclusive diagnosis was established based on\
sequencing of N. fowleri DNA from brain biopsies, supported by histopathological\
findings. Nasal irrigation using contaminated tap water is suspected as the\
source of infection.\
CONCLUSION: The clinical presentation of PAM is very similar to severe bacterial\
meningitis. This case is a reminder that when standard investigations fail to\
identify a cause of infection in severe meningoencephalitis, it is of crucial\
importance to continue a broad search for a conclusive diagnosis. PAM should be\
considered as a diagnosis in patients with symptoms of severe\
meningoencephalitis returning from endemic areas."

tf_idf_vectorizer = "Fatal primary amoebic meningoencephalitis in a Norwegian tourist returning from\
Thailand."

doc2vec = " Author information 1National Center for Emerging and Zoonotic Infectious Diseases Centers\
 for Disease Control and Prevention1600 Clifton Road Atlanta GA 30329 USA jey9cdcgov"

sentence_transformer = "Balamuthia mandrillaris is an amoeba found in fresh water and soil that cause\
 granulomatous amoebic encephalitis We report herein an autopsy case of B mandrillaris amoebic\
  encephalitis which wa definitely diagnosed by PCR An 81yearold man who had Sjögrens syndrome\
   manifested drowsiness 2 month before his death with progressive deterioration Neuroimaging\
    demonstrated focus of T2 and fluidattenuated inversion recovery high and T1 lowintensity with\
     irregular postcontrast ring enhancement in the cerebral hemisphere thalamus and midbrain\
      Pathologically multiple hemorrhagic and necrotic lesion were found in the cerebrum thalamus\
       midbrain pons medulla and cerebellum which were characterized by liquefactive necrosis marked \
        edema hemorrhage and necrotizing vasculitis associated with the perivascular accumulation of amoebic\
         trophozoite a few cyst and the infiltration of numerous neutrophil and microgliamacrophages The trophozoite\
          were ovoid or round 1060 μm in diameter and they showed foamy cytoplasm and a round nucleus with small\
           karyosome in the center The PCR and immunohistochemistry from paraffinembedded brain specimen revealed\
            angioinvasive encephalitis due to B mandrillaris Human case of B mandrillaris brain infection are rare\
             in Japan with only a few brief report in the literature"

bioSentVec = "INTRODUCTION Primary amoebic meningoencephalitis PAM is a rare disease caused by the freeliving\
 amoeba Naegleria fowleri Infection occurs by insufflation of water containing amoeba into the nasal cavity\
  and is usually associated with bathing in freshwater Nasal irrigation is a more rarely reported route of infection\
   CASE PRESENTATION A fatal case of PAM in a previously healthy Norwegian woman acquired during a holiday trip\
    to Thailand is described Clinical finding were consistent with rapidly progressing meningoencephalitis\
     The cause of infection wa discovered by chance owing to the unexpected detection of N fowleri DNA by a\
      PCR assay targeting fungi A conclusive diagnosis wa established based on sequencing of N fowleri DNA\
       from brain biopsy supported by histopathological finding Nasal irrigation using contaminated tap water\
        is suspected a the source of infection CONCLUSION The clinical presentation of PAM is very similar to\
         severe bacterial meningitis This case is a reminder that when standard investigation fail to identify\
          a cause of infection in severe meningoencephalitis it is of crucial importance to continue a broad search\
           for a conclusive diagnosis PAM should be considered a a diagnosis in patient with symptom of severe\
            meningoencephalitis returning from endemic area"

# %%
print(f'Question: {question}\n')
print(f'TF-IDF>>BM25: {tf_idf_bm_25 }\n')
print(f'TF-IDF Vectorizer: {tf_idf_vectorizer}\n')
print(f'Doc2Vec: {doc2vec}\n')
print(f'sentence transformers: {sentence_transformer}\n')
print(f'BioSentVec: {bioSentVec}\n')
# Out:
# Question: What cause amoebic brain disease and is associated with freshwater source
#
# TF-IDF>>BM25: INTRODUCTION: Primary amoebic meningoencephalitis (PAM) is a rare disease causedby the free-living amoeba Naegleria fowleri. Infection occurs by insufflation ofwater containing amoebae into the nasal cavity, and is usually associated withbathing in freshwater. Nasal irrigation is a more rarely reported route ofinfection.CASE PRESENTATION: A fatal case of PAM in a previously healthy Norwegian woman,acquired during a holiday trip to Thailand, is described. Clinical findings wereconsistent with rapidly progressing meningoencephalitis. The cause of infectionwas discovered by chance, owing to the unexpected detection of N. fowleri DNA bya PCR assay targeting fungi. A conclusive diagnosis was established based onsequencing of N. fowleri DNA from brain biopsies, supported by histopathologicalfindings. Nasal irrigation using contaminated tap water is suspected as thesource of infection.CONCLUSION: The clinical presentation of PAM is very similar to severe bacterialmeningitis. This case is a reminder that when standard investigations fail toidentify a cause of infection in severe meningoencephalitis, it is of crucialimportance to continue a broad search for a conclusive diagnosis. PAM should beconsidered as a diagnosis in patients with symptoms of severemeningoencephalitis returning from endemic areas.
#
# TF-IDF Vectorizer: Fatal primary amoebic meningoencephalitis in a Norwegian tourist returning fromThailand.
#
# Doc2Vec:  Author information 1National Center for Emerging and Zoonotic Infectious Diseases Centers for Disease Control and Prevention1600 Clifton Road Atlanta GA 30329 USA jey9cdcgov
#
# sentence transformers: Balamuthia mandrillaris is an amoeba found in fresh water and soil that cause granulomatous amoebic encephalitis We report herein an autopsy case of B mandrillaris amoebic  encephalitis which wa definitely diagnosed by PCR An 81yearold man who had Sjögrens syndrome   manifested drowsiness 2 month before his death with progressive deterioration Neuroimaging    demonstrated focus of T2 and fluidattenuated inversion recovery high and T1 lowintensity with     irregular postcontrast ring enhancement in the cerebral hemisphere thalamus and midbrain      Pathologically multiple hemorrhagic and necrotic lesion were found in the cerebrum thalamus       midbrain pons medulla and cerebellum which were characterized by liquefactive necrosis marked         edema hemorrhage and necrotizing vasculitis associated with the perivascular accumulation of amoebic         trophozoite a few cyst and the infiltration of numerous neutrophil and microgliamacrophages The trophozoite          were ovoid or round 1060 μm in diameter and they showed foamy cytoplasm and a round nucleus with small           karyosome in the center The PCR and immunohistochemistry from paraffinembedded brain specimen revealed            angioinvasive encephalitis due to B mandrillaris Human case of B mandrillaris brain infection are rare             in Japan with only a few brief report in the literature
#
# BioSentVec: INTRODUCTION Primary amoebic meningoencephalitis PAM is a rare disease caused by the freeliving amoeba Naegleria fowleri Infection occurs by insufflation of water containing amoeba into the nasal cavity  and is usually associated with bathing in freshwater Nasal irrigation is a more rarely reported route of infection   CASE PRESENTATION A fatal case of PAM in a previously healthy Norwegian woman acquired during a holiday trip    to Thailand is described Clinical finding were consistent with rapidly progressing meningoencephalitis     The cause of infection wa discovered by chance owing to the unexpected detection of N fowleri DNA by a      PCR assay targeting fungi A conclusive diagnosis wa established based on sequencing of N fowleri DNA       from brain biopsy supported by histopathological finding Nasal irrigation using contaminated tap water        is suspected a the source of infection CONCLUSION The clinical presentation of PAM is very similar to         severe bacterial meningitis This case is a reminder that when standard investigation fail to identify          a cause of infection in severe meningoencephalitis it is of crucial importance to continue a broad search           for a conclusive diagnosis PAM should be considered a a diagnosis in patient with symptom of severe            meningoencephalitis returning from endemic area
